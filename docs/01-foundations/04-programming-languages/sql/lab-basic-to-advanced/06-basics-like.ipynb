# %%
# %run 02-connect.ipynb

# %%
# %%sql
#
# SELECT *
# FROM billboard_top_100_year_end
# LIMIT 10;
# Out:
#      year  year_rank            group           artist  \
# 0  1956.0        1.0  "Elvis Presley"  "Elvis Presley"
# 1  1956.0        2.0  "Elvis Presley"  "Elvis Presley"
# 2  1956.0        3.0  "Nelson Riddle"  "Nelson Riddle"
# 3  1956.0        4.0       "Platters"       "Platters"
# 4  1956.0        5.0     "Gogi Grant"     "Gogi Grant"
# 5  1956.0        6.0     "Les Baxter"     "Les Baxter"
# 6  1956.0        7.0      "Doris Day"      "Doris Day"
# 7  1956.0        8.0  "Elvis Presley"  "Elvis Presley"
# 8  1956.0        9.0    "Dean Martin"    "Dean Martin"
# 9  1956.0       10.0      "Kay Starr"      "Kay Starr"
#
#                                     song_name  id
# 0                          "Heartbreak Hotel"   1
# 1                            "Don't Be Cruel"   2
# 2                            "Lisbon Antigua"   3
# 3                                 "My Prayer"   4
# 4                          "The Wayward Wind"   5
# 5                  "The Poor People Of Paris"   6
# 6  "Whatever Will Be Will Be (Que Sera Sera)"   7
# 7                                 "Hound Dog"   8
# 8                 "Memories Are Made Of This"   9
# 9                       "Rock And Roll Waltz"  10

# %%
# %%sql
#
# SELECT *
# FROM billboard_top_100_year_end
# WHERE artist LIKE '"Snoop%"'
# LIMIT 10;
# Out:
#      year  year_rank                                              group  \
# 0  1994.0       52.0                                 "Snoop Doggy Dogg"
# 1  1994.0       62.0                                 "Snoop Doggy Dogg"
# 2  2000.0       76.0                         "Dr. Dre feat. Snoop Dogg"
# 3  2003.0       42.0  "Snoop Dogg feat. Pharrell and Uncle Charlie W...
# 4  2003.0       76.0             "Chingy feat. Ludacris and Snoop Dogg"
# 5  2004.0       71.0                        "Snoop Dogg feat. Pharrell"
# 6  2004.0       87.0             "Chingy feat. Ludacris and Snoop Dogg"
# 7  2005.0       23.0                        "Snoop Dogg feat. Pharrell"
# 8  2006.0       15.0              "The Pussycat Dolls feat. Snoop Dogg"
# 9  2007.0        8.0                            "Akon feat. Snoop Dogg"
#
#                artist                     song_name    id
# 0  "Snoop Doggy Dogg"               "Gin And Juice"  3964
# 1  "Snoop Doggy Dogg"  "Who Am I (What's My Name?)"  3975
# 2        "Snoop Dogg"            "The Next Episode"  4649
# 3        "Snoop Dogg"                   "Beautiful"  5004
# 4        "Snoop Dogg"                  "Holidae In"  5054
# 5        "Snoop Dogg"       "Drop it Like it's Hot"  5181
# 6        "Snoop Dogg"                  "Holidae In"  5205
# 7        "Snoop Dogg"       "Drop it Like It's Hot"  5251
# 8        "Snoop Dogg"                     "Buttons"  5377
# 9        "Snoop Dogg"            "I Wanna Love You"  5506
