# %%
# %run 02-connect.ipynb

# %%
# %%sql
#
# SELECT *
# FROM billboard_top_100_year_end
# LIMIT 10;
# Out:
#      year  year_rank            group           artist  \
# 0  1956.0        1.0  "Elvis Presley"  "Elvis Presley"
# 1  1956.0        2.0  "Elvis Presley"  "Elvis Presley"
# 2  1956.0        3.0  "Nelson Riddle"  "Nelson Riddle"
# 3  1956.0        4.0       "Platters"       "Platters"
# 4  1956.0        5.0     "Gogi Grant"     "Gogi Grant"
# 5  1956.0        6.0     "Les Baxter"     "Les Baxter"
# 6  1956.0        7.0      "Doris Day"      "Doris Day"
# 7  1956.0        8.0  "Elvis Presley"  "Elvis Presley"
# 8  1956.0        9.0    "Dean Martin"    "Dean Martin"
# 9  1956.0       10.0      "Kay Starr"      "Kay Starr"
#
#                                     song_name  id
# 0                          "Heartbreak Hotel"   1
# 1                            "Don't Be Cruel"   2
# 2                            "Lisbon Antigua"   3
# 3                                 "My Prayer"   4
# 4                          "The Wayward Wind"   5
# 5                  "The Poor People Of Paris"   6
# ...

# %%
# %%sql
#
# SELECT *
# FROM billboard_top_100_year_end
# WHERE year = 2012 AND year_rank <= 10
# LIMIT 10;
# Out:
#      year  year_rank                         group              artist  \
# 0  2012.0        1.0          "Gotye feat. Kimbra"             "Gotye"
# 1  2012.0        1.0          "Gotye feat. Kimbra"            "Kimbra"
# 2  2012.0        2.0            "Carly Rae Jepsen"  "Carly Rae Jepsen"
# 3  2012.0        3.0    "fun. feat. Janelle Monae"              "fun."
# 4  2012.0        3.0    "fun. feat. Janelle Monae"     "Janelle Monae"
# 5  2012.0        4.0  "Maroon 5 feat. Wiz Khalifa"          "Maroon 5"
# 6  2012.0        4.0  "Maroon 5 feat. Wiz Khalifa"       "Wiz Khalifa"
# 7  2012.0        5.0              "Ellie Goulding"    "Ellie Goulding"
# 8  2012.0        6.0                  "The Wanted"        "The Wanted"
# 9  2012.0        7.0              "Kelly Clarkson"    "Kelly Clarkson"
#
#                             song_name    id
# 0      "Somebody That I Used To Know"  6203
# 1      "Somebody That I Used To Know"  6204
# 2                     "Call Me Maybe"  6205
# ...

# %%
# %%sql
#
# SELECT *
# FROM billboard_top_100_year_end
# WHERE year = 2012
# AND year_rank <= 10
# AND song_name LIKE '%You%'
# LIMIT 10;
# Out:
#      year  year_rank                       group            artist  \
# 0  2012.0        3.0  "fun. feat. Janelle Monae"            "fun."
# 1  2012.0        3.0  "fun. feat. Janelle Monae"   "Janelle Monae"
# 2  2012.0        6.0                "The Wanted"      "The Wanted"
# 3  2012.0        7.0            "Kelly Clarkson"  "Kelly Clarkson"
# 4  2012.0       10.0             "One Direction"   "One Direction"
#
#                             song_name    id
# 0                      "We Are Young"  6206
# 1                      "We Are Young"  6207
# 2                     "Glad You Came"  6211
# 3  "Stronger (What Doesn't Kill You)"  6212
# 4          "What Makes You Beautiful"  6216
