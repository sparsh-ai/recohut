# %% [markdown]
# A city traffic department wants to collect traffic data using swarm UAVs (drones) from a number of locations in the city and use the data collected for improving traffic flow in the city and for a number of other undisclosed projects. You are responsible for creating a scalable data warehouse that will host the vehicle trajectory data extracted by analyzing footage taken by swarm drones and static roadside cameras.
#
# The ELT framework helps analytic engineers in the city traffic department setup transformation workflows on a need basis.
#
# **Reference**
#
# 1. https://github.com/Nathnael12/DataEngineering_Datawarehouse_airflow

# %% [markdown]
# ## Environment Setup

# %%
# %run ~/prerun.ipynb

# %%
import os
from dotenv import load_dotenv
import pandas as pd

# %%
load_dotenv()

DBT_PROJECT_DIR = os.getenv('DBT_PROJECT_DIR')
SCHEMA = os.getenv('SCHEMA')

# %%
db_credentials = get_secret(secret_name='wysde')

USERNAME = db_credentials["RDS_POSTGRES_USERNAME"]
PASSWORD = db_credentials["RDS_POSTGRES_PASSWORD"]
HOST = db_credentials["RDS_POSTGRES_HOST"]
DBNAME = "postgres"

# %% [markdown]
# ### dbt

# %%
# !mkdir -p $DBT_PROJECT_DIR

# %%
# %%writefile $DBT_PROJECT_DIR/profiles.yml
# default:
#   outputs:
#     dev:
#       type: postgres
#       threads: 2
#       host: {HOST}
#       port: 5432
#       user: {USERNAME}
#       pass: "{PASSWORD}"
#       dbname: {DBNAME}
#       schema: {SCHEMA}
#   target: dev

# %%
# %%writefile $DBT_PROJECT_DIR/dbt_project.yml
# name: 'VehicleTrajectory'
# version: '1.0.0'
# config-version: 2
#
# profile: 'default'
#
# model-paths: ["models"]
# analysis-paths: ["analyses"]
# test-paths: ["tests"]
# seed-paths: ["seeds"]
# macro-paths: ["macros"]
# snapshot-paths: ["snapshots"]
#
# target-path: "target"
# clean-targets:
#   - "target"
#   - "dbt_packages"

# %%
# !dbt debug --profiles-dir $DBT_PROJECT_DIR --project-dir $DBT_PROJECT_DIR
# Out:
# 03:53:12  Running with dbt=1.3.1
# dbt version: 1.3.1
# python version: 3.9.7
# python path: /Users/sparshagarwal/anaconda3/envs/env-spacy/bin/python
# os info: macOS-10.16-x86_64-i386-64bit
# Using profiles.yml file at /Users/sparshagarwal/Desktop/projects/recohut/de/data-engineering-private/workshops/_drone-analytics/_dbt/profiles.yml
# Using dbt_project.yml file at /Users/sparshagarwal/Desktop/projects/recohut/de/data-engineering-private/workshops/_drone-analytics/_dbt/dbt_project.yml
#
# Configuration:
#   profiles.yml file [OK found and valid]
#   dbt_project.yml file [OK found and valid]
#
# Required dependencies:
#  - git [OK found]
#
# Connection:
#   host: database-1.cy8ltogyfgas.us-east-1.rds.amazonaws.com
#   port: 5432
#   user: postgres
#   database: postgres
#   schema: vehicle_trajectory
#   search_path: None
#   keepalives_idle: 0
#   sslmode: None
#   Connection test: [OK connection ok]
#
# All checks passed!

# %%
# %%writefile $DBT_PROJECT_DIR/models/schema.yml
# version: 2
#
# sources:
#   - name: source
#     schema: {SCHEMA}
#     tables:
#       - name: endpoints_location
#       - name: endpoints_trafficinfo
#
# # models:
# #   - name: dim_types
# #     columns:
# #       - name: Id
# #         tests:
# #           - unique
#
# #   - name: fast_vehicles
# #     description: "Query fast vehicles"
#
# #   - name: vehicles_summary
# #     description: "A summary of vehicles by distance and speed"
#
# #   - name: fast_vehicles_summary
# #     description: "A summary of vehicles by distance and speed"
#
# #   - name: timely_summary
# #     description: "A summary of vehicles by speed"
#
# #   - name: speed_timely_summary
# #     description: "A summary of vehicles by distance and speed"
#
# #   - name: lat_timely_summary
# #     description: "A summary of vehicles by distance and speed"
#
# #   - name: lon_timely_summary
# #     description: "A summary of vehicles by distance and speed"

# %% [markdown]
# ## EDA

# %%
df_trafficinfo = pd.read_csv("data/endpoints_trafficinfo.csv")
df_trafficinfo
# Out:
#       id  track_id             type  traveled_d  avg_speed        lat  \
# 0    342       343   Medium Vehicle      177.75   9.724672  37.978357
# 1      1         2              Car      103.37  18.985780  37.978027
# 2      2         3       Motorcycle      130.36  32.589339  37.978110
# 3      3         4       Motorcycle      160.70  26.537342  37.978128
# 4      4         5              Car      164.14  26.379138  37.978152
# ..   ...       ...              ...         ...        ...        ...
# 756  278       279              Car      228.54  12.855408  37.978318
# 757  279       280              Car      507.76  33.601963  37.980734
# 758  280       281   Medium Vehicle      508.87  34.827755  37.980751
# 759  281       282              Car      235.18  13.105756  37.978319
# 760  282       283              Car       29.46   5.467491  37.977631
#
#            lon    speed  lon_acc  lat_acc   time  location_id
# 0    23.737813  22.2933   0.0211  -0.0124  311.0         43.0
# 1    23.737237  19.5936  -0.0688  -0.8172    0.0          3.0
# 2    23.737129   0.0053   0.0083   0.0000    0.0          4.0
# 3    23.737149   0.0022   0.0031   0.0000    0.0          4.0
# 4    23.737110   0.0015   0.0024   0.0000    0.0          4.0
# ..         ...      ...      ...      ...    ...          ...
# 756  23.735342  24.9794  -0.0001   0.0772  250.4          1.0
# 757  23.734999  30.5495   0.0834  -0.0967  252.2         41.0
# 758  23.735024  38.1639   0.0646   0.0463  252.4         42.0
# 759  23.735339  25.5763   0.0233   0.0206  252.6          1.0
# 760  23.737415   3.0620   0.0454  -0.0011  253.4         40.0
#
# [761 rows x 12 columns]

# %% [markdown]
# ## Data Load

# %%
# !dbt seed --profiles-dir $DBT_PROJECT_DIR --project-dir $DBT_PROJECT_DIR
# Out:
# 03:49:02  Running with dbt=1.3.1
# 03:49:02  Partial parse save file not found. Starting full parse.
# 03:49:08  Found 0 models, 2 tests, 0 snapshots, 0 analyses, 289 macros, 0 operations, 2 seed files, 0 sources, 0 exposures, 0 metrics
# 03:49:08
# 03:49:23  Concurrency: 2 threads (target='dev')
# 03:49:23
# 03:49:23  1 of 2 START seed file vehicle_trajectory.endpoints_location ................... [RUN]
# 03:49:23  2 of 2 START seed file vehicle_trajectory.endpoints_trafficinfo ................ [RUN]
# 03:49:27  1 of 2 OK loaded seed file vehicle_trajectory.endpoints_location ............... [INSERT 47 in 4.59s]
# 03:49:44  2 of 2 OK loaded seed file vehicle_trajectory.endpoints_trafficinfo ............ [INSERT 761 in 20.77s]
# 03:49:47
# 03:49:47  Finished running 2 seeds in 0 hours 0 minutes and 39.11 seconds (39.11s).
# 03:49:47
# 03:49:47  Completed successfully
# 03:49:47
# 03:49:47  Done. PASS=2 WARN=0 ERROR=0 SKIP=0 TOTAL=2

# %% [markdown]
# ## Transformation with dbt

# %%
# !dbt run --profiles-dir $DBT_PROJECT_DIR --project-dir $DBT_PROJECT_DIR
# Out:
# 05:11:23  Running with dbt=1.3.1
# 05:11:24  Found 17 models, 3 tests, 0 snapshots, 0 analyses, 289 macros, 0 operations, 2 seed files, 2 sources, 0 exposures, 0 metrics
# 05:11:24
# 05:11:36  Concurrency: 2 threads (target='dev')
# 05:11:36
# 05:11:36  1 of 17 START sql table model vehicle_trajectory.dim_types ..................... [RUN]
# 05:11:36  2 of 17 START sql view model vehicle_trajectory.distance_distribution .......... [RUN]
# 05:11:41  2 of 17 OK created sql view model vehicle_trajectory.distance_distribution ..... [CREATE VIEW in 5.51s]
# 05:11:41  1 of 17 OK created sql table model vehicle_trajectory.dim_types ................ [SELECT 6 in 5.51s]
# 05:11:41  3 of 17 START sql view model vehicle_trajectory.fast_vehicles .................. [RUN]
# 05:11:41  4 of 17 START sql view model vehicle_trajectory.max_distance ................... [RUN]
# 05:11:47  4 of 17 OK created sql view model vehicle_trajectory.max_distance .............. [CREATE VIEW in 5.51s]
# 05:11:47  3 of 17 OK created sql view model vehicle_trajectory.fast_vehicles ............. [CREATE VIEW in 5.51s]
# 05:11:47  5 of 17 START sql view model vehicle_trajectory.max_speed ...................... [RUN]
# 05:11:47  6 of 17 START sql view model vehicle_trajectory.max_time ....................... [RUN]
# 05:11:52  5 of 17 OK created sql view model vehicle_trajectory.max_speed ................. [CREATE VIEW in 5.31s]
# 05:11:52  6 of 17 OK created sql view model vehicle_trajectory.max_time .................. [CREATE VIEW in 5.31s]
# 05:11:52  7 of 17 START sql view model vehicle_trajectory.speed_distribution ............. [RUN]
# 05:11:52  8 of 17 START sql view model vehicle_trajectory.time_distribution .............. [RUN]
# 05:11:56  8 of 17 OK created sql view model vehicle_trajectory.time_distribution ......... [CREATE VIEW in 4.28s]
# 05:11:56  9 of 17 START sql view model vehicle_trajectory.timely_summary ................. [RUN]
# 05:11:57  7 of 17 OK created sql view model vehicle_trajectory.speed_distribution ........ [CREATE VIEW in 4.59s]
# 05:11:57  10 of 17 START sql view model vehicle_trajectory.type_distribution ............. [RUN]
# 05:12:02  9 of 17 OK created sql view model vehicle_trajectory.timely_summary ............ [CREATE VIEW in 5.11s]
# 05:12:02  11 of 17 START sql view model vehicle_trajectory.vehicles_summary .............. [RUN]
# 05:12:02  10 of 17 OK created sql view model vehicle_trajectory.type_distribution ........ [CREATE VIEW in 5.61s]
# 05:12:02  12 of 17 START sql table model vehicle_trajectory.fct_summary .................. [RUN]
# 05:12:07  11 of 17 OK created sql view model vehicle_trajectory.vehicles_summary ......... [CREATE VIEW in 5.31s]
# 05:12:07  13 of 17 START sql table model vehicle_trajectory.fct_trajectory ............... [RUN]
# 05:12:08  12 of 17 OK created sql table model vehicle_trajectory.fct_summary ............. [SELECT 761 in 5.72s]
# 05:12:08  14 of 17 START sql view model vehicle_trajectory.fast_vehicles_summary ......... [RUN]
# 05:12:12  13 of 17 OK created sql table model vehicle_trajectory.fct_trajectory .......... [SELECT 761 in 5.51s]
# 05:12:12  15 of 17 START sql view model vehicle_trajectory.lat_timely_summary ............ [RUN]
# 05:12:13  14 of 17 OK created sql view model vehicle_trajectory.fast_vehicles_summary .... [CREATE VIEW in 4.84s]
# 05:12:13  16 of 17 START sql view model vehicle_trajectory.lon_timely_summary ............ [RUN]
# 05:12:17  15 of 17 OK created sql view model vehicle_trajectory.lat_timely_summary ....... [CREATE VIEW in 4.70s]
# 05:12:17  17 of 17 START sql view model vehicle_trajectory.speed_timely_summary .......... [RUN]
# 05:12:18  16 of 17 OK created sql view model vehicle_trajectory.lon_timely_summary ....... [CREATE VIEW in 4.72s]
# 05:12:22  17 of 17 OK created sql view model vehicle_trajectory.speed_timely_summary ..... [CREATE VIEW in 4.49s]
# 05:12:26
# 05:12:26  Finished running 14 view models, 3 table models in 0 hours 1 minutes and 1.98 seconds (61.98s).
# 05:12:26
# 05:12:26  Completed successfully
# 05:12:26
# 05:12:26  Done. PASS=17 WARN=0 ERROR=0 SKIP=0 TOTAL=17
