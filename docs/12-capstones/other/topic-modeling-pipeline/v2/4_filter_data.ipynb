# %% [markdown]
# # Data Filtering

# %%
# !pip3 freeze | grep -E 'boto3|s3fs|pandas=='
# Out:
# boto3==1.24.61
# pandas==1.4.3
# s3fs==0.4.2

# %%
# %load_ext lab_black
# %load_ext autoreload
# %autoreload 2

# %%
import os
import zipfile
from datetime import datetime
from glob import glob
from typing import Dict, List, Union

import boto3
import pandas as pd

# %% [markdown]
# ## About

# %% [markdown]
# As part of this hourly data processing, we will now
# - filter out tweets with unwanted text in the tweet, where these texts include terms related to the following topics
#   - cryptocurrency (see the `crypto_terms` list below)
#   - video games (`video_game_terms`)
#   - religion (`religious_terms`)
#   - non-English words (`non_english_terms`)
#   - miscellaneous unwanted words (`misc_unwanted_terms`)
#   - inappropriate terms (profanity, etc. in `inappropriate_terms`)
# - only keep tweets that contain terms specific to the subject of this project and these terms are defined below in the following Python lists
#   - `tweet_search_terms`
#   - `case_sensitive_tweet_search_terms`
#   - `joined_tweet_search_terms`
#
# **Pre-Requisites**
# 1. In order to access data stored on Amazon S3, this data preparation notebook must be provided with the following environment variables
#    - `AWS_S3_BUCKET_NAME`

# %% [markdown]
# ## User Inputs

# %%
# raw data on S3
path_to_folder = "/datasets/twitter/kinesis-demo/"

# processed data
processed_data_dir = "data/processed"  # (S3) "data/processed" or (locally) "datasets/twitter/kinesis-demo/processed"
proc_zip_fname = "combined_data.zip"
filtered_zip_fname = "processed_data.zip"

# keep tweets with text containing terms
case_sensitive_tweet_search_terms = ["NASA", "ESA", "CSA", "Kepler"]
tweet_search_terms = [
    "aeronautics",
    # "webb",  # picks up random astronomers unrelated to the mission
    "goddard",
    "propulsion",
    # "telescope",  # picks up topics not related to the mission
    "exoplanet",
    # 'launch',  # picks up topics not related to space exploration
    # 'astronomy',  # picks up random astronomers unrelated to the mission
    # 'astrophysics',  # picks up random astrophysicists unrelated to the mission
    # "laboratory",  # picks up random astronomers unrelated to the mission
    "jwst",
    # "exploration",  # picks up topics not related to space exploration
    # " mission",  # picks up topics not related to space exploration
    "spacecraft",
]
joined_tweet_search_terms = [
    "james webb",
    "space telescope",
    "webb space",
    "webb telescope",
    "jet propulsion lab",
    "canadian space agency",
    "european space agency",
    "national aeronautics",
    "shuttle launch",
    "space shuttle",
    "goddard space flight center",
    "johnson space center",
    "ames research center",
    "marshall space flight center",
    "glenn research center",
    "ball aerospace",
    "harris corporation",
    "space telescope science institute",
    "billochs",
    "johndurning",
    "johnmather",
    "jonathangardner",
    "northrop grumman",
    "lockheed martin",
    # "stephen hawking",  # picks up topics not related to the mission
    # "dark matter",  # picks up topics not related to the mission
    # "dark energy",  # picks up topics not related to the mission
    "hubble space",
    "hubble telescope",
]
# remove tweets with text containing terms
crypto_terms = [
    "crypto",
    # "token",
    "koistarter",
    "daostarter",
    "decentralized",
    # "services",
    # "pancakeswap",
    # "eraxnft",
    # "browsing",
    # "kommunitas",
    # "hosting",
    # "internet",
    # "exipofficial",
    # "servers",
    # "wallet",
    # "liquidity",
    # "rewards",
    # "floki",
    # "10000000000000linkstelegram",
    "dogecoin",
    "czbinance",
    # "watch",
    "binance",
    "dogelonmars",
    "cryptocurrency",
    # "money",
    # "danheld",
    # "cybersecurity",
    "ethereum",
    "bitcrush",
    "vvsorigin",
]
video_games_terms = [
    # "gamejoin",
    "arcade",
    "dreamcast",
    "sega",
    "xbox",
    "wii",
    "ps4",
]
non_english_terms = [
    "webuye",
    "bungoma",
    "ethereum",
    "pay someone",
    "seungkwan",
    "woozi",
    "hoshi",
    "kasama",
    "nung",
    "lahat",
    "jinsoul",
    "brunisoul",
    "loona",
    "taas",
    "nung",
]
misc_unwanted_terms = [
    "nft",
    "volcano detected",
    "block-2",
    "tanzanite",
    "gemstonecarat",
    "popescu",
    "breeding",
    "nairobi",
    "pay someone",
    "homeworkpay",
    "homework",
    "photocards",
    "essay",
    # "hbomax",
]
religious_terms = [
    "scriptures",
    "methusealah",
    "testament",
    "yahweh",
    "god",
    "mullah",
    "allah",
    "clergy",
    "mercy",
    "morality",
    "muslims,",
    "hindus",
    "buddhist",
    "catholics",
    "christians",
    "atheist",
]
inappropriate_terms = [
    "prostitution",
    "musembe",
    "mo-greene",
    "running scared2012",
    "running scared 2012",
    "massacres",
    "eric ephriam chavez",
    "drugs",
    "bin laden",
    "saddam",
    "perished",
    "whore",
    "nasty",
    "nazist",
    "antifa",
    "proud boys",
]
min_num_words_tweet = 10

upload_to_s3 = True
cleanup_local_files = True

# columns for EDA
vcols = [
    "is_quote_status",
    "quote_count",
    "reply_count",
    # "retweet_count",
    "favorite_count",
    "favorited",
    "retweeted",
    "source_text",
    "user_followers",
    "user_friends",
    "user_favourites",
    "user_verified",
    "retweeted_tweet",
]

# %%
s3_bucket_name = os.getenv("AWS_S3_BUCKET_NAME", "sagemakertestwillz3s")

joined_tweet_search_terms_no_spaces = [
    t.replace(" ", "") for t in joined_tweet_search_terms
]
unwanted_partial_strings_list = (
    crypto_terms
    + religious_terms
    + inappropriate_terms
    + video_games_terms
    + misc_unwanted_terms
    + non_english_terms
)
dtypes_dict = {
    "id": pd.StringDtype(),
    "geo": pd.StringDtype(),
    "coordinates": pd.StringDtype(),
    "place": pd.StringDtype(),
    "contributors": pd.StringDtype(),  # pd.BooleanDtype(),
    "is_quote_status": pd.StringDtype(),  # pd.BooleanDtype(),
    "quote_count": pd.Int32Dtype(),
    "reply_count": pd.Int32Dtype(),
    "retweet_count": pd.Int32Dtype(),
    "favorite_count": pd.Int32Dtype(),
    "favorited": pd.StringDtype(),  # pd.BooleanDtype(),
    "retweeted": pd.StringDtype(),  # pd.BooleanDtype(),
    "source": pd.StringDtype(),
    "in_reply_to_user_id": pd.StringDtype(),
    "in_reply_to_screen_name": pd.StringDtype(),
    "source_text": pd.StringDtype(),
    "place_id": pd.StringDtype(),
    "place_url": pd.StringDtype(),
    "place_place_type": pd.StringDtype(),
    "place_name": pd.StringDtype(),
    "place_full_name": pd.StringDtype(),
    "place_country_code": pd.StringDtype(),
    "place_country": pd.StringDtype(),
    "place_bounding_box_type": pd.StringDtype(),
    "place_bounding_box_coordinates": pd.StringDtype(),
    "place_attributes": pd.StringDtype(),
    "coords_type": pd.StringDtype(),
    "coords_lon": pd.StringDtype(),
    "coords_lat": pd.StringDtype(),
    "geo_type": pd.StringDtype(),
    "geo_lon": pd.StringDtype(),
    "geo_lat": pd.StringDtype(),
    "user_name": pd.StringDtype(),
    "user_screen_name": pd.StringDtype(),
    "user_followers": pd.Int32Dtype(),
    "user_friends": pd.Int32Dtype(),
    "user_listed": pd.Int32Dtype(),
    "user_favourites": pd.Int32Dtype(),
    "user_statuses": pd.Int32Dtype(),
    "user_protected": pd.StringDtype(),  # pd.BooleanDtype(),
    "user_verified": pd.StringDtype(),  # pd.BooleanDtype(),
    "user_contributors_enabled": pd.StringDtype(),
    "user_location": pd.StringDtype(),
    "retweeted_tweet": pd.StringDtype(),
    "tweet_text_urls": pd.StringDtype(),
    "tweet_text_hashtags": pd.StringDtype(),
    "tweet_text_usernames": pd.StringDtype(),
    "num_urls_in_tweet_text": pd.Int32Dtype(),
    "num_users_in_tweet_text": pd.Int32Dtype(),
    "num_hashtags_in_tweet_text": pd.Int32Dtype(),
    "text": pd.StringDtype(),
    "contains_wanted_text": pd.BooleanDtype(),
    "contains_wanted_text_case_sensitive": pd.BooleanDtype(),
    "contains_multi_word_wanted_text": pd.BooleanDtype(),
    "contains_crypto_terms": pd.BooleanDtype(),
    "contains_religious_terms": pd.BooleanDtype(),
    "contains_inappropriate_terms": pd.BooleanDtype(),
    "contains_video_games_terms": pd.BooleanDtype(),
    "contains_misc_unwanted_terms": pd.BooleanDtype(),
    "contains_non_english_terms": pd.BooleanDtype(),
}

# %%
session = boto3.Session(profile_name="default")
s3_client = session.client("s3")

# %%
def save_to_parquet(
    df: pd.DataFrame, filepath: str, storage_options: Union[None, Dict[str, str]] = None
) -> None:
    """Save DataFrame to .parquet.gzip file."""
    print(f"Saving to parquet file {os.path.basename(filepath)}...")
    df.to_parquet(filepath, index=False, storage_options=storage_options)
    print("Done.")


def read_parquet(
    filepath: str,
    columns: Union[None, List[str]] = None,
    storage_options: Union[None, Dict[str, str]] = None,
    verbose: bool = False,
) -> pd.DataFrame:
    """Read DataFrame from .parquet.gzip file."""
    df = pd.read_parquet(filepath, columns=columns, storage_options=storage_options)
    if verbose:
        print(
            f"Read {len(df):,} rows of data from parquet "
            f"file {os.path.basename(filepath)}"
        )
    return df


def create_zip_file(
    file_search_pattern: str, processed_data_dir: str, proc_data_zip_fname: str
):
    """Create zipped file."""
    os.chdir(processed_data_dir)
    ZipFile = zipfile.ZipFile(proc_data_zip_fname, "w")
    for f in glob(file_search_pattern):
        ZipFile.write(f, compress_type=zipfile.ZIP_DEFLATED)
    ZipFile.close()
    os.chdir("../../")


def upload_file_to_s3(
    aws_region: str,
    processed_data_dir: str,
    fname: str,
    s3_bucket_name: str,
    s3_key: str,
) -> None:
    """Upload file to key in S3 bucket."""
    s3_resource = boto3.resource("s3", region_name=aws_region)
    s3_resource.meta.client.upload_file(
        f"{processed_data_dir}/{fname}",
        s3_bucket_name,
        s3_key,
    )


def download_file_from_s3(
    s3_bucket_name: str,
    path_to_folder: str,
    data_dir: str,
    fname: str,
    aws_region: str,
) -> None:
    """Download file from ."""
    dest_filepath = os.path.join(data_dir, fname)
    s3_filepath_key = s3_client.list_objects_v2(
        Bucket=s3_bucket_name,
        Delimiter="/",
        Prefix=f"{path_to_folder[1:]}processed/",
    )["Contents"][0]["Key"]
    start = datetime.now()
    print(
        f"Started downloading processed data zip file from {s3_filepath_key} to "
        f"{dest_filepath} at {start.strftime('%Y-%m-%d %H:%M:%S.%f')[:-3]}..."
    )
    s3 = boto3.resource("s3", region_name=aws_region)
    s3.meta.client.download_file(
        s3_bucket_name,
        s3_filepath_key,
        dest_filepath,
    )
    duration = (datetime.now() - start).total_seconds()
    print(f"Done downloading in {duration:.3f} seconds.")


def extract_zip_file(dest_filepath: str, data_dir: str) -> None:
    """."""
    start = datetime.now()
    print(
        "Started extracting filtered data parquet files from "
        f"processed data zip file to {data_dir} at "
        f"{start.strftime('%Y-%m-%d %H:%M:%S.%f')[:-3]}..."
    )
    zip_ref = zipfile.ZipFile(dest_filepath)
    zip_ref.extractall(data_dir)
    zip_ref.close()
    duration = (datetime.now() - start).total_seconds()
    print(f"Done extracting in {duration:.3f} seconds.")

# %%
def get_raw_masks(
    df,
    tweet_search_terms_list: List[str],
    case_sensitive_tweet_search_terms_list: List[str],
    joined_tweet_search_terms_no_spaces_list: List[str],
) -> List[pd.Series]:
    """Get masks for tweets with types of wanted terms in text."""
    lowercase_mask = (
        df["text"].str.lower().str.contains("|".join(tweet_search_terms_list))
    )
    case_mask = df["text"].str.contains(
        "|".join(case_sensitive_tweet_search_terms_list)
    )
    joined_case_mask = (
        df["text"]
        .str.lower()
        .str.replace(" ", "")
        .str.contains("|".join(joined_tweet_search_terms_no_spaces_list))
    )
    print("Created masks to filter raw data based on wanted text in tweets")
    return [lowercase_mask, case_mask, joined_case_mask]


def add_search_term_boolean_columns(
    df: pd.DataFrame,
    lowercase_mask: pd.Series,
    case_mask: pd.Series,
    joined_case_mask: pd.Series,
    crypto_terms_list: List[str],
    religious_terms_list: List[str],
    inappropriate_terms_list: List[str],
    video_games_terms_list: List[str],
    misc_unwanted_terms_list: List[str],
    non_english_terms_list: List[str],
) -> pd.DataFrame:
    """Add boolean columns based on presence of wanted and unwanted terms in tweet text."""
    df = (
        df.assign(contains_wanted_text=lowercase_mask)
        .assign(contains_wanted_text_case_sensitive=case_mask)
        .assign(contains_multi_word_wanted_text=joined_case_mask)
        .assign(
            contains_crypto_terms=df["text"].str.contains("|".join(crypto_terms_list))
        )
        .assign(
            contains_religious_terms=df["text"].str.contains(
                "|".join(religious_terms_list)
            )
        )
        .assign(
            contains_inappropriate_terms=df["text"].str.contains(
                "|".join(inappropriate_terms_list)
            )
        )
        .assign(
            contains_video_games_terms=df["text"].str.contains(
                "|".join(video_games_terms_list)
            )
        )
        .assign(
            contains_misc_unwanted_terms=df["text"].str.contains(
                "|".join(misc_unwanted_terms_list)
            )
        )
        .assign(
            contains_non_english_terms=df["text"].str.contains(
                "|".join(non_english_terms_list)
            )
        )
    )
    print("Created boolean columns to indicate presence of unwanted terms in tweets")
    terms_str = []
    pcts_total = []
    for c in df.columns[df.columns.str.endswith("_terms")]:
        pct_of_total = (df[c].sum() / len(df)) * 100
        term_type = c.replace("contains_", "").replace("_terms", "")
        term_str = f"{term_type}={pct_of_total:.3f}"
        terms_str.append(term_str)
        pcts_total.append(pct_of_total)
    term_str_full = " | ".join(terms_str) + f" | total unwanted={sum(pcts_total):.3f}"
    print(term_str_full)
    return df


def apply_masks(
    df: pd.DataFrame,
    case_mask: pd.Series,
    lowercase_mask: pd.Series,
    joined_case_mask: pd.Series,
    unwanted_partial_strings_list: List[str],
) -> pd.DataFrame:
    """Apply masks for only keeping tweets based on terms in text."""
    df = df.loc[case_mask | lowercase_mask | joined_case_mask]
    unwanted_mask = df["text"].str.contains("|".join(unwanted_partial_strings_list))
    df = df.loc[~unwanted_mask]
    print(f"Kept {len(df):,} tweets after filtering raw data with masks")
    return df


def filter_by_num_words_in_tweet(
    df: pd.DataFrame, min_num_tweet_words_wanted: int
) -> pd.DataFrame:
    """Filter tweets based on number of words in text."""
    min_num_words_mask = (
        df["text"].str.split(" ").str.len() >= min_num_tweet_words_wanted
    )
    print(
        f"Kept {len(df.loc[min_num_words_mask]):,} tweets with more than "
        f"approximately {min_num_tweet_words_wanted:,} words per tweet"
    )
    df = df.loc[min_num_words_mask]
    return df

# %%
def filter_files_per_hour(
    proc_files: List[str],
    tweet_search_terms: List[str],
    case_sensitive_tweet_search_terms: List[str],
    joined_tweet_search_terms_no_spaces: List[str],
    crypto_terms: List[str],
    religious_terms: List[str],
    inappropriate_terms: List[str],
    video_games_terms: List[str],
    misc_unwanted_terms: List[str],
    non_english_terms: List[str],
    unwanted_partial_strings_list: List[str],
    min_num_words_tweet: int,
    dtypes_dict: Dict,
    processed_data_dir: str,
) -> pd.DataFrame:
    """Filter files combined per hour."""
    records = []
    for k, f in enumerate(proc_files, 1):
        start = datetime.now()
        print(
            f"Filtering Tweets from combined data file {k}/{len(proc_files):,} "
            f"({os.path.basename(f)})\nStarting time = "
            f"{start.strftime('%Y-%m-%d %H:%M:%S.%f')[:-3]}..."
        )
        # extract
        df_combined = read_parquet(f, None, None, True)
        # transform
        lowercase_mask, case_mask, joined_case_mask = get_raw_masks(
            df_combined,
            tweet_search_terms,
            case_sensitive_tweet_search_terms,
            joined_tweet_search_terms_no_spaces,
        )
        df_filtered = (
            df_combined.pipe(
                add_search_term_boolean_columns,
                lowercase_mask=lowercase_mask,
                case_mask=case_mask,
                joined_case_mask=joined_case_mask,
                crypto_terms_list=crypto_terms,
                religious_terms_list=religious_terms,
                inappropriate_terms_list=inappropriate_terms,
                video_games_terms_list=video_games_terms,
                misc_unwanted_terms_list=misc_unwanted_terms,
                non_english_terms_list=non_english_terms,
            )
            .pipe(
                apply_masks,
                case_mask=case_mask,
                lowercase_mask=lowercase_mask,
                joined_case_mask=joined_case_mask,
                unwanted_partial_strings_list=unwanted_partial_strings_list,
            )
            .pipe(
                filter_by_num_words_in_tweet,
                min_num_tweet_words_wanted=min_num_words_tweet,
            )
            .astype(dtypes_dict)
        )
        end = datetime.now()
        duration = (end - start).total_seconds()
        print(
            "Done filtering at "
            f"{end.strftime('%Y-%m-%d %H:%M:%S.%f')[:-3]} ({duration:.3f} seconds)."
        )
        # load
        file_name = (
            f"filtered__{os.path.basename(f).split('.')[0]}"
            # f"__{end.strftime('%Y%m%d_%H%M%S')}"
        )
        filepath = f"{processed_data_dir}/{file_name}.parquet.gzip"
        save_to_parquet(df_filtered, filepath, None)
        records.append(
            {
                "filename": f,
                "num_rows_combined": len(df_combined),
                "num_rows_filtered": len(df_filtered),
            }
        )
        if k < len(proc_files):
            print()
    # summarize
    df_summary = pd.DataFrame.from_records(records)
    num_combined_rows = df_summary["num_rows_combined"].sum()
    num_filtered_rows = df_summary["num_rows_filtered"].sum()
    print(
        f"\nCombined data contained {num_combined_rows:,} rows\n"
        f"Filtered data contains {num_filtered_rows:,} rows"
    )
    return df_summary

# %% [markdown]
# ## Get Hourly Combined Data

# %%
# %%time
if not os.path.exists(os.path.join(processed_data_dir, proc_zip_fname)):
    download_file_from_s3(
        s3_bucket_name, path_to_folder, processed_data_dir, proc_zip_fname, session.region_name
    )
    extract_zip_file(os.path.join(processed_data_dir, proc_zip_fname), processed_data_dir)
combined_files = glob(f"{processed_data_dir}/*.parquet.gzip")
# Out:
# CPU times: user 851 µs, sys: 174 µs, total: 1.03 ms
# Wall time: 994 µs

# %% [markdown]
# ## Filter Data Per Hour

# %% [markdown]
# Run an ETL workflow to process hourly file objects in the S3 bucket
# - extract all hourly file objects into a single `pandas` `DataFrame`
# - process the hourly data
#   - exclude tweets that contain terms related to
#     - cryptocurrency
#     - video games
#     - non-English
#     - religious
#     - miscellaneous unwanted
#     - inappropriate
#
#     subjects
#   - include tweets that contain terms related to the subject of this project
#   - set appropriate datatypes
# - export the processed `DataFrame` to a `.parquet` file

# %%
# %%time
df_summary = filter_files_per_hour(
    combined_files,
    tweet_search_terms,
    case_sensitive_tweet_search_terms,
    joined_tweet_search_terms_no_spaces,
    crypto_terms,
    religious_terms,
    inappropriate_terms,
    video_games_terms,
    misc_unwanted_terms,
    non_english_terms,
    unwanted_partial_strings_list,
    min_num_words_tweet,
    dtypes_dict,
    processed_data_dir,
)
display(df_summary)
# Out:
# Filtering Tweets from combined data file 1/225 (2022010308.parquet.gzip)
# Starting time = 2022-08-28 18:14:01.804...
# Read 3,537 rows of data from parquet file 2022010308.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.311 | religious=0.339 | inappropriate=0.057 | video_games=0.198 | misc_unwanted=0.028 | non_english=0.396 | total unwanted=1.329
# Kept 494 tweets after filtering raw data with masks
# Kept 455 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:02.313 (0.508 seconds).
# Saving to parquet file filtered__2022010308.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 2/225 (2022010310.parquet.gzip)
# Starting time = 2022-08-28 18:14:02.329...
# Read 4,015 rows of data from parquet file 2022010310.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=4.533 | religious=0.224 | inappropriate=0.100 | video_games=0.025 | misc_unwanted=0.125 | non_english=0.498 | total unwanted=5.504
# Kept 436 tweets after filtering raw data with masks
# Kept 403 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:02.736 (0.407 seconds).
# Saving to parquet file filtered__2022010310.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 3/225 (2022010312.parquet.gzip)
# Starting time = 2022-08-28 18:14:02.752...
# Read 4,314 rows of data from parquet file 2022010312.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.533 | religious=0.139 | inappropriate=0.070 | video_games=0.046 | misc_unwanted=0.046 | non_english=0.185 | total unwanted=1.020
# Kept 500 tweets after filtering raw data with masks
# Kept 463 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:03.073 (0.321 seconds).
# Saving to parquet file filtered__2022010312.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 4/225 (2022010314.parquet.gzip)
# Starting time = 2022-08-28 18:14:03.084...
# Read 4,932 rows of data from parquet file 2022010314.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=12.125 | religious=0.243 | inappropriate=0.081 | video_games=0.081 | misc_unwanted=0.020 | non_english=0.162 | total unwanted=12.713
# Kept 654 tweets after filtering raw data with masks
# Kept 622 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:03.457 (0.373 seconds).
# Saving to parquet file filtered__2022010314.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 5/225 (2022010315.parquet.gzip)
# Starting time = 2022-08-28 18:14:03.471...
# Read 6,292 rows of data from parquet file 2022010315.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.366 | religious=0.254 | inappropriate=0.048 | video_games=0.032 | misc_unwanted=0.064 | non_english=0.095 | total unwanted=0.858
# Kept 1,759 tweets after filtering raw data with masks
# Kept 1,716 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:03.971 (0.500 seconds).
# Saving to parquet file filtered__2022010315.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 6/225 (2022010317.parquet.gzip)
# Starting time = 2022-08-28 18:14:03.989...
# Read 5,726 rows of data from parquet file 2022010317.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=2.078 | religious=0.175 | inappropriate=0.087 | video_games=0.157 | misc_unwanted=0.000 | non_english=0.017 | total unwanted=2.515
# Kept 779 tweets after filtering raw data with masks
# Kept 727 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:04.368 (0.379 seconds).
# Saving to parquet file filtered__2022010317.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 7/225 (2022010319.parquet.gzip)
# Starting time = 2022-08-28 18:14:04.381...
# Read 5,551 rows of data from parquet file 2022010319.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.703 | religious=0.414 | inappropriate=0.018 | video_games=0.018 | misc_unwanted=0.126 | non_english=0.090 | total unwanted=1.369
# Kept 827 tweets after filtering raw data with masks
# Kept 773 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:04.864 (0.483 seconds).
# Saving to parquet file filtered__2022010319.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 8/225 (2022010320.parquet.gzip)
# Starting time = 2022-08-28 18:14:04.876...
# Read 4,802 rows of data from parquet file 2022010320.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.354 | religious=0.312 | inappropriate=0.021 | video_games=0.146 | misc_unwanted=0.000 | non_english=0.000 | total unwanted=0.833
# Kept 924 tweets after filtering raw data with masks
# Kept 836 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:05.319 (0.443 seconds).
# Saving to parquet file filtered__2022010320.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 9/225 (2022010322.parquet.gzip)
# Starting time = 2022-08-28 18:14:05.336...
# Read 5,776 rows of data from parquet file 2022010322.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.039 | religious=0.087 | inappropriate=0.052 | video_games=0.052 | misc_unwanted=0.069 | non_english=0.069 | total unwanted=1.368
# Kept 943 tweets after filtering raw data with masks
# Kept 858 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:05.754 (0.418 seconds).
# Saving to parquet file filtered__2022010322.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 10/225 (2022010400.parquet.gzip)
# Starting time = 2022-08-28 18:14:05.767...
# Read 4,759 rows of data from parquet file 2022010400.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.967 | religious=0.210 | inappropriate=0.021 | video_games=0.042 | misc_unwanted=0.105 | non_english=0.147 | total unwanted=1.492
# Kept 715 tweets after filtering raw data with masks
# Kept 646 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:06.087 (0.320 seconds).
# Saving to parquet file filtered__2022010400.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 11/225 (2022010417.parquet.gzip)
# Starting time = 2022-08-28 18:14:06.099...
# Read 7,288 rows of data from parquet file 2022010417.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.659 | religious=0.233 | inappropriate=0.041 | video_games=0.014 | misc_unwanted=0.041 | non_english=0.055 | total unwanted=1.043
# Kept 1,904 tweets after filtering raw data with masks
# Kept 1,691 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:06.657 (0.557 seconds).
# Saving to parquet file filtered__2022010417.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 12/225 (2021123017.parquet.gzip)
# Starting time = 2022-08-28 18:14:06.675...
# Read 2,055 rows of data from parquet file 2021123017.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.438 | religious=0.146 | inappropriate=0.292 | video_games=0.097 | misc_unwanted=0.097 | non_english=0.146 | total unwanted=1.217
# Kept 426 tweets after filtering raw data with masks
# Kept 391 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:06.842 (0.166 seconds).
# Saving to parquet file filtered__2021123017.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 13/225 (2021123118.parquet.gzip)
# Starting time = 2022-08-28 18:14:06.852...
# Read 3,555 rows of data from parquet file 2021123118.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=3.657 | religious=0.281 | inappropriate=0.056 | video_games=0.197 | misc_unwanted=0.056 | non_english=0.084 | total unwanted=4.332
# Kept 506 tweets after filtering raw data with masks
# Kept 477 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:07.092 (0.240 seconds).
# Saving to parquet file filtered__2021123118.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 14/225 (2021123119.parquet.gzip)
# Starting time = 2022-08-28 18:14:07.102...
# Read 4,434 rows of data from parquet file 2021123119.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=4.285 | religious=0.293 | inappropriate=0.045 | video_games=0.045 | misc_unwanted=0.135 | non_english=0.023 | total unwanted=4.826
# Kept 580 tweets after filtering raw data with masks
# Kept 541 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:07.421 (0.319 seconds).
# Saving to parquet file filtered__2021123119.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 15/225 (2021123120.parquet.gzip)
# Starting time = 2022-08-28 18:14:07.434...
# Read 5,140 rows of data from parquet file 2021123120.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.167 | religious=0.272 | inappropriate=0.039 | video_games=0.078 | misc_unwanted=0.000 | non_english=0.019 | total unwanted=1.576
# Kept 853 tweets after filtering raw data with masks
# Kept 643 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:07.846 (0.412 seconds).
# Saving to parquet file filtered__2021123120.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 16/225 (2021123121.parquet.gzip)
# Starting time = 2022-08-28 18:14:07.861...
# Read 4,354 rows of data from parquet file 2021123121.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.413 | religious=0.184 | inappropriate=0.115 | video_games=0.184 | misc_unwanted=0.184 | non_english=0.023 | total unwanted=1.102
# Kept 917 tweets after filtering raw data with masks
# Kept 622 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:08.155 (0.294 seconds).
# Saving to parquet file filtered__2021123121.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 17/225 (2021123122.parquet.gzip)
# Starting time = 2022-08-28 18:14:08.167...
# Read 4,494 rows of data from parquet file 2021123122.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.357 | religious=0.289 | inappropriate=0.045 | video_games=0.178 | misc_unwanted=0.089 | non_english=0.022 | total unwanted=1.980
# Kept 878 tweets after filtering raw data with masks
# Kept 678 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:08.466 (0.299 seconds).
# Saving to parquet file filtered__2021123122.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 18/225 (2021123123.parquet.gzip)
# Starting time = 2022-08-28 18:14:08.478...
# Read 4,910 rows of data from parquet file 2021123123.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.163 | religious=0.448 | inappropriate=0.041 | video_games=0.163 | misc_unwanted=0.041 | non_english=0.000 | total unwanted=0.855
# Kept 1,111 tweets after filtering raw data with masks
# Kept 975 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:08.791 (0.313 seconds).
# Saving to parquet file filtered__2021123123.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 19/225 (2022010100.parquet.gzip)
# Starting time = 2022-08-28 18:14:08.805...
# Read 6,766 rows of data from parquet file 2022010100.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.118 | religious=0.281 | inappropriate=0.059 | video_games=0.074 | misc_unwanted=0.030 | non_english=0.103 | total unwanted=0.665
# Kept 1,983 tweets after filtering raw data with masks
# Kept 1,864 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:09.245 (0.440 seconds).
# Saving to parquet file filtered__2022010100.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 20/225 (2022010101.parquet.gzip)
# Starting time = 2022-08-28 18:14:09.264...
# Read 5,952 rows of data from parquet file 2022010101.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.084 | religious=0.084 | inappropriate=0.050 | video_games=0.034 | misc_unwanted=0.050 | non_english=0.067 | total unwanted=0.370
# Kept 1,389 tweets after filtering raw data with masks
# Kept 1,260 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:09.684 (0.420 seconds).
# Saving to parquet file filtered__2022010101.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 21/225 (2022010102.parquet.gzip)
# Starting time = 2022-08-28 18:14:09.701...
# Read 5,651 rows of data from parquet file 2022010102.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.035 | religious=0.159 | inappropriate=0.088 | video_games=0.000 | misc_unwanted=0.018 | non_english=0.000 | total unwanted=0.301
# Kept 1,474 tweets after filtering raw data with masks
# Kept 1,371 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:10.116 (0.415 seconds).
# Saving to parquet file filtered__2022010102.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 22/225 (2022010103.parquet.gzip)
# Starting time = 2022-08-28 18:14:10.132...
# Read 5,617 rows of data from parquet file 2022010103.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.036 | religious=0.107 | inappropriate=0.018 | video_games=0.018 | misc_unwanted=0.053 | non_english=0.125 | total unwanted=0.356
# Kept 1,176 tweets after filtering raw data with masks
# Kept 1,082 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:10.485 (0.352 seconds).
# Saving to parquet file filtered__2022010103.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 23/225 (2022010104.parquet.gzip)
# Starting time = 2022-08-28 18:14:10.500...
# Read 5,709 rows of data from parquet file 2022010104.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.490 | religious=0.193 | inappropriate=0.018 | video_games=0.018 | misc_unwanted=0.070 | non_english=0.088 | total unwanted=0.876
# Kept 1,245 tweets after filtering raw data with masks
# Kept 1,184 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:10.894 (0.394 seconds).
# Saving to parquet file filtered__2022010104.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 24/225 (2022010105.parquet.gzip)
# Starting time = 2022-08-28 18:14:10.910...
# Read 5,763 rows of data from parquet file 2022010105.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.729 | religious=0.087 | inappropriate=0.052 | video_games=0.000 | misc_unwanted=0.087 | non_english=0.104 | total unwanted=1.058
# Kept 1,342 tweets after filtering raw data with masks
# Kept 1,055 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:11.253 (0.343 seconds).
# Saving to parquet file filtered__2022010105.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 25/225 (2022010106.parquet.gzip)
# Starting time = 2022-08-28 18:14:11.267...
# Read 4,697 rows of data from parquet file 2022010106.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.852 | religious=0.213 | inappropriate=0.043 | video_games=0.021 | misc_unwanted=0.000 | non_english=0.043 | total unwanted=1.171
# Kept 929 tweets after filtering raw data with masks
# Kept 811 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:11.559 (0.291 seconds).
# Saving to parquet file filtered__2022010106.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 26/225 (2022010107.parquet.gzip)
# Starting time = 2022-08-28 18:14:11.572...
# Read 4,533 rows of data from parquet file 2022010107.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=3.552 | religious=0.132 | inappropriate=0.022 | video_games=0.022 | misc_unwanted=0.110 | non_english=0.022 | total unwanted=3.861
# Kept 841 tweets after filtering raw data with masks
# Kept 743 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:11.855 (0.283 seconds).
# Saving to parquet file filtered__2022010107.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 27/225 (2022010108.parquet.gzip)
# Starting time = 2022-08-28 18:14:11.867...
# Read 4,854 rows of data from parquet file 2022010108.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=3.543 | religious=0.206 | inappropriate=0.103 | video_games=0.000 | misc_unwanted=0.062 | non_english=0.041 | total unwanted=3.956
# Kept 809 tweets after filtering raw data with masks
# Kept 716 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:12.159 (0.292 seconds).
# Saving to parquet file filtered__2022010108.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 28/225 (2022010109.parquet.gzip)
# Starting time = 2022-08-28 18:14:12.171...
# Read 4,526 rows of data from parquet file 2022010109.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=3.182 | religious=0.243 | inappropriate=0.044 | video_games=0.110 | misc_unwanted=0.022 | non_english=0.000 | total unwanted=3.601
# Kept 656 tweets after filtering raw data with masks
# Kept 618 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:12.445 (0.274 seconds).
# Saving to parquet file filtered__2022010109.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 29/225 (2022010110.parquet.gzip)
# Starting time = 2022-08-28 18:14:12.456...
# Read 6,509 rows of data from parquet file 2022010110.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.874 | religious=0.031 | inappropriate=0.015 | video_games=0.046 | misc_unwanted=0.000 | non_english=0.031 | total unwanted=1.997
# Kept 616 tweets after filtering raw data with masks
# Kept 577 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:12.883 (0.427 seconds).
# Saving to parquet file filtered__2022010110.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 30/225 (2022010111.parquet.gzip)
# Starting time = 2022-08-28 18:14:12.896...
# Read 3,713 rows of data from parquet file 2022010111.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=3.555 | religious=0.081 | inappropriate=0.054 | video_games=0.027 | misc_unwanted=0.000 | non_english=0.000 | total unwanted=3.717
# Kept 649 tweets after filtering raw data with masks
# Kept 607 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:13.180 (0.284 seconds).
# Saving to parquet file filtered__2022010111.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 31/225 (2022010112.parquet.gzip)
# Starting time = 2022-08-28 18:14:13.192...
# Read 4,416 rows of data from parquet file 2022010112.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=2.649 | religious=0.159 | inappropriate=0.000 | video_games=0.000 | misc_unwanted=0.045 | non_english=0.045 | total unwanted=2.899
# Kept 648 tweets after filtering raw data with masks
# Kept 600 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:13.480 (0.288 seconds).
# Saving to parquet file filtered__2022010112.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 32/225 (2022010113.parquet.gzip)
# Starting time = 2022-08-28 18:14:13.491...
# Read 5,694 rows of data from parquet file 2022010113.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.036 | religious=0.158 | inappropriate=0.070 | video_games=0.053 | misc_unwanted=0.018 | non_english=0.140 | total unwanted=1.475
# Kept 746 tweets after filtering raw data with masks
# Kept 689 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:13.854 (0.363 seconds).
# Saving to parquet file filtered__2022010113.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 33/225 (2022010114.parquet.gzip)
# Starting time = 2022-08-28 18:14:13.866...
# Read 5,696 rows of data from parquet file 2022010114.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.984 | religious=0.140 | inappropriate=0.035 | video_games=0.000 | misc_unwanted=0.070 | non_english=0.105 | total unwanted=2.335
# Kept 753 tweets after filtering raw data with masks
# Kept 704 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:14.233 (0.366 seconds).
# Saving to parquet file filtered__2022010114.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 34/225 (2022010115.parquet.gzip)
# Starting time = 2022-08-28 18:14:14.248...
# Read 6,375 rows of data from parquet file 2022010115.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.616 | religious=0.141 | inappropriate=0.016 | video_games=0.000 | misc_unwanted=0.078 | non_english=0.078 | total unwanted=1.929
# Kept 884 tweets after filtering raw data with masks
# Kept 804 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:14.653 (0.405 seconds).
# Saving to parquet file filtered__2022010115.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 35/225 (2022010116.parquet.gzip)
# Starting time = 2022-08-28 18:14:14.666...
# Read 5,773 rows of data from parquet file 2022010116.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.975 | religious=0.104 | inappropriate=0.052 | video_games=0.069 | misc_unwanted=0.052 | non_english=0.087 | total unwanted=2.338
# Kept 806 tweets after filtering raw data with masks
# Kept 711 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:15.118 (0.452 seconds).
# Saving to parquet file filtered__2022010116.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 36/225 (2022010117.parquet.gzip)
# Starting time = 2022-08-28 18:14:15.131...
# Read 6,052 rows of data from parquet file 2022010117.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.711 | religious=0.182 | inappropriate=0.017 | video_games=0.050 | misc_unwanted=0.050 | non_english=0.033 | total unwanted=1.041
# Kept 850 tweets after filtering raw data with masks
# Kept 790 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:15.711 (0.581 seconds).
# Saving to parquet file filtered__2022010117.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 37/225 (2022010118.parquet.gzip)
# Starting time = 2022-08-28 18:14:15.733...
# Read 5,417 rows of data from parquet file 2022010118.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.720 | religious=0.258 | inappropriate=0.258 | video_games=0.037 | misc_unwanted=0.111 | non_english=0.018 | total unwanted=1.403
# Kept 878 tweets after filtering raw data with masks
# Kept 807 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:16.208 (0.475 seconds).
# Saving to parquet file filtered__2022010118.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 38/225 (2022010119.parquet.gzip)
# Starting time = 2022-08-28 18:14:16.221...
# Read 4,965 rows of data from parquet file 2022010119.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.765 | religious=0.423 | inappropriate=0.020 | video_games=0.040 | misc_unwanted=0.040 | non_english=0.020 | total unwanted=1.309
# Kept 708 tweets after filtering raw data with masks
# Kept 627 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:16.566 (0.344 seconds).
# Saving to parquet file filtered__2022010119.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 39/225 (2022010120.parquet.gzip)
# Starting time = 2022-08-28 18:14:16.577...
# Read 4,524 rows of data from parquet file 2022010120.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.752 | religious=0.199 | inappropriate=0.155 | video_games=0.066 | misc_unwanted=0.066 | non_english=0.066 | total unwanted=1.304
# Kept 687 tweets after filtering raw data with masks
# Kept 639 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:16.894 (0.317 seconds).
# Saving to parquet file filtered__2022010120.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 40/225 (2022010121.parquet.gzip)
# Starting time = 2022-08-28 18:14:16.906...
# Read 4,284 rows of data from parquet file 2022010121.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.607 | religious=0.350 | inappropriate=0.093 | video_games=0.093 | misc_unwanted=0.093 | non_english=0.000 | total unwanted=1.237
# Kept 646 tweets after filtering raw data with masks
# Kept 594 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:17.206 (0.300 seconds).
# Saving to parquet file filtered__2022010121.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 41/225 (2022010122.parquet.gzip)
# Starting time = 2022-08-28 18:14:17.217...
# Read 3,950 rows of data from parquet file 2022010122.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.127 | religious=0.354 | inappropriate=0.051 | video_games=0.076 | misc_unwanted=0.000 | non_english=0.076 | total unwanted=0.684
# Kept 598 tweets after filtering raw data with masks
# Kept 529 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:17.489 (0.272 seconds).
# Saving to parquet file filtered__2022010122.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 42/225 (2022010123.parquet.gzip)
# Starting time = 2022-08-28 18:14:17.501...
# Read 3,954 rows of data from parquet file 2022010123.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.177 | religious=0.228 | inappropriate=0.000 | video_games=0.076 | misc_unwanted=0.101 | non_english=0.177 | total unwanted=0.759
# Kept 548 tweets after filtering raw data with masks
# Kept 508 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:17.853 (0.353 seconds).
# Saving to parquet file filtered__2022010123.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 43/225 (2022010200.parquet.gzip)
# Starting time = 2022-08-28 18:14:17.866...
# Read 3,717 rows of data from parquet file 2022010200.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.296 | religious=0.538 | inappropriate=0.000 | video_games=0.081 | misc_unwanted=0.054 | non_english=0.081 | total unwanted=1.049
# Kept 432 tweets after filtering raw data with masks
# Kept 388 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:18.205 (0.338 seconds).
# Saving to parquet file filtered__2022010200.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 44/225 (2022010201.parquet.gzip)
# Starting time = 2022-08-28 18:14:18.218...
# Read 3,421 rows of data from parquet file 2022010201.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.351 | religious=0.292 | inappropriate=0.029 | video_games=0.117 | misc_unwanted=0.000 | non_english=0.438 | total unwanted=1.228
# Kept 452 tweets after filtering raw data with masks
# Kept 423 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:18.513 (0.296 seconds).
# Saving to parquet file filtered__2022010201.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 45/225 (2022010202.parquet.gzip)
# Starting time = 2022-08-28 18:14:18.524...
# Read 3,603 rows of data from parquet file 2022010202.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.222 | religious=0.583 | inappropriate=0.000 | video_games=0.056 | misc_unwanted=0.056 | non_english=0.250 | total unwanted=1.166
# Kept 437 tweets after filtering raw data with masks
# Kept 352 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:18.757 (0.233 seconds).
# Saving to parquet file filtered__2022010202.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 46/225 (2022010203.parquet.gzip)
# Starting time = 2022-08-28 18:14:18.766...
# Read 3,788 rows of data from parquet file 2022010203.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.264 | religious=0.132 | inappropriate=0.053 | video_games=0.000 | misc_unwanted=0.106 | non_english=0.185 | total unwanted=0.739
# Kept 492 tweets after filtering raw data with masks
# Kept 438 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:19.014 (0.248 seconds).
# Saving to parquet file filtered__2022010203.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 47/225 (2022010204.parquet.gzip)
# Starting time = 2022-08-28 18:14:19.025...
# Read 4,021 rows of data from parquet file 2022010204.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.119 | religious=0.224 | inappropriate=0.075 | video_games=0.075 | misc_unwanted=0.025 | non_english=0.075 | total unwanted=1.592
# Kept 475 tweets after filtering raw data with masks
# Kept 433 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:19.281 (0.256 seconds).
# Saving to parquet file filtered__2022010204.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 48/225 (2022010205.parquet.gzip)
# Starting time = 2022-08-28 18:14:19.292...
# Read 4,257 rows of data from parquet file 2022010205.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.211 | religious=0.094 | inappropriate=0.094 | video_games=0.094 | misc_unwanted=0.023 | non_english=0.070 | total unwanted=0.587
# Kept 438 tweets after filtering raw data with masks
# Kept 399 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:19.553 (0.262 seconds).
# Saving to parquet file filtered__2022010205.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 49/225 (2022010206.parquet.gzip)
# Starting time = 2022-08-28 18:14:19.563...
# Read 3,300 rows of data from parquet file 2022010206.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.303 | religious=0.273 | inappropriate=0.121 | video_games=0.091 | misc_unwanted=0.091 | non_english=0.333 | total unwanted=1.212
# Kept 307 tweets after filtering raw data with masks
# Kept 271 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:19.780 (0.217 seconds).
# Saving to parquet file filtered__2022010206.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 50/225 (2022010207.parquet.gzip)
# Starting time = 2022-08-28 18:14:19.789...
# Read 3,235 rows of data from parquet file 2022010207.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.526 | religious=0.185 | inappropriate=0.124 | video_games=0.062 | misc_unwanted=0.062 | non_english=0.433 | total unwanted=1.391
# Kept 356 tweets after filtering raw data with masks
# Kept 322 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:20.008 (0.218 seconds).
# Saving to parquet file filtered__2022010207.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 51/225 (2022010208.parquet.gzip)
# Starting time = 2022-08-28 18:14:20.017...
# Read 3,414 rows of data from parquet file 2022010208.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.410 | religious=0.117 | inappropriate=0.205 | video_games=0.000 | misc_unwanted=0.146 | non_english=0.439 | total unwanted=1.318
# Kept 404 tweets after filtering raw data with masks
# Kept 351 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:20.290 (0.273 seconds).
# Saving to parquet file filtered__2022010208.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 52/225 (2022010209.parquet.gzip)
# Starting time = 2022-08-28 18:14:20.302...
# Read 3,632 rows of data from parquet file 2022010209.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.936 | religious=0.275 | inappropriate=0.330 | video_games=0.000 | misc_unwanted=0.028 | non_english=0.330 | total unwanted=1.900
# Kept 411 tweets after filtering raw data with masks
# Kept 346 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:20.544 (0.242 seconds).
# Saving to parquet file filtered__2022010209.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 53/225 (2022010210.parquet.gzip)
# Starting time = 2022-08-28 18:14:20.554...
# Read 3,790 rows of data from parquet file 2022010210.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.528 | religious=0.290 | inappropriate=0.185 | video_games=0.079 | misc_unwanted=0.132 | non_english=0.211 | total unwanted=1.425
# Kept 421 tweets after filtering raw data with masks
# Kept 353 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:20.795 (0.241 seconds).
# Saving to parquet file filtered__2022010210.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 54/225 (2022010211.parquet.gzip)
# Starting time = 2022-08-28 18:14:20.806...
# Read 4,405 rows of data from parquet file 2022010211.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.681 | religious=0.114 | inappropriate=0.136 | video_games=0.023 | misc_unwanted=0.114 | non_english=0.000 | total unwanted=1.067
# Kept 424 tweets after filtering raw data with masks
# Kept 363 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:21.060 (0.254 seconds).
# Saving to parquet file filtered__2022010211.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 55/225 (2022010212.parquet.gzip)
# Starting time = 2022-08-28 18:14:21.070...
# Read 4,443 rows of data from parquet file 2022010212.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.913 | religious=0.338 | inappropriate=0.068 | video_games=0.000 | misc_unwanted=0.023 | non_english=0.158 | total unwanted=2.498
# Kept 453 tweets after filtering raw data with masks
# Kept 383 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:21.344 (0.274 seconds).
# Saving to parquet file filtered__2022010212.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 56/225 (2022010213.parquet.gzip)
# Starting time = 2022-08-28 18:14:21.354...
# Read 4,558 rows of data from parquet file 2022010213.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=2.567 | religious=0.241 | inappropriate=0.154 | video_games=0.088 | misc_unwanted=0.044 | non_english=0.132 | total unwanted=3.225
# Kept 528 tweets after filtering raw data with masks
# Kept 450 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:21.646 (0.292 seconds).
# Saving to parquet file filtered__2022010213.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 57/225 (2022010214.parquet.gzip)
# Starting time = 2022-08-28 18:14:21.656...
# Read 5,617 rows of data from parquet file 2022010214.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.694 | religious=0.160 | inappropriate=0.214 | video_games=0.000 | misc_unwanted=0.071 | non_english=1.584 | total unwanted=2.724
# Kept 559 tweets after filtering raw data with masks
# Kept 474 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:22.202 (0.546 seconds).
# Saving to parquet file filtered__2022010214.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 58/225 (2022010215.parquet.gzip)
# Starting time = 2022-08-28 18:14:22.214...
# Read 6,330 rows of data from parquet file 2022010215.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=2.070 | religious=0.126 | inappropriate=0.079 | video_games=0.016 | misc_unwanted=0.047 | non_english=1.801 | total unwanted=4.139
# Kept 723 tweets after filtering raw data with masks
# Kept 658 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:22.601 (0.387 seconds).
# Saving to parquet file filtered__2022010215.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 59/225 (2022010216.parquet.gzip)
# Starting time = 2022-08-28 18:14:22.615...
# Read 6,338 rows of data from parquet file 2022010216.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.515 | religious=0.221 | inappropriate=0.110 | video_games=0.426 | misc_unwanted=0.047 | non_english=1.199 | total unwanted=3.518
# Kept 760 tweets after filtering raw data with masks
# Kept 689 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:23.027 (0.412 seconds).
# Saving to parquet file filtered__2022010216.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 60/225 (2022010217.parquet.gzip)
# Starting time = 2022-08-28 18:14:23.042...
# Read 5,926 rows of data from parquet file 2022010217.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.232 | religious=0.489 | inappropriate=0.118 | video_games=0.371 | misc_unwanted=0.084 | non_english=0.742 | total unwanted=3.037
# Kept 680 tweets after filtering raw data with masks
# Kept 627 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:23.429 (0.387 seconds).
# Saving to parquet file filtered__2022010217.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 61/225 (2022010218.parquet.gzip)
# Starting time = 2022-08-28 18:14:23.440...
# Read 5,132 rows of data from parquet file 2022010218.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=2.143 | religious=0.487 | inappropriate=0.078 | video_games=0.312 | misc_unwanted=0.117 | non_english=0.624 | total unwanted=3.761
# Kept 619 tweets after filtering raw data with masks
# Kept 572 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:23.770 (0.330 seconds).
# Saving to parquet file filtered__2022010218.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 62/225 (2022010219.parquet.gzip)
# Starting time = 2022-08-28 18:14:23.782...
# Read 5,347 rows of data from parquet file 2022010219.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=2.693 | religious=0.318 | inappropriate=0.075 | video_games=0.131 | misc_unwanted=0.112 | non_english=0.580 | total unwanted=3.909
# Kept 607 tweets after filtering raw data with masks
# Kept 554 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:24.125 (0.343 seconds).
# Saving to parquet file filtered__2022010219.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 63/225 (2022010220.parquet.gzip)
# Starting time = 2022-08-28 18:14:24.136...
# Read 4,697 rows of data from parquet file 2022010220.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.724 | religious=0.341 | inappropriate=0.043 | video_games=0.192 | misc_unwanted=0.128 | non_english=0.852 | total unwanted=2.278
# Kept 604 tweets after filtering raw data with masks
# Kept 556 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:24.432 (0.296 seconds).
# Saving to parquet file filtered__2022010220.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 64/225 (2022010221.parquet.gzip)
# Starting time = 2022-08-28 18:14:24.443...
# Read 4,571 rows of data from parquet file 2022010221.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.875 | religious=0.525 | inappropriate=0.088 | video_games=0.088 | misc_unwanted=0.022 | non_english=0.459 | total unwanted=2.056
# Kept 790 tweets after filtering raw data with masks
# Kept 717 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:24.843 (0.400 seconds).
# Saving to parquet file filtered__2022010221.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 65/225 (2022010222.parquet.gzip)
# Starting time = 2022-08-28 18:14:24.858...
# Read 4,608 rows of data from parquet file 2022010222.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.130 | religious=0.347 | inappropriate=0.043 | video_games=0.022 | misc_unwanted=0.022 | non_english=0.477 | total unwanted=1.042
# Kept 686 tweets after filtering raw data with masks
# Kept 628 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:25.225 (0.367 seconds).
# Saving to parquet file filtered__2022010222.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 66/225 (2022010223.parquet.gzip)
# Starting time = 2022-08-28 18:14:25.238...
# Read 4,024 rows of data from parquet file 2022010223.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.224 | religious=0.348 | inappropriate=0.025 | video_games=0.174 | misc_unwanted=0.099 | non_english=0.348 | total unwanted=1.218
# Kept 542 tweets after filtering raw data with masks
# Kept 505 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:25.542 (0.304 seconds).
# Saving to parquet file filtered__2022010223.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 67/225 (2022010300.parquet.gzip)
# Starting time = 2022-08-28 18:14:25.552...
# Read 3,737 rows of data from parquet file 2022010300.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.027 | religious=0.187 | inappropriate=0.054 | video_games=0.161 | misc_unwanted=0.000 | non_english=0.562 | total unwanted=0.990
# Kept 580 tweets after filtering raw data with masks
# Kept 524 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:25.809 (0.256 seconds).
# Saving to parquet file filtered__2022010300.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 68/225 (2022010301.parquet.gzip)
# Starting time = 2022-08-28 18:14:25.820...
# Read 3,700 rows of data from parquet file 2022010301.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.486 | religious=0.541 | inappropriate=0.081 | video_games=0.459 | misc_unwanted=0.135 | non_english=0.514 | total unwanted=2.216
# Kept 511 tweets after filtering raw data with masks
# Kept 474 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:14:26.059 (0.239 seconds).
# Saving to parquet file filtered__2022010301.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 69/225 (2022010302.parquet.gzip)
# Starting time = 2022-08-28 18:14:26.070...
# Read 4,181 rows of data from parquet file 2022010302.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# ...
# Starting time = 2022-08-28 18:15:18.115...
# Read 4,521 rows of data from parquet file 2022010905.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.575 | religious=0.310 | inappropriate=0.088 | video_games=0.111 | misc_unwanted=0.155 | non_english=0.066 | total unwanted=1.305
# Kept 1,168 tweets after filtering raw data with masks
# Kept 1,107 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:15:18.415 (0.300 seconds).
# Saving to parquet file filtered__2022010905.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 206/225 (2022010906.parquet.gzip)
# Starting time = 2022-08-28 18:15:18.430...
# Read 3,895 rows of data from parquet file 2022010906.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.411 | religious=0.282 | inappropriate=0.180 | video_games=0.103 | misc_unwanted=0.026 | non_english=0.128 | total unwanted=1.130
# Kept 895 tweets after filtering raw data with masks
# Kept 832 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:15:18.701 (0.271 seconds).
# Saving to parquet file filtered__2022010906.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 207/225 (2022010907.parquet.gzip)
# Starting time = 2022-08-28 18:15:18.714...
# Read 3,829 rows of data from parquet file 2022010907.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.366 | religious=0.313 | inappropriate=0.104 | video_games=0.026 | misc_unwanted=0.183 | non_english=0.340 | total unwanted=1.332
# Kept 849 tweets after filtering raw data with masks
# Kept 764 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:15:18.983 (0.268 seconds).
# Saving to parquet file filtered__2022010907.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 208/225 (2022010908.parquet.gzip)
# Starting time = 2022-08-28 18:15:18.996...
# Read 3,923 rows of data from parquet file 2022010908.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.433 | religious=0.484 | inappropriate=0.076 | video_games=0.051 | misc_unwanted=0.025 | non_english=0.127 | total unwanted=1.198
# Kept 1,038 tweets after filtering raw data with masks
# Kept 919 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:15:19.271 (0.275 seconds).
# Saving to parquet file filtered__2022010908.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 209/225 (2022010909.parquet.gzip)
# Starting time = 2022-08-28 18:15:19.285...
# Read 3,746 rows of data from parquet file 2022010909.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.682 | religious=0.747 | inappropriate=0.107 | video_games=0.000 | misc_unwanted=0.053 | non_english=0.187 | total unwanted=2.776
# Kept 794 tweets after filtering raw data with masks
# Kept 717 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:15:19.685 (0.400 seconds).
# Saving to parquet file filtered__2022010909.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 210/225 (2022010910.parquet.gzip)
# Starting time = 2022-08-28 18:15:19.698...
# Read 3,756 rows of data from parquet file 2022010910.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.985 | religious=0.319 | inappropriate=0.080 | video_games=0.027 | misc_unwanted=0.133 | non_english=0.080 | total unwanted=1.624
# Kept 840 tweets after filtering raw data with masks
# Kept 782 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:15:19.966 (0.268 seconds).
# Saving to parquet file filtered__2022010910.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 211/225 (2022010911.parquet.gzip)
# Starting time = 2022-08-28 18:15:19.979...
# Read 3,643 rows of data from parquet file 2022010911.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.180 | religious=1.016 | inappropriate=0.027 | video_games=0.027 | misc_unwanted=0.055 | non_english=0.055 | total unwanted=2.361
# Kept 794 tweets after filtering raw data with masks
# Kept 707 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:15:20.241 (0.262 seconds).
# Saving to parquet file filtered__2022010911.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 212/225 (2022010912.parquet.gzip)
# Starting time = 2022-08-28 18:15:20.253...
# Read 4,253 rows of data from parquet file 2022010912.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=1.082 | religious=0.376 | inappropriate=0.165 | video_games=0.024 | misc_unwanted=0.094 | non_english=0.047 | total unwanted=1.787
# Kept 1,049 tweets after filtering raw data with masks
# Kept 784 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:15:20.539 (0.286 seconds).
# Saving to parquet file filtered__2022010912.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 213/225 (2022010913.parquet.gzip)
# Starting time = 2022-08-28 18:15:20.553...
# Read 5,671 rows of data from parquet file 2022010913.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.670 | religious=0.141 | inappropriate=0.071 | video_games=0.035 | misc_unwanted=0.123 | non_english=0.882 | total unwanted=1.922
# Kept 1,346 tweets after filtering raw data with masks
# Kept 960 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:15:20.914 (0.361 seconds).
# Saving to parquet file filtered__2022010913.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 214/225 (2022010914.parquet.gzip)
# Starting time = 2022-08-28 18:15:20.928...
# Read 4,778 rows of data from parquet file 2022010914.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.481 | religious=0.377 | inappropriate=0.105 | video_games=0.042 | misc_unwanted=0.063 | non_english=0.251 | total unwanted=1.319
# Kept 1,230 tweets after filtering raw data with masks
# Kept 948 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:15:21.255 (0.327 seconds).
# Saving to parquet file filtered__2022010914.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 215/225 (2022010915.parquet.gzip)
# Starting time = 2022-08-28 18:15:21.269...
# Read 5,586 rows of data from parquet file 2022010915.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.591 | religious=0.698 | inappropriate=0.072 | video_games=0.000 | misc_unwanted=0.233 | non_english=0.072 | total unwanted=1.665
# Kept 1,382 tweets after filtering raw data with masks
# Kept 1,163 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:15:21.724 (0.455 seconds).
# Saving to parquet file filtered__2022010915.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 216/225 (2022010916.parquet.gzip)
# Starting time = 2022-08-28 18:15:21.742...
# Read 5,450 rows of data from parquet file 2022010916.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.752 | religious=1.009 | inappropriate=0.055 | video_games=0.055 | misc_unwanted=0.239 | non_english=0.165 | total unwanted=2.275
# Kept 1,180 tweets after filtering raw data with masks
# Kept 971 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:15:22.131 (0.389 seconds).
# Saving to parquet file filtered__2022010916.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 217/225 (2022010917.parquet.gzip)
# Starting time = 2022-08-28 18:15:22.146...
# Read 5,886 rows of data from parquet file 2022010917.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.425 | religious=2.446 | inappropriate=0.119 | video_games=0.017 | misc_unwanted=0.170 | non_english=0.034 | total unwanted=3.211
# Kept 1,320 tweets after filtering raw data with masks
# Kept 1,097 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:15:22.563 (0.417 seconds).
# Saving to parquet file filtered__2022010917.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 218/225 (2022010918.parquet.gzip)
# Starting time = 2022-08-28 18:15:22.579...
# Read 5,472 rows of data from parquet file 2022010918.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.859 | religious=2.595 | inappropriate=0.055 | video_games=0.018 | misc_unwanted=0.091 | non_english=0.091 | total unwanted=3.710
# Kept 1,211 tweets after filtering raw data with masks
# Kept 1,005 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:15:22.996 (0.418 seconds).
# Saving to parquet file filtered__2022010918.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 219/225 (2022010919.parquet.gzip)
# Starting time = 2022-08-28 18:15:23.012...
# Read 5,262 rows of data from parquet file 2022010919.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.665 | religious=2.281 | inappropriate=0.076 | video_games=0.057 | misc_unwanted=0.000 | non_english=0.000 | total unwanted=3.079
# Kept 1,290 tweets after filtering raw data with masks
# Kept 1,130 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:15:23.426 (0.414 seconds).
# Saving to parquet file filtered__2022010919.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 220/225 (2022010920.parquet.gzip)
# Starting time = 2022-08-28 18:15:23.442...
# Read 5,873 rows of data from parquet file 2022010920.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.545 | religious=1.635 | inappropriate=0.085 | video_games=0.068 | misc_unwanted=0.102 | non_english=0.000 | total unwanted=2.435
# Kept 1,028 tweets after filtering raw data with masks
# Kept 884 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:15:23.883 (0.441 seconds).
# Saving to parquet file filtered__2022010920.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 221/225 (2022010921.parquet.gzip)
# Starting time = 2022-08-28 18:15:23.899...
# Read 5,702 rows of data from parquet file 2022010921.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.456 | religious=1.491 | inappropriate=0.035 | video_games=0.035 | misc_unwanted=0.210 | non_english=0.018 | total unwanted=2.245
# Kept 1,025 tweets after filtering raw data with masks
# Kept 878 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:15:24.294 (0.395 seconds).
# Saving to parquet file filtered__2022010921.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 222/225 (2022010922.parquet.gzip)
# Starting time = 2022-08-28 18:15:24.308...
# Read 5,471 rows of data from parquet file 2022010922.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.512 | religious=1.005 | inappropriate=0.018 | video_games=0.073 | misc_unwanted=0.110 | non_english=0.000 | total unwanted=1.718
# Kept 827 tweets after filtering raw data with masks
# Kept 675 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:15:24.664 (0.356 seconds).
# Saving to parquet file filtered__2022010922.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 223/225 (2022010923.parquet.gzip)
# Starting time = 2022-08-28 18:15:24.677...
# Read 6,158 rows of data from parquet file 2022010923.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.698 | religious=0.227 | inappropriate=0.016 | video_games=0.032 | misc_unwanted=0.016 | non_english=0.032 | total unwanted=1.023
# Kept 798 tweets after filtering raw data with masks
# Kept 583 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:15:25.048 (0.372 seconds).
# Saving to parquet file filtered__2022010923.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 224/225 (2022011000.parquet.gzip)
# Starting time = 2022-08-28 18:15:25.060...
# Read 5,838 rows of data from parquet file 2022011000.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.188 | religious=0.325 | inappropriate=0.017 | video_games=0.017 | misc_unwanted=0.154 | non_english=0.069 | total unwanted=0.771
# Kept 800 tweets after filtering raw data with masks
# Kept 616 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:15:25.439 (0.379 seconds).
# Saving to parquet file filtered__2022011000.parquet.gzip...
# Done.
#
# Filtering Tweets from combined data file 225/225 (2022011001.parquet.gzip)
# Starting time = 2022-08-28 18:15:25.452...
# Read 3,118 rows of data from parquet file 2022011001.parquet.gzip
# Created masks to filter raw data based on wanted text in tweets
# Created boolean columns to indicate presence of unwanted terms in tweets
# crypto=0.449 | religious=0.257 | inappropriate=0.032 | video_games=0.096 | misc_unwanted=0.064 | non_english=0.160 | total unwanted=1.058
# Kept 409 tweets after filtering raw data with masks
# Kept 324 tweets with more than approximately 10 words per tweet
# Done filtering at 2022-08-28 18:15:25.673 (0.221 seconds).
# Saving to parquet file filtered__2022011001.parquet.gzip...
# Done.
#
# Combined data contained 1,155,499 rows
# Filtered data contains 171,506 rows
#                                    filename  num_rows_combined  \
# 0    data/processed/2022010308.parquet.gzip               3537
# 1    data/processed/2022010310.parquet.gzip               4015
# 2    data/processed/2022010312.parquet.gzip               4314
# 3    data/processed/2022010314.parquet.gzip               4932
# 4    data/processed/2022010315.parquet.gzip               6292
# ..                                      ...                ...
# 220  data/processed/2022010921.parquet.gzip               5702
# 221  data/processed/2022010922.parquet.gzip               5471
# 222  data/processed/2022010923.parquet.gzip               6158
# 223  data/processed/2022011000.parquet.gzip               5838
# 224  data/processed/2022011001.parquet.gzip               3118
#
#      num_rows_filtered
# 0                  455
# 1                  403
# 2                  463
# 3                  622
# 4                 1716
# ..                 ...
# 220                878
# 221                675
# 222                583
# 223                616
# 224                324
#
# [225 rows x 3 columns]
# CPU times: user 1min 21s, sys: 1.5 s, total: 1min 23s
# Wall time: 1min 23s

# %% [markdown]
# **Notes**
# 1. Like the previous notebook, this ETL workflow will also give a single `.parquet` file for every hour of every day on which tweets were streamed. Since the number of hourly tweets for this subject are small enough to fit into memory, it is possible to use `pandas` (in-memory) for filtering the hourly data.

# %% [markdown]
# ## Compress to `.zip` and Upload to S3

# %% [markdown]
# All `.parquet` files are now
# - combined into a single `.zip` file with a `filtered__` prefix in the filename, which is then
#   - uploaded to the `datasets/twitter/kinesis-demo/processed` prefix in the S3 bucket
#   - deleted locally
# - deleted locally

# %%
# %%time
if upload_to_s3:
    # zip all processed data files, upload to S3, delete local files
    # create zip of all .parquet.gzip processed data files
    curr_dir = os.getcwd()
    create_zip_file("filtered__*.parquet.gzip", processed_data_dir, filtered_zip_fname)
    # upload zip file to S3 bucket
    try:
        assert os.getcwd() == curr_dir
        upload_file_to_s3(
            session.region_name,
            processed_data_dir,
            filtered_zip_fname,
            s3_bucket_name,
            f"{path_to_folder[1:-1]}/processed/{filtered_zip_fname}",
        )
        print("\nUploaded filtered zipped file to S3 bucket")
    except AssertionError as e:
        print(
            f"\n{str(e)}: Incorrect working directory. "
            "Did not upload filtered zipped file to S3 bucket."
        )

if cleanup_local_files:
    # 1. delete local combined parquet files
    list(
        map(
            os.remove,
            glob(f"{processed_data_dir}/*.parquet.gzip"),
        )
    )
    print("Deleted local .parquet.gzip files with combined data.")

    # 2. delete locally exported processed parquet files
    list(
        map(
            os.remove,
            glob(f"{processed_data_dir}/filtered__*.parquet.gzip"),
        )
    )
    print("Deleted local .parquet.gzip files with filtered data.")

    # 3. delete local processed zip file
    os.remove(os.path.join(processed_data_dir, proc_zip_fname))
    print("Deleted local .zip file created from all combined data files.")

    # 4. delete local filtered zip file
    os.remove(os.path.join(processed_data_dir, filtered_zip_fname))
    print("Deleted local .zip file created from all filtered data files.")

# %% [markdown]
# ---

# %% [markdown]
# <span style="float:left;">
#     <a href="./3_combine_data.ipynb"><< 3 - Combine Hourly Data</a>
# </span>
#
# <span style="float:right;">
#     <a href="./5_process_data.ipynb">5 - Big Data Processing >></a>
# </span>
