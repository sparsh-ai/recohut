# %% [markdown]
# # Combine raw data files, per hour, into CSVs

# %%
# %load_ext lab_black
# %load_ext autoreload
# %autoreload 2

# %%
import os
from datetime import datetime
from zoneinfo import ZoneInfo

import boto3
import pandas as pd
from dotenv import find_dotenv, load_dotenv

# %%
# %aimport src.data.combine_data
import src.data.combine_data as cdh

# %%
load_dotenv(find_dotenv())
# Out:
# True

# %%
s3_bucket_name = os.getenv("AWS_S3_BUCKET_NAME")

# %% [markdown]
# ## About

# %% [markdown]
# Here, raw tweets (twitter data) that was streamed per hour (using `twitter_s3.py`) will be combined (using `pandas.concat()`) into a single CSV file and stored in a sub-folder, in the same S3 bucket as the raw twitter data, at the path `<s3-bucket-name>/datasets/twitter/kinesis-demo/csvs`. The formatting of the following datetime columns will be changed to the `yyyy-mm-dd HH:MM::SS` format (although this conversion should have been done in the twitter streaming script)
# - `created_at`
#   - datetime at which the tweet was posted on Twitter platform
# - `user_joined`
#   - datetime at which user joined Twitter platform
#
# Also
# - a subset of the tweet metadata will be selected for this version of the analysis. This subset (columns) will be exported to each CSV file
# - hashtags and usernames were extracted from the tweet text and stored in separate fields in the raw data exported to S3, and they will not be used in the current analysis (though they can be combined with the text in future iterations of this project)

# %% [markdown]
# ## User Inputs

# %%
# S3
path_to_folder = "/datasets/twitter/kinesis-demo/"
sub_folders_list = ["csvs", "predictions", "athena-queries-outputs", "models"]

# List of headers for all streamed twitter attributes
headers = [
    "id",
    "geo",
    "coordinates",
    "place",
    "contributors",
    "is_quote_status",
    "quote_count",
    "reply_count",
    "retweet_count",
    "favorite_count",
    "favorited",
    "retweeted",
    "created_at",
    "source",
    "in_reply_to_user_id",
    "in_reply_to_screen_name",
    "source_text",
    "place_id",
    "place_url",
    "place_place_type",
    "place_name",
    "place_full_name",
    "place_country_code",
    "place_country",
    "place_bounding_box_type",
    "place_bounding_box_coordinates",
    "place_attributes",
    "coords_type",
    "coords_lon",
    "coords_lat",
    "geo_type",
    "geo_lon",
    "geo_lat",
    "user_name",
    "user_screen_name",
    "user_followers",
    "user_friends",
    "user_listed",
    "user_favourites",
    "user_statuses",
    "user_protected",
    "user_verified",
    "user_contributors_enabled",
    "user_joined",
    "user_location",
    "retweeted_tweet",
    "tweet_text_urls",
    "tweet_text_hashtags",
    "tweet_text_usernames",
    "num_urls_in_tweet_text",
    "num_users_in_tweet_text",
    "num_hashtags_in_tweet_text",
    "text",
]

# List of twitter attributes to use in this version of the analysis
cols_to_use = [
    "id",
    "contributors",
    "created_at",
    "source",
    "in_reply_to_screen_name",
    "source_text",
    "place_id",
    "place_url",
    "place_place_type",
    "place_country_code",
    "place_country",
    "user_name",
    "user_screen_name",
    "user_followers",
    "user_friends",
    "user_listed",
    "user_favourites",
    "user_statuses",
    "user_protected",
    "user_verified",
    "user_joined",
    "user_location",
    "retweeted_tweet",
    "text",
]

# List of partial strings to use to filter out unwanted tweets
# - tweets containing sensitive tweet texts that were found retrospectively
#   and should be excluded from the CSV files
unwanted_partial_strings_list = [
    # specific to crypto mining
    "crypto",
    "token",
    "koistarter",
    "daostarter",
    "decentralized",
    "services",
    "pancakeswap",
    "eraxnft",
    "browsing",
    "kommunitas",
    "hosting",
    "internet",
    "exipofficial",
    "servers",
    "wallet",
    "liquidity",
    "rewards",
    "floki",
    "10000000000000linkstelegram",
    "dogecoin",
    "czbinance",
    "watch",
    "binance",
    "dogelonmars",
    "cryptocurrency",
    "hbomax",
    "money",
    "danheld",
    "cybersecurity",
    # others
    "prostitution",
    "nairobi",
    "musembe",
    "volcano detected",
    "block-2",
    "mo-greene",
    "running scared2012",
    "running scared 2012",
    "massacres",
    "eric ephriam chavez",
    "drugs",
    "tanzanite",
    "vvsorigin",
    "gemstonecarat",
    "bin laden",
    "saddam",
    "webuye",
    "bungoma",
    "perished",
    "popescu",
    "whore",
    "nasty",
    "ethereum",
    "pay someone",
    "gamejoin",
    "nft",
    "breeding",
    "seungkwan",
    "woozi",
    "hoshi",
    "bitcrush",
    "arcade",
    "homeworkpay",
    "homework",
    "photocards",
    "deta",
    "marketing",
    "dreamcast",
    "sega",
    "xbox",
    "wii",
    "ps4",
    "kasama",
    "nung",
    "lahat",
    "jinsoul",
    "brunisoul",
    "loona",
    "taas",
    "nung",
    "essay",
    # religious
    "scriptures",
    "methusealah",
    "testament",
    "yahweh",
    "god",
    "mullah",
    "allah",
    "clergy",
    "mercy",
    "morality",
    "muslims,",
    "hindus",
    "buddhist",
    "catholics",
    "christians",
    "atheist",
    # inappropriate
    "nazist",
    "antifa",
    "proud boys",
]

# %%
aws_region = os.getenv("AWS_REGION")

# %% [markdown]
# ## Combine raw data into CSV files

# %% [markdown]
# ### Create sub-folders

# %% [markdown]
# Create the following sub-folders at the same depth as the S3 folder where the Kinesis Firehose exports raw data by year (i.e. in `<bucket-name>/datasets/twitter`)
# - `csvs`
# - `predictions`
# - `athena-queries-outputs`
# - `models`

# %%
# %%time
for sub_folder_name in sub_folders_list:
    cdh.create_folder_in_s3_bucket(aws_region, s3_bucket_name, sub_folder_name)
# Out:
# Found existing folder csvs in specified S3 bucket. Did nothing.
# Found existing folder predictions in specified S3 bucket. Did nothing.
# Found existing folder athena-queries-outputs in specified S3 bucket. Did nothing.
# Found existing folder models in specified S3 bucket. Did nothing.
# CPU times: user 168 ms, sys: 30.7 ms, total: 198 ms
# Wall time: 784 ms

# %% [markdown]
# ### Combine files into single CSV file in `csvs/`

# %% [markdown]
# Get list of all CSV files in `csvs/`

# %% [markdown]
# ```python
# # src/data/combine_data.py
# def get_existing_csv_files_list(
#     s3_bucket_name: str, region: str, prefix: str
# ) -> List[str]:
#     """Get list of files in subfolder in S3 bucket, by filename prefix."""
#     s3_resource = boto3.resource("s3", region_name=region)
#     bucket = s3_resource.Bucket(s3_bucket_name)
#     # Get list of objects containing user-specified prefix in filename
#     files_found_objects_list = list(bucket.objects.filter(Prefix=prefix))
#     # For each object, get dictionary of file attributes under .key attribute
#     # and store these dictionaries in a list
#     files_found_names_list = [w.key for w in files_found_objects_list]
#     return files_found_names_list
# ```

# %%
existing_csv_files_list = cdh.get_existing_csv_files_list(
    s3_bucket_name, aws_region, path_to_folder[1:] + "csvs/tweets_"
)
existing_csv_files_list
# Out:
# ['datasets/twitter/kinesis-demo/csvs/tweets_15_hc2021123017_s20220106193315.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_40_hc2021123118_s20220106193321.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_57_hc2022010416_s20220106195607.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2021123119_s20220106193331.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2021123122_s20220106193423.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010100_s20220106193454.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010104_s20220106193556.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010107_s20220106193641.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010109_s20220106193710.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010112_s20220106193752.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010116_s20220106193852.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010120_s20220106193954.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010123_s20220106194036.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010200_s20220106194051.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010202_s20220106194120.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010204_s20220106194147.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010206_s20220106194215.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010207_s20220106194229.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010209_s20220106194257.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010211_s20220106194325.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010213_s20220106194353.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010218_s20220106194507.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010221_s20220106194551.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010223_s20220106194620.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010301_s20220106194648.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010303_s20220106194716.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010305_s20220106194745.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010307_s20220106194813.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010308_s20220106194827.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010310_s20220106194855.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010311_s20220106194908.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010314_s20220106194952.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010318_s20220106195053.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010321_s20220106195137.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010323_s20220106195207.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010401_s20220106195236.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010404_s20220106195320.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010406_s20220106195347.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010408_s20220106195414.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010409_s20220106195427.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010411_s20220106195454.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010413_s20220106195522.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010417_s20220106195623.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010421_s20220106195724.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010500_s20220106195806.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010501_s20220106195820.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010502_s20220106195834.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010504_s20220106195904.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010507_s20220106195948.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010509_s20220106200016.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010510_s20220106200030.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010512_s20220106200058.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010517_s20220106200218.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010522_s20220106200335.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010601_s20220106200420.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010604_s20220106200503.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010606_s20220106200530.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010608_s20220106200557.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010610_s20220106200626.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010611_s20220106200639.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010614_s20220106200722.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010619_s20220106200848.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010620_s20220106200903.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010621_s20220106200917.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2021123120_s20220106193345.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2021123121_s20220106193409.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2021123123_s20220106193438.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010101_s20220106193510.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010102_s20220106193525.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010103_s20220106193541.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010105_s20220106193611.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010106_s20220106193626.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010108_s20220106193655.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010110_s20220106193723.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010111_s20220106193738.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010113_s20220106193806.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010114_s20220106193821.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010115_s20220106193836.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010117_s20220106193907.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010118_s20220106193923.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010119_s20220106193938.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010121_s20220106194008.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010122_s20220106194022.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010201_s20220106194106.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010203_s20220106194133.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010205_s20220106194201.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010208_s20220106194243.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010210_s20220106194310.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010212_s20220106194339.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010214_s20220106194407.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010215_s20220106194422.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010216_s20220106194437.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010217_s20220106194452.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010219_s20220106194522.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010220_s20220106194537.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010222_s20220106194605.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010300_s20220106194634.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010302_s20220106194702.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010304_s20220106194730.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010306_s20220106194759.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010309_s20220106194840.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010312_s20220106194922.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010313_s20220106194937.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010315_s20220106195006.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010316_s20220106195022.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010317_s20220106195037.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010319_s20220106195107.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010320_s20220106195123.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010322_s20220106195152.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010400_s20220106195221.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010402_s20220106195250.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010403_s20220106195305.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010405_s20220106195333.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010407_s20220106195400.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010410_s20220106195441.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010412_s20220106195508.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010414_s20220106195536.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010415_s20220106195552.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010418_s20220106195640.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010419_s20220106195655.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010420_s20220106195709.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010422_s20220106195738.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010423_s20220106195752.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010503_s20220106195849.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010505_s20220106195918.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010506_s20220106195933.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010508_s20220106200001.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010511_s20220106200044.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010513_s20220106200112.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010514_s20220106200127.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010515_s20220106200143.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010516_s20220106200159.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010518_s20220106200234.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010519_s20220106200250.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010520_s20220106200305.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010521_s20220106200320.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010523_s20220106200351.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010600_s20220106200406.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010602_s20220106200434.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010603_s20220106200449.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010605_s20220106200516.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010607_s20220106200543.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010609_s20220106200612.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010612_s20220106200653.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010613_s20220106200708.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010615_s20220106200736.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010616_s20220106200751.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010617_s20220106200806.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010618_s20220106200833.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010622_s20220106200934.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010623_s20220106200950.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_59_hc2022010700_s20220106201004.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_9_hc2022010701_s20220106201018.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_15_hc2021123017_s20220106193315.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_40_hc2021123118_s20220106193321.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_57_hc2022010416_s20220106195607.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2021123119_s20220106193331.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2021123122_s20220106193423.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010100_s20220106193454.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010104_s20220106193556.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010107_s20220106193641.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010109_s20220106193710.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010112_s20220106193752.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010116_s20220106193852.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010120_s20220106193954.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010123_s20220106194036.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010200_s20220106194051.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010202_s20220106194120.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010204_s20220106194147.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010206_s20220106194215.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010207_s20220106194229.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010209_s20220106194257.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010211_s20220106194325.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010213_s20220106194353.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010218_s20220106194507.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010221_s20220106194551.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010223_s20220106194620.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010301_s20220106194648.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010303_s20220106194716.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010305_s20220106194745.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010307_s20220106194813.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010308_s20220106194827.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010310_s20220106194855.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010311_s20220106194908.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010314_s20220106194952.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010318_s20220106195053.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010321_s20220106195137.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010323_s20220106195207.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010401_s20220106195236.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010404_s20220106195320.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010406_s20220106195347.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010408_s20220106195414.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010409_s20220106195427.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010411_s20220106195454.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010413_s20220106195522.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010417_s20220106195623.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010421_s20220106195724.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010500_s20220106195806.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010501_s20220106195820.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010502_s20220106195834.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010504_s20220106195904.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010507_s20220106195948.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010509_s20220106200016.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010510_s20220106200030.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010512_s20220106200058.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010517_s20220106200218.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010522_s20220106200335.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010601_s20220106200420.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010604_s20220106200503.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010606_s20220106200530.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010608_s20220106200557.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010610_s20220106200626.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010611_s20220106200639.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010614_s20220106200722.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010619_s20220106200848.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010620_s20220106200903.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_58_hc2022010621_s20220106200917.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2021123120_s20220106193345.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2021123121_s20220106193409.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2021123123_s20220106193438.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010101_s20220106193510.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010102_s20220106193525.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010103_s20220106193541.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010105_s20220106193611.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010106_s20220106193626.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010108_s20220106193655.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010110_s20220106193723.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010111_s20220106193738.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010113_s20220106193806.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010114_s20220106193821.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010115_s20220106193836.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010117_s20220106193907.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010118_s20220106193923.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010119_s20220106193938.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010121_s20220106194008.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010122_s20220106194022.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010201_s20220106194106.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010203_s20220106194133.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010205_s20220106194201.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010208_s20220106194243.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010210_s20220106194310.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010212_s20220106194339.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010214_s20220106194407.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010215_s20220106194422.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010216_s20220106194437.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010217_s20220106194452.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010219_s20220106194522.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010220_s20220106194537.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010222_s20220106194605.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010300_s20220106194634.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010302_s20220106194702.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010304_s20220106194730.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010306_s20220106194759.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010309_s20220106194840.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010312_s20220106194922.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010313_s20220106194937.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010315_s20220106195006.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010316_s20220106195022.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010317_s20220106195037.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010319_s20220106195107.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010320_s20220106195123.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010322_s20220106195152.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010400_s20220106195221.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010402_s20220106195250.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010403_s20220106195305.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010405_s20220106195333.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010407_s20220106195400.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010410_s20220106195441.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010412_s20220106195508.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010414_s20220106195536.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010415_s20220106195552.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010418_s20220106195640.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010419_s20220106195655.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010420_s20220106195709.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010422_s20220106195738.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010423_s20220106195752.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010503_s20220106195849.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010505_s20220106195918.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010506_s20220106195933.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010508_s20220106200001.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010511_s20220106200044.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010513_s20220106200112.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010514_s20220106200127.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010515_s20220106200143.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010516_s20220106200159.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010518_s20220106200234.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010519_s20220106200250.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010520_s20220106200305.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010521_s20220106200320.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010523_s20220106200351.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010600_s20220106200406.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010602_s20220106200434.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010603_s20220106200449.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010605_s20220106200516.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010607_s20220106200543.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010609_s20220106200612.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010612_s20220106200653.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010613_s20220106200708.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010615_s20220106200736.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010616_s20220106200751.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010617_s20220106200806.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010618_s20220106200833.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010622_s20220106200934.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010623_s20220106200950.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_59_hc2022010700_s20220106201004.csv',
#  'datasets/twitter/kinesis-demo/csvs/tweets_metadata_9_hc2022010701_s20220106201018.csv']

# %% [markdown]
# Using a custom Python module in `src/data/combine_data.py` (which will be discussed in the next section), combine raw data files, per hour, into single CSV file (using `pandas.concat()`). This module wlill perform the following steps
# - get list of all files exported by AWS Kinesis Fireohse to the S3 bucket during a given hour
# - read in all files in the S3 bucket during a given hour
#   - over multiple hours, this creates a nested list where each inner list is also a nested list corresponding to tweets collected during 60 seconds (since the Kinesis firehose was programmed to dump data to the AWS S3 bucket after each 60 second period)
# - use `pandas.concat()` to create a single `pandas.DataFrame` from the the inner nested list (multiple files each holding data dumped every 60 seconds)
# - vertically concatenate all `pandas.DataFrame`s during a given hour into a single `DataFrame`
# - filter out tweets with sensitive terms that were retrospectively discovered (when examining the results of topic modeling in the next notebook `4_data_processing.ipynb`)
# - export `DataFrame` it to a single CSV file in the `csvs/` sub-folder in the same AWS S3 bucket
#
# which will be repeated for every hour during which the Kinesis Firehose produced data files in the S3 bucket

# %%
# %%time
# Loop over <bucket-name>/datasets/twitter/kinesis-demo
for content in cdh.get_objects_in_one_s3_level(
    s3_bucket_name, path_to_folder[1:], aws_region
).get("CommonPrefixes"):
    # Check if <bucket-name>/datasets/twitter/kinesis-demo/<year> exists
    if cdh.get_objects_in_one_s3_level(s3_bucket_name, content, aws_region).get(
        "Prefix"
    ).split("/", 3)[-1] not in [f"{f}/" for f in sub_folders_list]:
        if cdh.get_objects_in_one_s3_level(
            s3_bucket_name, content, aws_region
        ):
            # Loop over <bucket-name>/datasets/twitter/kinesis-demo/<year>
            for content_year in cdh.get_objects_in_one_s3_level(
                s3_bucket_name, content, aws_region
            ).get("CommonPrefixes"):
                # Loop over <bucket-name>/datasets/twitter/kinesis-demo/<year>/<month>
                for content_month in cdh.get_objects_in_one_s3_level(
                    s3_bucket_name, content_year, aws_region
                ).get("CommonPrefixes"):
                    utc_hour_counter = 0
                    # Loop over <bucket-name>/datasets/twitter/kinesis-demo/<year>/<month>/<day>
                    for content_day in cdh.get_objects_in_one_s3_level(
                        s3_bucket_name, content_month, aws_region
                    ).get("CommonPrefixes"):
                        # Get month and day
                        month, day = [
                            int(component) for component in content_month["Prefix"][:-1].split("/", 5)[-2:]
                        ]
                        # Get masks to filter raw data that will be combined
                        # # December
                        dec_mask = month in [12]
                        # # January, up to 01:00 UTC on the most recent day with streaming data saved to S3
                        curr_day_of_month_utc = int(datetime.now(tz=ZoneInfo("UTC")).strftime("%d"))
                        prev_days_of_month = list(range(1, (curr_day_of_month_utc - 1) + 1))
                        jan_prev_days_mask = month == 1 and day in prev_days_of_month
                        jan_curr_day_mask = month == 1 and day == curr_day_of_month_utc and utc_hour_counter <= 1
                        # Combine raw data into hourly CSVs
                        if dec_mask or jan_prev_days_mask or jan_curr_day_mask:
                            # Save tweets
                            # - data to <bucket-name>/datasets/twitter/kinesis-demo/csvs/tweets_*.csv
                            #   - this will be filtered to remove unwanted terms in the text of the tweet
                            # - metadata to <bucket-name>/datasets/twitter/kinesis-demo/csvs/tweets_metadata_*.csv
                            #   - this will not be filtered
                            cdh.save_data_and_metadata_to_s3_csv(
                                content_day.get("Prefix"),
                                existing_csv_files_list,
                                s3_bucket_name,
                                headers,
                                content_day,
                                path_to_folder[1:],
                                aws_region,
                                cols_to_use,
                                unwanted_partial_strings_list,
                                combine_hashtags_usernames=False,
                                aggregate_metadata=False,
                            )
                            # print(month, day, utc_hour_counter, [curr_day_of_month_utc, utc_hour_counter])
                            utc_hour_counter += 1

# %% [markdown]
# ## Inspect data in the combined CSV files

# %% [markdown]
# ### Get List of CSV files with data

# %%
files_list = [
    f"{s3_bucket_name}/{f}"
    for f in cdh.get_existing_csv_files_list(
        s3_bucket_name, aws_region, path_to_folder[1:] + "csvs/tweets_"
    )
    if "metadata" not in f
]

# %% [markdown]
# **Notes**
# 1. This will produce a list with the following entries
#    ```python
#    ['<s3-bucket-name>/datasets/twitter/kinesis-demo/csvs/tweets_15_hc2021123017_s20220102120517.csv',
#     '<s3-bucket-name>/datasets/twitter/kinesis-demo/csvs/tweets_15_hc2022010217_s20220102121623.csv',
#     '<s3-bucket-name>/datasets/twitter/kinesis-demo/csvs/tweets_40_hc2021123118_s20220102120522.csv',
#     '<s3-bucket-name>/datasets/twitter/kinesis-demo/csvs/tweets_58_hc2021123119_s20220102120532.csv',
#     '<s3-bucket-name>/datasets/twitter/kinesis-demo/csvs/tweets_58_hc2021123122_s20220102120615.csv',
#     '<s3-bucket-name>/datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010100_s20220102120644.csv',
#     '<s3-bucket-name>/datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010104_s20220102120745.csv',
#     '<s3-bucket-name>/datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010107_s20220102120828.csv',
#     '<s3-bucket-name>/datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010109_s20220102120856.csv',
#     '<s3-bucket-name>/datasets/twitter/kinesis-demo/csvs/tweets_58_hc2022010112_s20220102120939.csv',
#     .
#     .
#     .
#     .
#    ```

# %% [markdown]
# ### View slice of the data

# %% [markdown]
# Show the following
# - subset of columns for the first 10 rows (tweets) of data from the combined CSV files
# - number of tweets in every raw file exported from the Firehose stream to each (hourly) folder in the S3 bucket

# %%
cols_to_show = [
    "created_at",
    "user_joined",
    "user_name",
    "user_screen_name",
    "text",
    "file_name",
]

# %%
# %%time
df = pd.concat([pd.read_csv("s3://" + f, lineterminator="\n") for f in files_list[:3]], ignore_index=True)
print(f"Total number of tweets retrieved = {len(df):,}, Number of columns in the data = {df.shape[1]:,}")
with pd.option_context("display.max_colwidth", 2_000):
    display(df[cols_to_show].head(n=10))
with pd.option_context("display.max_colwidth", 2_000):
    display(
        df["file_name"].value_counts()
        .rename("num_tweets")
        .sort_index()
        .reset_index()
        .rename(columns={"index": "file_name"})
    )
list(df)
# Out:
# Total number of tweets retrieved = 11,100, Number of columns in the data = 25
#                   created_at                user_joined  \
# 0  2021-12-30 17:35:53+00:00  2021-11-27 20:38:14+00:00
# 1  2021-12-30 17:35:54+00:00  2018-09-04 17:18:46+00:00
# 2  2021-12-30 17:35:55+00:00  2016-05-25 10:54:46+00:00
# 3  2021-12-30 17:35:55+00:00  2009-02-21 14:48:52+00:00
# 4  2021-12-30 17:35:55+00:00  2008-07-26 17:50:37+00:00
# 5  2021-12-30 17:35:56+00:00  2016-09-12 07:35:14+00:00
# 6  2021-12-30 17:35:56+00:00  2008-12-23 19:34:02+00:00
# 7  2021-12-30 17:35:58+00:00  2009-07-14 05:10:36+00:00
# 8  2021-12-30 17:35:58+00:00  2016-04-03 20:59:45+00:00
# 9  2021-12-30 17:35:59+00:00  2017-11-03 12:41:31+00:00
#
#                                      user_name user_screen_name  \
# 0                         Happy New Years 2022   GuessWho122021
# 1                                TheToysRusKid           JC1of1
# 2                                BCABA Network     BcabaNetwork
# 3  Jude Jackson 💙 Solidarity with #NHS workers         JudeJack
# 4                                   Alan Stern        AlanStern
# 5                                   Nhada Naim        kognomee_
# 6                Themistoclea (Bonnie DeVarco)     Themistoclea
# 7                            Radio Justice 📻🎙⚖    justiceputnam
# 8                              Kwaku Barcelona    o_theophilus1
# 9                                 The Buckshee    BucksheeForum
#
#                                                                                                                                                                                                                                                                                         text  \
# 0                                                                                                                           Space colonists may turn to cannibalism, scientists warn:The first generations to occupy space outposts may be left with few nutrition choices, scholars believe
# 1                                                                                                              1. Beat Street2. Harlem Knights 3. National Lampoons Vacation 4. Bachelor Party 5. Do The right Thing6. How High7. Weird Science 8. Clerks 9. Beverly Hills Cop10. Goodfellas
# 2                                                                                                                                                                                                                                    NASA Plans Coverage of Webb Space Telescope Deployments
# 3                            Exciting times!Back in 1915, Einstein published his theory of General Relativity. 1917 the Bolsheviks led the worlds’ first proletarian revolution. Humanity is about to peer back to the beginning of time, and the world is poised once again for revolution.
# 4      Obviously, since science is a mental mode of nature and Pluto doesn’t have a mind. But having it is the very essence of science and that requires functionally useful concepts like “planet”. Non-functional concepts hurt the progress of science and the public’s insights into it.
# 5                                                                                                                                                                                                                Jupiter is in Penis and Vagina is stationed retrograde. Wear a condom ya’ll
# 6                                                         How 'bout we squeeze in some good news before the year ends? Not only did  deploy its tower assembly, the team also said the telescope's launch was so precise that we should expect the science to continue well beyond 10 years!
# 7                                                                                                                                                                                                                                     NASA: It wasn't a strike, it was just a work slowdown.
# 8    I was being interviewed by Elon Musk. He asked, "where are you from", and I said Portugal. He replied, "so you are a fellow country man of a Pen merchant whose freekick ball broke my rover on Mars. Get out!". Tears ran down my face. Shame on you Pendu for costing me my dream job
# 9                                                                                                                                                                                                                                Webb telescope is captured soaring through space from Earth
#
#                                                                             file_name
# 0  twitter_delivery_stream-1-2021-12-30-17-35-58-b98c4593-2164-445f-9c09-b80d647c80fe
# 1  twitter_delivery_stream-1-2021-12-30-17-35-58-b98c4593-2164-445f-9c09-b80d647c80fe
# 2  twitter_delivery_stream-1-2021-12-30-17-35-58-b98c4593-2164-445f-9c09-b80d647c80fe
# 3  twitter_delivery_stream-1-2021-12-30-17-35-58-b98c4593-2164-445f-9c09-b80d647c80fe
# 4  twitter_delivery_stream-1-2021-12-30-17-35-58-b98c4593-2164-445f-9c09-b80d647c80fe
# 5  twitter_delivery_stream-1-2021-12-30-17-35-58-b98c4593-2164-445f-9c09-b80d647c80fe
# 6  twitter_delivery_stream-1-2021-12-30-17-35-58-b98c4593-2164-445f-9c09-b80d647c80fe
# 7  twitter_delivery_stream-1-2021-12-30-17-35-58-b98c4593-2164-445f-9c09-b80d647c80fe
# 8  twitter_delivery_stream-1-2021-12-30-17-35-58-b98c4593-2164-445f-9c09-b80d647c80fe
# 9  twitter_delivery_stream-1-2021-12-30-17-35-58-b98c4593-2164-445f-9c09-b80d647c80fe
#                                                                               file_name  \
# 0    twitter_delivery_stream-1-2021-12-30-17-35-58-b98c4593-2164-445f-9c09-b80d647c80fe
# 1    twitter_delivery_stream-1-2021-12-30-17-37-00-03050126-c5a3-457a-9141-44c723e9a16e
# 2    twitter_delivery_stream-1-2021-12-30-17-38-01-ee043884-55a1-4696-afe2-ae744d931748
# 3    twitter_delivery_stream-1-2021-12-30-17-39-01-45daac32-de3f-4189-b312-8cd405214fe4
# 4    twitter_delivery_stream-1-2021-12-30-17-40-03-9c7445d1-3438-4c6c-96df-4629d801bbd1
# ..                                                                                  ...
# 107  twitter_delivery_stream-1-2022-01-04-16-55-48-5b2ac7c5-1710-4a50-8886-be31f33778da
# 108  twitter_delivery_stream-1-2022-01-04-16-56-51-7f105f30-4f40-4093-a9e9-c4f0486b9896
# 109  twitter_delivery_stream-1-2022-01-04-16-57-52-98571cc0-a199-43ea-ad2e-bdac6c574c33
# 110  twitter_delivery_stream-1-2022-01-04-16-58-54-be868279-f0eb-4a50-8223-cdb34159aad6
# 111  twitter_delivery_stream-1-2022-01-04-16-59-55-2f0a051d-a681-4d44-b3ed-a97c1a3ab849
#
#      num_tweets
# 0           118
# 1           127
# 2           107
# 3           164
# 4           150
# ..          ...
# 107          77
# 108          89
# 109          88
# 110          99
# 111         134
#
# [112 rows x 2 columns]
# CPU times: user 259 ms, sys: 47.5 ms, total: 307 ms
# Wall time: 1.2 s
# ['id',
#  'contributors',
#  'created_at',
#  'source',
#  'in_reply_to_screen_name',
#  'source_text',
#  'place_id',
#  'place_url',
#  'place_place_type',
#  'place_country_code',
#  'place_country',
#  'user_name',
#  'user_screen_name',
#  'user_followers',
#  'user_friends',
#  'user_listed',
#  'user_favourites',
#  'user_statuses',
#  'user_protected',
#  'user_verified',
#  'user_joined',
#  'user_location',
#  'retweeted_tweet',
#  'text',
#  'file_name']

# %% [markdown]
# Show subset of columns for retweets

# %%
with pd.option_context("display.max_colwidth", 2_000):
    display(df.query("retweeted_tweet == 'yes'")[cols_to_show])
# Out:
#                      created_at                user_joined  \
# 478   2021-12-30 17:39:46+00:00  2014-12-21 22:37:43+00:00
# 780   2021-12-30 17:41:56+00:00  2021-11-07 00:41:45+00:00
# 1516  2021-12-30 17:48:03+00:00  2012-02-11 20:29:25+00:00
# 1631  2021-12-30 17:49:01+00:00  2020-10-24 08:57:41+00:00
# 4828  2021-12-31 18:59:25+00:00  2021-07-17 11:47:11+00:00
# 4879  2021-12-31 19:00:05+00:00  2020-05-07 10:32:01+00:00
# 7896  2022-01-04 16:28:01+00:00  2010-01-24 19:15:10+00:00
# 7966  2022-01-04 16:28:36+00:00  2014-09-09 23:17:37+00:00
# 8030  2022-01-04 16:29:14+00:00  2012-02-23 01:42:23+00:00
# 9048  2022-01-04 16:38:48+00:00  2020-03-08 22:09:46+00:00
#
#                             user_name user_screen_name  \
# 478                              Mae✨    Midnigth_City
# 780         problematiccontentenjoyer   probsaproblem1
# 1516                       pintobean🗝     smdeangelo18
# 1631                           demjin    fuduhhhhhhhhh
# 4828                             josh  an0nym0us_eskeh
# 4879                 HAKOM TimeSeries  HakomTimeSeries
# 7896         Nadeem Ansari FCIM F IDM     nadeemansary
# 7966  Tennessee Wing Civil Air Patrol     TennesseeCAP
# 8030                    Eric V. Scott      ericvscott5
# 9048       📔Lee the Kobold Librarian📔   Kobold_Servant
#
#                                                                                                                                                                          text  \
# 478                                                                                                                                 if you were born while Pluto was a planet
# 780                                                                                                                                 if you were born while Pluto was a planet
# 1516                                                                                                                                if you were born while Pluto was a planet
# 1631                                                                                                                                if you were born while Pluto was a planet
# 4828                                                                                                                                if you were born while Pluto was a planet
# 4879                                                                                                                  RT:The Dark Matter of  Common Sense Is Not So Common v/
# 7896  RT  Well, this is amazing! It's an Actual Image of China’s Tianwen-1 Orbiting Mars captured by a smaller satellite that the orbiter released while orbiting the planet.
# 7966                                                           RT CivilAirPatrol "Cadets from our  will be asking questions to astronauts currently in space. Tune in soon at
# 8030                                                           RT CivilAirPatrol "Cadets from our  will be asking questions to astronauts currently in space. Tune in soon at
# 9048                                                                                                                                if you were born while Pluto was a planet
#
#                                                                                file_name
# 478   twitter_delivery_stream-1-2021-12-30-17-39-01-45daac32-de3f-4189-b312-8cd405214fe4
# 780   twitter_delivery_stream-1-2021-12-30-17-41-03-b8becce2-f393-42a9-bc9c-f8847fb4a7d2
# 1516  twitter_delivery_stream-1-2021-12-30-17-47-10-e7c45fc0-d1a2-4843-beed-2489ad22b82f
# 1631  twitter_delivery_stream-1-2021-12-30-17-48-10-31a1f4b1-30ef-4123-93f5-0b377dafcf2e
# 4828  twitter_delivery_stream-1-2021-12-31-18-59-21-04ddb807-dfc3-4889-998c-2ffcb0ff10d6
# 4879  twitter_delivery_stream-1-2021-12-31-18-59-21-04ddb807-dfc3-4889-998c-2ffcb0ff10d6
# 7896  twitter_delivery_stream-1-2022-01-04-16-27-24-37dbe71d-2d30-4dce-9027-57f9a3f4a385
# 7966  twitter_delivery_stream-1-2022-01-04-16-28-25-a43e3da5-1145-4e44-a59b-90018969f41c
# 8030  twitter_delivery_stream-1-2022-01-04-16-28-25-a43e3da5-1145-4e44-a59b-90018969f41c
# 9048  twitter_delivery_stream-1-2022-01-04-16-38-33-66ba9099-1f4f-441c-a25e-02882e53a63b

# %% [markdown]
# ## Inspect raw data in the S3 bucket

# %% [markdown]
# At the end of the previous section, all raw data files collected during an hour were combined into a single CSV file. This was done using a custom Python module, as explained above.
#
# In this section, we will briefly explore the raw data exported to the S3 bucket from the Firehose stream. We'll now show how each raw data file (each streamed Twitter record) can be converted into a `DataFrame` where each row corresponds to a single streamed record of Twitter data. The custom module used above handles this, but here we will briefly explore the first few processing steps that are encapsulated into that module.

# %% [markdown]
# Define the `boto3` S3 client

# %%
s3_client = boto3.client("s3", region_name=aws_region)

# %% [markdown]
# Use `boto3` to list files in the S3 bucket for one hour of tweets streamed using Kinesis Firehose and TweePy
# - we'll focus on files that were exported to an S3 folder during the 19:00 hour (UTC) on a single date (2021-12-31)

# %%
response_new = s3_client.list_objects_v2(
    Bucket=s3_bucket_name,
    Prefix=path_to_folder[1:] + "2021/12/31/19/",
    Delimiter="/",
)
with pd.option_context("display.max_colwidth", 2_000):
    display(
        pd.DataFrame.from_records(response_new["Contents"]).replace(
            {"ETag": '"'}, "", regex=True
        )
    )
# Out:
#                                                                                                                                Key  \
# 0   datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-00-23-a2b41515-424e-44d7-b146-1d7ec4f87e47
# 1   datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-01-24-0db1f3e6-292e-4ca1-ad48-f67c1272ce1e
# 2   datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-02-25-489245e0-c418-4d07-927f-2c5f258fa2d6
# 3   datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-03-29-1e4e4d1e-fde2-45de-beb0-504a02189e0f
# 4   datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-04-30-2e72131b-96ed-448e-ac15-dcda3313e671
# 5   datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-05-32-b265214c-8a04-4d4b-910a-418bb129ed58
# 6   datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-06-34-c4287ed5-121d-47a2-b085-2efa05c95f31
# 7   datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-07-36-58902263-5fbf-4ff0-b9ec-27fe3765c39a
# 8   datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-08-37-c54a59d5-5fb1-4208-ba0b-4ae0d162ca7d
# 9   datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-09-39-748ac6f5-9b72-4249-bdc7-124acb69065f
# 10  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-10-40-2f603c92-df7a-401d-8f3d-f611eac522b3
# 11  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-11-41-7b7f1693-5778-4734-a3bf-502a70764c07
# 12  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-12-42-4617c6d8-226b-43c9-a3d5-b45cc7934a3a
# 13  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-13-44-df01c3d4-d85f-4d2b-8920-d63fda97e5e2
# 14  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-14-45-0bfb9538-d502-48e7-922a-2a051ad53e52
# 15  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-15-46-08ce58db-c24f-4654-9c48-281b88158624
# 16  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-16-48-519e8033-eeeb-4068-878f-5ca3e860da54
# 17  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-17-53-9f031a22-e285-45aa-ba1d-aa79798b630a
# 18  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-18-54-d50d1c41-9f96-4f10-9541-20a5816cf5e8
# 19  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-19-54-507f41ec-051b-4087-9829-170ddccdbcbd
# 20  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-20-55-568e68f5-b670-427c-92d2-69d7a47ef31d
# 21  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-21-56-ec7797a6-0117-4b17-940f-a9b9383adda2
# 22  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-22-57-35966ccd-3b29-4da3-b0b5-c80f7e7c1f9e
# 23  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-23-59-742b1060-5b68-4493-99a8-0e778ea9b98a
# 24  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-25-03-419981ac-f7c2-4e27-8d7f-a608905b4f98
# 25  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-26-05-213ae787-a955-4da8-b31b-2309a521e0d2
# 26  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-27-05-af9d9540-c158-492f-ab9d-314b01607bdc
# 27  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-28-08-dcccbbca-905c-4481-b3a1-24c3ad7959ac
# 28  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-29-09-89f97ebc-c2fb-49c2-af24-7de6fe2413eb
# 29  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-30-09-625f8157-793c-4aa5-9ee1-2753d847b220
# 30  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-31-11-781c1b60-0a29-430a-b38a-a9503e6f54a8
# 31  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-32-12-d585727c-ce1e-452c-ac99-ba7ca099b32b
# 32  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-33-12-440d98f4-efa9-468b-9807-892fae98b4d4
# 33  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-34-13-935732b1-bdfb-45eb-8ad6-27563cd1b2f5
# 34  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-35-16-b0f9f56d-3727-4647-9eaa-114bf9b84784
# 35  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-36-18-5adf7766-8689-4433-9b79-2ef55fc6de85
# 36  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-37-19-34e1d964-737b-404a-910e-b8798a7c7294
# 37  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-38-19-05fd22fa-6a12-4575-800b-b81bc5dc52d8
# 38  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-39-21-a2824a4e-b6fa-4423-baf1-15cef25bfdaa
# 39  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-40-22-1b8ad8c2-07ed-4a04-ad73-7ae2b855933c
# 40  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-41-23-4dbebfc7-2fea-440a-95c2-75586b830d61
# 41  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-42-25-2b81299e-41c4-4034-be3f-fbb9c25c3b4e
# 42  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-43-28-57268e59-b621-4849-b314-34f2e363d921
# 43  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-44-31-bd1c751a-55ee-4c48-aaa4-b98663adae9b
# 44  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-45-33-fdbf2717-794b-42a7-9be6-0bd71057cec4
# 45  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-46-35-11bf9ae0-c1a2-4db4-abd5-cb8fa799ec56
# 46  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-47-36-9fb5483b-6845-4b32-925b-e2307ca3a517
# 47  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-48-38-71f30cbc-147b-4045-a9b1-c6a59c47645d
# 48  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-49-41-768009d4-7e11-4191-842c-830f3ffffec7
# 49  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-50-42-8795e79d-1a11-4901-abd6-ce7e6ef29a1b
# 50  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-51-43-f7cb95ab-3438-4914-b6b1-bc782d934ee2
# 51  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-52-49-7e8960b5-8034-4f6f-9aee-fb8cf5e5f7ed
# 52  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-53-51-96022c78-add5-46ed-af44-586d1249b57a
# 53  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-54-53-b6817be3-89f9-4c97-bc97-1cf449dd9b69
# 54  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-55-56-adb0519b-f9bc-4de9-80e1-4a06f2baad20
# 55  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-56-57-20685dc4-8ce4-4169-96db-6ef6309069f2
# 56  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-57-59-8616ad7d-1762-4b9f-8e0b-91f5d346bb00
# 57  datasets/twitter/kinesis-demo/2021/12/31/19/twitter_delivery_stream-1-2021-12-31-19-59-01-855071bc-8ddd-4344-b2d5-01d9377fdf69
#
#                 LastModified                              ETag   Size  \
# 0  2021-12-31 19:01:26+00:00  c64f8fa442b7f5d4915852806a221f9d  45440
# 1  2021-12-31 19:02:27+00:00  4e2023f345c02c806459c947e7914b24  48326
# 2  2021-12-31 19:03:28+00:00  6fcbc2acce8a6bbd411cbcaaf423e98e  49540
# 3  2021-12-31 19:04:31+00:00  f60e91bbd5c152197be5e25ef85a00b1  46082
# 4  2021-12-31 19:05:33+00:00  4515363c49f4b8b9bc53cbda40dee9ba  53066
# 5  2021-12-31 19:06:35+00:00  72e28226158634f1496b24f778de961d  42484
# 6  2021-12-31 19:07:37+00:00  de9c3c09e1bfac9e2bfb81aede7fd2af  47380
# 7  2021-12-31 19:08:38+00:00  ee0c021f3a7065fb6b0e20144de8565e  44098
# 8  2021-12-31 19:09:39+00:00  d76281f28a049cb7b5d6e0c29b664614  39662
# 9  2021-12-31 19:10:41+00:00  e26d005d8280faae9b58ed74d7fc3a99  50850
# 10 2021-12-31 19:11:42+00:00  5e96893134e7b5f05b7c0d5708ae348c  40585
# 11 2021-12-31 19:12:43+00:00  52479a4d4a1b72f1c2bfac73e38e96c9  42277
# 12 2021-12-31 19:13:45+00:00  ff8ed05c5dd659e820934b4b8255be5e  40231
# 13 2021-12-31 19:14:46+00:00  615b3760d9e165ae064e3bea4296038e  43979
# 14 2021-12-31 19:15:47+00:00  e7ee7d8c7d354e16bce2cbb99f8b0044  38927
# 15 2021-12-31 19:16:49+00:00  d2620f5ea0410f3dcfe94af7b3cfe3fb  36628
# 16 2021-12-31 19:17:51+00:00  19f0986eaee88229bdc5da99402b535d  48896
# 17 2021-12-31 19:18:55+00:00  61613f8d3f3f4dfb5a5ca148d701c5c4  44951
# 18 2021-12-31 19:19:56+00:00  689294d322598dbb63f24ea9abb0a000  46870
# 19 2021-12-31 19:20:57+00:00  6ca47accf64ebefcace7a110e386e6ea  40602
# 20 2021-12-31 19:21:58+00:00  4ee85070dc145a7b801e926b0816edb5  45341
# 21 2021-12-31 19:22:59+00:00  4c5cc8ee67decd35346bd401c2a61bd3  40874
# 22 2021-12-31 19:24:00+00:00  40ce4a636f37758927875aef1defe086  32558
# 23 2021-12-31 19:25:01+00:00  046bd0cd228b383646171901aa48d064  31515
# 24 2021-12-31 19:26:06+00:00  fd88bb321aadb6f0c89b500ad97bcca9  45488
# 25 2021-12-31 19:27:07+00:00  d7fef8ff2e19c50c2b79e46024484094  45334
# 26 2021-12-31 19:28:08+00:00  323ab35277b3ea3b9c2c8cde7735ba97  36592
# 27 2021-12-31 19:29:10+00:00  76ebc2632fc1ec09d84d8a5335488f78  31526
# 28 2021-12-31 19:30:11+00:00  69d33f04acbdeadbdcbefa9d0ef2a644  31167
# 29 2021-12-31 19:31:12+00:00  fe867d0c7e2cba66fffeb2cb71d062a6  35554
# 30 2021-12-31 19:32:13+00:00  60ad93d0f523668e2652c3b4e988e794  41744
# 31 2021-12-31 19:33:14+00:00  e39032af8eba28f8c66e3f22e9ee6bc3  34671
# 32 2021-12-31 19:34:15+00:00  ac4320ed37596c003abc32ae33ebe39b  40212
# 33 2021-12-31 19:35:16+00:00  17d364afa3eeaf2c24ead19212f4a008  32118
# 34 2021-12-31 19:36:19+00:00  df3fa0f6b5d41c36e64ee785bc141b6a  38981
# 35 2021-12-31 19:37:20+00:00  e3aeb4681c0ea4d65de02858f0b298bf  30779
# 36 2021-12-31 19:38:21+00:00  66b718c14113b2875369f71f442981d2  39233
# 37 2021-12-31 19:39:22+00:00  8a0d974b89b5dc3e2d8b0705fb77f72e  36126
# 38 2021-12-31 19:40:23+00:00  f46e89d0e3b43bb5810fa2d3ec4c5b94  44407
# 39 2021-12-31 19:41:24+00:00  78e35a28bab6e71a6f06a7ba3024d872  44695
# 40 2021-12-31 19:42:26+00:00  f1f39c1423f8cefd6b9dcbf089d4173a  32612
# 41 2021-12-31 19:43:28+00:00  62c315a9313eb2b1221f7577057f98cd  34946
# 42 2021-12-31 19:44:30+00:00  a827f3a586719ec4dc6f83435f6570f0  39490
# 43 2021-12-31 19:45:34+00:00  85ceb7cc797f04d55a31e4013df2fe29  38771
# 44 2021-12-31 19:46:35+00:00  a71bba9824e054ad42e23b95e5624950  46140
# 45 2021-12-31 19:47:37+00:00  87e46998e25b8737a32ca608afb35565  34951
# 46 2021-12-31 19:48:38+00:00  c7efdafa13bc0400544e107921a7ada3  42330
# 47 2021-12-31 19:49:41+00:00  13329a9108424fbcbc193cf04552e3a4  40689
# 48 2021-12-31 19:50:44+00:00  1d77874eee1d2b2f831bd056fb631c9e  29887
# 49 2021-12-31 19:51:45+00:00  8c525afea293c6376e21fa74d8f86a7f  40722
# 50 2021-12-31 19:52:46+00:00  e901217b7f93c9d197dcdd4261410fcf  36848
# 51 2021-12-31 19:53:51+00:00  2e96bd41e7682dd42040cdf9ddefe419  44651
# 52 2021-12-31 19:54:53+00:00  85b5e77f2d48550fb3acddc86558236c  42881
# 53 2021-12-31 19:55:56+00:00  b8ae6691453a924dfd77129581cd6942  40415
# 54 2021-12-31 19:56:59+00:00  1a9454895e30f68101605744cab60508  38255
# 55 2021-12-31 19:58:00+00:00  1ff405d9d3c84525d1ca0ebd2bdb0562  27789
# 56 2021-12-31 19:59:02+00:00  ca311a964573a45fb61bb2cd8bca42a3  46329
# 57 2021-12-31 20:00:03+00:00  5fc9ac53b0fdf81894cf6ba269cfa756  41439
#
#    StorageClass
# 0      STANDARD
# 1      STANDARD
# 2      STANDARD
# 3      STANDARD
# 4      STANDARD
# 5      STANDARD
# 6      STANDARD
# 7      STANDARD
# 8      STANDARD
# 9      STANDARD
# 10     STANDARD
# 11     STANDARD
# 12     STANDARD
# 13     STANDARD
# 14     STANDARD
# 15     STANDARD
# 16     STANDARD
# 17     STANDARD
# 18     STANDARD
# 19     STANDARD
# 20     STANDARD
# 21     STANDARD
# 22     STANDARD
# 23     STANDARD
# 24     STANDARD
# 25     STANDARD
# 26     STANDARD
# 27     STANDARD
# 28     STANDARD
# 29     STANDARD
# 30     STANDARD
# 31     STANDARD
# 32     STANDARD
# 33     STANDARD
# 34     STANDARD
# 35     STANDARD
# 36     STANDARD
# 37     STANDARD
# 38     STANDARD
# 39     STANDARD
# 40     STANDARD
# 41     STANDARD
# 42     STANDARD
# 43     STANDARD
# 44     STANDARD
# 45     STANDARD
# 46     STANDARD
# 47     STANDARD
# 48     STANDARD
# 49     STANDARD
# 50     STANDARD
# 51     STANDARD
# 52     STANDARD
# 53     STANDARD
# 54     STANDARD
# 55     STANDARD
# 56     STANDARD
# 57     STANDARD

# %% [markdown]
# **Observations**
# 1. Each row corresponds to a file of twitter data streamed during a 60-second period (per the configuration of the AWS Kinesis Firehose). There are 58 such files.
# 2. There are multiple twitter (tweet) records in every file. At this point, it is not possible to determine how many records are stored in every file but that will be determined next using `boto3`.

# %% [markdown]
# Get the first file collected during the chosen hour (19:00 UTC) in `path_to_folder`

# %%
file = response_new["Contents"][0]
file

# %% [markdown]
# Get the file body and file name from the file object

# %%
file_body = s3_client.get_object(Bucket=s3_bucket_name, Key=file.get("Key"))[
    "Body"
].read()
file_name = os.path.basename(file["Key"])

# %% [markdown]
# Get the file name

# %%
print(file_name)

# %% [markdown]
# From the file body, get the number of tweets in this file

# %%
print(len(file_body.decode("utf-8").split("\n")))
# Out:
# 86

# %% [markdown]
# **Observations**
# 1. The last row in the file is a new line (blank) in the file. This blank line is present since the `twitter_s3.py` streaming script writes every record that ends in a newline character (`\n`). When this read into a `DataFrame` using pandas `read_csv` earlier, we could (optionally) specify a line terminator to be `\n`, meaning that the last line of the raw data file does **not** get accidently picked up as a blank row in that `DataFrame`. However, here, we are working with the raw file body where we split on the newline object, but this will ignore the last newline character (the one at the end of the last streamed tweet). Since the last `\n` is not used to split any lines, it is considered as a line on its own. This will manifest itself as a blank line (appearing as a blank string) at the end of **every** file.
#
#    This is illustrated in a simple example below
#
#    ```python
#    single_tweet_record = "1\n2\n3\n"
#    print(len(single_tweet_record.split("\n")), single_tweet_record.split("\n"))
#    ```
#    which gives the following output
#    ```python
#    4 ['1', '2', '3', '']
#    ```
#
#    where we are expecting three fields (which we get), but we also get a blank string due to the leftover newline character that cannot split any more lines (see [here](https://stackoverflow.com/a/34844548/4057186) for further discussion). This will be verified below for the data in S3.

# %% [markdown]
# First, show the full first tweet (and all user attributes) that were saved

# %%
first_record = file_body.decode("utf-8").split("\n")[0]
print(first_record.strip().split("\t"))
# Out:
# ['1476991622084710403', 'None', 'None', 'None', 'None', 'False', '0', '0', '0', '0', 'False', 'False', 'Fri Dec 31 19:00:18 +0000 2021', '<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>', 'None', 'None', 'Twitter for Android', '', '', '', '', '', '', '', '', '[[]]', '{}', '', '', '', '', '', '', 'Pezhman', 'Pezhman921', '0', '1', '0', '101', '87', 'False', 'False', 'False', 'Fri Dec 24 17:12:22 +0000 2021', 'None', 'no', 'https://t.co/tZQX952m3C|https://t.co/MQFNdH7JdL', 'space|space|cryptocurrency|Helios', 'OKEx|SidusSpacewith|NASAand|MissionHelios', '2', '4', '4', " We are the First decentralized  community. The world's biggest media reported the collaboration of ____   We are Bridge between  and  .  $Helios"]

# %% [markdown]
# **Observations**
# 1. We can see that every element of this list is a string, as expected since we converted all streamed data (in `twitter_s3.py`) to strings before exporting each tweet *record* to S3 using Firehose.
# 2. As mentioned above, since we are splitting this list of lists using a newline character, every record except the last one does not end in a newline charater (`\n`). Here, since we are showing the first such record and not the last one, we can see that the record does not end in a newline character.

# %% [markdown]
# Next, we will verify that, for every file, the last retrieved record is a blank string (resulting from the leftover newline character discussed above)

# %%
# %%time
for file in response_new["Contents"]:
    file_body = s3_client.get_object(Bucket=s3_bucket_name, Key=file.get("Key"))[
        "Body"
    ].read()
    nested_list_of_records = file_body.decode("utf-8").split("\n")
    last_record = nested_list_of_records[-1]
    assert last_record == ''
# Out:
# CPU times: user 254 ms, sys: 2.99 ms, total: 257 ms
# Wall time: 3.76 s

# %% [markdown]
# Next, the first three streamed Twitter records are shown below

# %%
nested_list_of_records[:3]
# Out:
# ['1477006376647942156\tNone\tNone\tNone\tNone\tFalse\t0\t0\t0\t0\tFalse\tFalse\tFri Dec 31 19:58:56 +0000 2021\t<a href="http://twitter.com/download/iphone" rel="nofollow">Twitter for iPhone</a>\tNone\tNone\tTwitter for iPhone\t\t\t\t\t\t\t\t\t[[]]\t{}\t\t\t\t\t\t\tAndrew Parris\tAndrewParris17\t111\t74\t1\t2986\t2262\tFalse\tFalse\tFalse\tSun Jun 02 20:24:34 +0000 2019\tHouston, TX\tno\thttps://t.co/fyF7CuEM6S\t\t\t1\t0\t0\tOne hell of a year 2021, the best year of my life. When I started the year I had no idea what was in store, and I definitely didn’t know I’d become an astronaut. This year I met the most incredible people, had experiences I never imagined possible, grew, and became even more me\t',
#  '1477006377855901701\tNone\tNone\tNone\tNone\tFalse\t0\t0\t0\t0\tFalse\tFalse\tFri Dec 31 19:58:56 +0000 2021\t<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>\tNone\tNone\tTwitter for Android\t\t\t\t\t\t\t\t\t[[]]\t{}\t\t\t\t\t\t\tJoe Benigno\tjoe_benigno5\t52\t263\t3\t36748\t30095\tFalse\tFalse\tFalse\tSat Feb 13 19:39:10 +0000 2016\tEasthampton, MA\tno\thttps://t.co/JeJRIY34vD\t\t\t1\t0\t0\t97 years ago today Edwin Hubble announced the existence of other galaxies. What a long, strange, trip its been.\t',
#  '1477006381802688512\tNone\tNone\tNone\tNone\tFalse\t0\t0\t0\t0\tFalse\tFalse\tFri Dec 31 19:58:57 +0000 2021\t<a href="http://twitter.com/download/android" rel="nofollow">Twitter for Android</a>\t1463635603065487361\tNationNormie3\tTwitter for Android\t\t\t\t\t\t\t\t\t[[]]\t{}\t\t\t\t\t\t\tBrandon Fortino\tBLFortino\t24\t124\t2\t4027\t1092\tFalse\tFalse\tFalse\tTue Mar 13 20:05:30 +0000 2012\tNone\tno\t\t\tNationNormie3|SciGuySpace\t0\t2\t0\t  The Russian core segment is structurally failing. The cracks are growing and there is no way to stop it. I don\'t think the core segment can be replaced safely. The amount of maintenance is also reducing man-hours for science. I\'m sure NASA is discussing this internally.\t']

# %% [markdown]
# We are now ready to split each record by a tab separator (`\t`) and the resulting list will correspond to the fields (columns) for a the first three streamed records in our overall `DataFrame`, as shown below

# %%
with pd.option_context("display.max_columns", 100):
    display(
        pd.DataFrame(
            [record.split("\t")[:-1] for record in nested_list_of_records[:3]],
            columns=headers,
        )
    )
# Out:
#                     id   geo coordinates place contributors is_quote_status  \
# 0  1477006376647942156  None        None  None         None           False
# 1  1477006377855901701  None        None  None         None           False
# 2  1477006381802688512  None        None  None         None           False
#
#   quote_count reply_count retweet_count favorite_count favorited retweeted  \
# 0           0           0             0              0     False     False
# 1           0           0             0              0     False     False
# 2           0           0             0              0     False     False
#
#                        created_at  \
# 0  Fri Dec 31 19:58:56 +0000 2021
# 1  Fri Dec 31 19:58:56 +0000 2021
# 2  Fri Dec 31 19:58:57 +0000 2021
#
#                                               source  in_reply_to_user_id  \
# 0  <a href="http://twitter.com/download/iphone" r...                 None
# 1  <a href="http://twitter.com/download/android" ...                 None
# 2  <a href="http://twitter.com/download/android" ...  1463635603065487361
#
#   in_reply_to_screen_name          source_text place_id place_url  \
# 0                    None   Twitter for iPhone
# 1                    None  Twitter for Android
# 2           NationNormie3  Twitter for Android
#
#   place_place_type place_name place_full_name place_country_code  \
# 0
# 1
# 2
#
#   place_country place_bounding_box_type place_bounding_box_coordinates  \
# 0                                                                 [[]]
# 1                                                                 [[]]
# 2                                                                 [[]]
#
#   place_attributes coords_type coords_lon coords_lat geo_type geo_lon geo_lat  \
# 0               {}
# 1               {}
# 2               {}
#
#          user_name user_screen_name user_followers user_friends user_listed  \
# 0    Andrew Parris   AndrewParris17            111           74           1
# 1      Joe Benigno     joe_benigno5             52          263           3
# 2  Brandon Fortino        BLFortino             24          124           2
#
#   user_favourites user_statuses user_protected user_verified  \
# 0            2986          2262          False         False
# 1           36748         30095          False         False
# 2            4027          1092          False         False
#
#   user_contributors_enabled                     user_joined    user_location  \
# 0                     False  Sun Jun 02 20:24:34 +0000 2019      Houston, TX
# 1                     False  Sat Feb 13 19:39:10 +0000 2016  Easthampton, MA
# 2                     False  Tue Mar 13 20:05:30 +0000 2012             None
#
#   retweeted_tweet          tweet_text_urls tweet_text_hashtags  \
# 0              no  https://t.co/fyF7CuEM6S
# 1              no  https://t.co/JeJRIY34vD
# 2              no
#
#         tweet_text_usernames num_urls_in_tweet_text num_users_in_tweet_text  \
# 0                                                 1                       0
# 1                                                 1                       0
# 2  NationNormie3|SciGuySpace                      0                       2
#
#   num_hashtags_in_tweet_text  \
# 0                          0
# 1                          0
# 2                          0
#
#                                                 text
# 0  One hell of a year 2021, the best year of my l...
# 1  97 years ago today Edwin Hubble announced the ...
# 2    The Russian core segment is structurally fai...

# %% [markdown]
# **Notes**
# 1. Similar to splitting records by `\n`, which results in a leftover `\n` at the end of the file, here we will have a leftover `\t`. For this reason, we slice the resulting list to exclude the last list item (the leftover `\t` character).

# %% [markdown]
# As mentioned at the end of the previous section, the functionality to create this `DataFrame`, for every file, is encapsulated in a standalone Python module in `src/data/combine_data.py`. In that module, additional functionality is included to extract metadata about the files from the S3 bucket. This module was used at the end of the previous section to create such a `DataFrame`, for every hour's worth of streamed Twitter data, and export that `DataFrame` to a single CSV file to a subfolder in the S3 bucket at `datasets/twitter/kinesis-demo/csvs/` (giving one CSV file per hour).
#
# The contents of this custom Python module are shown below
#
# ```python
# # src/data/combine_data.py
# import os
# from datetime import datetime
# from io import StringIO
# from typing import Dict, List, Union
#
# import boto3
# import pandas as pd
#
#
# def get_objects_in_one_s3_level(
#     s3b_name: str, content: Union[Dict, str], region: str
# ) -> Dict:
#     """Get list of all storage objects in single S3 level."""
#     s3_client = boto3.client("s3", region_name=region)
#     # Get path to hourly sub-folders within each daily folder on S3 bucket
#     prefix = content if isinstance(content, str) else content.get("Prefix")
#     # Get list of all objects in all hourly sub-folders
#     # - each list of is a list of dictionaries, where each dict contains keys:
#     #   - Key, LastModified, ETag, Size, StorageClass
#     response_new = s3_client.list_objects_v2(
#         Bucket=s3b_name, Prefix=prefix, Delimiter="/"
#     )
#     return response_new
#
#
# def get_data_metadata(file: str, s3_bucket_name: str, region: str) -> Dict:
#     """Extract data and file metadata from raw tweets data."""
#     s3_client = boto3.client("s3", region_name=region)
#     # Get File body (decoded contents) from file dictionary
#     file_body = s3_client.get_object(
#         Bucket=s3_bucket_name, Key=file.get("Key")
#     )["Body"].read()
#     # Get File name from file dictionary
#     file_name = os.path.basename(file["Key"])
#     return {"file_body": file_body, "file_name": file_name}
#
#
# def get_attrs_extracted_from_tweet_text(
#     row: pd.Series, attr_type: str = "hashtags"
# ) -> str:
#     """Get attrs (hashtags or usernames) extracted from tweet text."""
#     # Get extracted attribute (tweet_text_hashtags or tweet_text_usernames)
#     # from each tweet (row of a pandas DataFrame)
#     # - attributes will be the '|' separated string
#     extracted = str(row[f"tweet_text_{attr_type}"])
#     # Split the string by the pipe operator ('|') to give a single string of
#     # space-separated attributes
#     extracted_separated = (
#         " " + extracted.replace("|", " ") if str(extracted) != "nan" else ""
#     )
#     # print(
#     #     row.name,
#     #     type(extracted_separated),
#     #     extracted_separated,
#     #     f"extracted_{attr_type}={extracted_separated}",
#     # )
#     return extracted_separated
#
#
# def get_datetime_string() -> str:
#     """Generate current timestamp as string."""
#     return datetime.now().strftime("%Y%m%d%H%M%S")
#
#
# def get_hourly_data_metadata(
#     data_list: List,
#     headers: List,
#     fpath: str,
#     cols_to_use: List[str],
#     get_metadata_agg: bool = False,
# ) -> List[pd.DataFrame]:
#     """Load raw tweets data and file metadata into DataFrames."""
#     year, month, day, hour = fpath.split("/", 3)[-1].split("/", 3)
#     dfs = []
#     dfs_metadata = []
#     # Loop over list of dictionaries, where each dict corresponds to a
#     # separate file and contains keys: file_name, file_body (file contents)
#     for k, raw_data_contents in enumerate(data_list):
#         # Decode file contents and split by \n giving nested list
#         # - each sub-list is a single tweet and its metadata
#         single_buffer_data_strings = (
#             raw_data_contents["file_body"].decode("utf-8").split("\n")
#         )
#         # Iterate over nested list
#         all_buffer_contents = []
#         for q, data_string in enumerate(single_buffer_data_strings):
#             if data_string:
#                 # split each sub-list by \t in order to get values for each
#                 # field
#                 values = data_string.strip().split("\t")
#                 # print(
#                 #     k+1,
#                 #     q+1,
#                 #     len(raw_data_contents["file_body"]),
#                 #     len(values),
#                 #     len(values) != len(headers),
#                 #     data_string,
#                 # )
#                 # Append tweet metadata to dict
#                 dfs_metadata.append(
#                     {
#                         "file": k + 1,
#                         "file_name": raw_data_contents["file_name"],
#                         "encoded_length": len(raw_data_contents["file_body"]),
#                         "values_index": q + 1,
#                         "len_values": len(values),
#                         "malformed_values": len(values) != len(headers),
#                         "file_year": year,
#                         "file_month": month,
#                         "file_day": day,
#                         "file_hour": hour[:-1],
#                     }
#                 )
#                 # Append tweet data to dict (if data is not malformed with
#                 # more fields than expected)
#                 if len(values) == len(headers):
#                     all_buffer_contents.append(values)
#         # Convert nested list of tweet data into DataFrame and append raw data
#         # filename as separate column
#         df_row = pd.DataFrame(all_buffer_contents, columns=headers).assign(
#             file_name=raw_data_contents["file_name"]
#         )
#         # Append DataFrame of data to empty list
#         dfs.append(df_row)
#     # Vertically concatenate list of DFs of data in order to get single DF of
#     # tweets retrieved per hour
#     df = pd.concat(dfs, ignore_index=True)
#     # Combine tweet text with space-separated hashtags and usernames that
#     # were extracted from the text of the tweet
#     # - eg. 'tweet text goes here' will be combined with
#     #       (hashtags string) 'hashtag1 hashtag2 hashtag3' and
#     #       (user names string) 'username1 username2 username3'
#     for attr_type in ["hashtags", "usernames"]:
#         df[f"{attr_type}_str"] = df.apply(
#             get_attrs_extracted_from_tweet_text, axis=1, attr_type=attr_type
#         )
#     df["text"] = df["text"] + df["hashtags_str"] + df["usernames_str"]
#     # Slice vertically concatenated data to select required columns
#     all_cols_to_use = cols_to_use + ["file_name"]
#     df = df[all_cols_to_use].dropna()
#     # Vertically concatenate list of DFs of metadata in order to get single DF
#     # of tweets metadata per hour
#     df_metadata = pd.DataFrame.from_records(dfs_metadata)
#     # (optional) Aggregate metadata by raw data file name
#     if get_metadata_agg:
#         df_metadata_agg = (
#             df_metadata.groupby(["file_name"], as_index=False)
#             .agg(
#                 {
#                     "encoded_length": "min",
#                     "values_index": "max",
#                     "len_values": "min",
#                     "malformed_values": "sum",
#                 }
#             )
#             .assign(num_valid_records=len(df))
#         )
#     else:
#         # if no aggregation wanted, return empty DataFrame
#         df_metadata_agg = pd.DataFrame()
#     return [df, df_metadata, df_metadata_agg]
#
#
# def create_folder_in_s3_bucket(
#     region: str, s3_bucket_name: str, folder_name: str = "csvs"
# ) -> None:
#     """Create folder in S3 bucket, if it does not exist."""
#     s3_client = boto3.client("s3", region_name=region)
#     # List all objects in S3 bucket that are inside the CSVs/ sub-folder
#     folders_response_result = s3_client.list_objects_v2(
#         Bucket=s3_bucket_name,
#         Prefix="datasets/twitter/kinesis-demo/csvs",
#         Delimiter="/",
#     )
#     # Create object (with no body), which will result in an empty folder
#     # (if a folder of the same name is not already present in the CSVs/
#     # sub-folder)
#     if "CommonPrefixes" in folders_response_result:
#         print(
#             f"Found existing folder {folder_name} in specified S3 bucket. "
#             "Did nothing."
#         )
#     else:
#         proc_data_folder_creation_response = s3_client.put_object(
#             Bucket=s3_bucket_name,
#             Body="",
#             Key="datasets/twitter/kinesis-demo/csvs/",
#         )
#         print(f"Created folder csvs in {s3_bucket_name}.")
#
#
# def get_existing_csv_files_list(
#     s3_bucket_name: str, region: str, prefix: str
# ) -> List[str]:
#     """Get list of files in subfolder in S3 bucket, by filename prefix."""
#     s3_resource = boto3.resource("s3", region_name=region)
#     bucket = s3_resource.Bucket(s3_bucket_name)
#     # Get list of objects containing user-specified prefix in filename
#     files_found_objects_list = list(bucket.objects.filter(Prefix=prefix))
#     # For each object, get dictionary of file attributes under .key attribute
#     # and store these dictionaries in a list
#     files_found_names_list = [w.key for w in files_found_objects_list]
#     return files_found_names_list
#
#
# def save_df_to_csv_on_s3(
#     df: pd.DataFrame,
#     bucket_name: str,
#     filepath: str,
#     region: str,
#     df_type: str = "metadata",
# ) -> None:
#     """Export DataFrame as CSV to folder in S3 bucket."""
#     s3_client = boto3.client("s3", region_name=region)
#     # Prepare DataFrame for export to an S3 bucket
#     # - https://stackoverflow.com/a/58636316/4057186
#     csv_buf = StringIO()
#     df.to_csv(csv_buf, header=True, index=False)
#     csv_buf.seek(0)
#     # Add CSV to bucket under the specified filepath (in this case, under
#     # the CSVs/ sub-folder)
#     s3_client.put_object(
#         Bucket=bucket_name, Body=csv_buf.getvalue(), Key=filepath
#     )
#     print(f"- Copied {len(df):,} rows of {df_type} to bucket at {filepath}.")
#
#
# def save_data_and_metadata_to_s3_csv(
#     subfolder_path: str,
#     existing_csv_files: List[str],
#     s3_bucket_name: str,
#     headers: List[str],
#     content: Dict,
#     path_to_csvs_folder: str,
#     region: str,
#     cols_to_use: List[str],
#     aggregate_metadata: bool = False,
# ) -> None:
#     """Extract tweets data and metadata and export to csvs/ in S3 bucket."""
#     # Concatenate year, month, day and hour specified by subfolder_path
#     # - 'datasets/twitter/kinesis-demo/2021/12/30/17/' becomes 'hc2021123017'
#     ctime_str = "hc" + subfolder_path.split("/", 3)[-1].rstrip("/").replace(
#         "/", ""
#     )
#     # Get list of hourly CSVs of data and metadata that already exist in
#     # csvs/ sub-folder in S3 bucket
#     existing_matching_csv_files = [
#         f for f in existing_csv_files if ctime_str in f
#     ]
#     # Get string with current datetime
#     ftime_str = "s" + get_datetime_string()
#     # For the given subfolder path, if no hourly CSVs of data and metadata
#     # exists in S3 bucket under the CSVs/ sub-folder, then extract these as
#     # pandas DFs and export each
#     # - i.e. if the above list (existing_matching_csv_files) is not empty,
#     #   then export data and metadata, else do nothing
#     if not existing_matching_csv_files:
#         # Get list of dictionaries (with file name and file body) in S3 bucket
#         data_list = [
#             get_data_metadata(file_name, s3_bucket_name, region)
#             for file_name in get_objects_in_one_s3_level(
#                 s3_bucket_name,
#                 content,
#                 region,
#             )["Contents"]
#         ]
#         # Get DFs of tweets data and metadata from file attributes in list of
#         # dicts
#         df, df_metadata, _ = get_hourly_data_metadata(
#             data_list,
#             headers,
#             content.get("Prefix"),
#             cols_to_use,
#             aggregate_metadata,
#         )
#         # Change datetime format in DF of data
#         for c in ["created_at", "user_joined"]:
#             df[c] = pd.to_datetime(df[c])
#         # Save DFs of data and metadata as CSVs to S3 bucket under the CSVs/
#         # sub-folder, if a CSV does not already exist for that hour
#         for df_obj, suffix, file_type in zip(
#             [df, df_metadata],
#             ["tweets_", "tweets_metadata_"],
#             ["data", "metadata"],
#         ):
#             fpath = (
#                 f"{path_to_csvs_folder}csvs/{suffix}"
#                 f"{len(data_list)}_{ctime_str}_{ftime_str}.csv"
#             )
#             print(f"Did not find {file_type} CSV file in {fpath}. ")
#             save_df_to_csv_on_s3(
#                 df_obj, s3_bucket_name, fpath, region, file_type
#             )
#     else:
#         # Since hourly CSV exists in CSVs/ sub-folder in S3 bucket, do nothing
#         fpath = existing_matching_csv_files[0]
#         print(f"Found CSV file in {fpath}. Did nothing.")
# ```
