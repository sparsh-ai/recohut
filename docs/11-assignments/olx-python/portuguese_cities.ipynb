# %%
import requests as rq
from zipfile import ZipFile
import pandas as pd
import pygeohash as gh
import json
import boto3

# %%
def download_zip_file(online_path, local_path):
    with rq.get(online_path) as response:
        open(local_path, "wb").write(response.content)
    return None

# %%
def get_full_df(local_zip_path, filename):
    with ZipFile(local_zip_path) as zip_file:
        df = pd.read_csv(zip_file.open(filename))
    return df

# %%
def filter_country(dataframe, country_to_filter):
    df = dataframe[dataframe.country==country_to_filter]
    return df

# %%
def select_columns(dataframe,*argv):
    df=pd.DataFrame()
    for arg in argv:
        df[arg]=dataframe[[arg]]
    return df

# %%
def adding_geohash_code(dataframe):
    dataframe["geohash"]=dataframe.apply(lambda x: gh.encode(x.lat, x.lng, precision=12), axis=1)
    return dataframe

# %%
def from_df_to_json(dataframe, json_filename):
    result = dataframe.to_json(orient="records")
    with open(json_filename, 'w', encoding='utf-8') as f:
        json.dump(result, f, ensure_ascii=False, indent=4)
    return None

# %%
def upload_to_s3(filename, s3_bucket, s3_path):
    s3_client = boto3.client('s3')
    try:
        response = s3_client.upload_file(filename, s3_bucket, f'{s3_path}{filename}')
    except ClientError as e:
        logging.error(e)
        return False
    return True

# %%
download_zip_file('https://simplemaps.com/static/data/world-cities/basic/simplemaps_worldcities_basicv1.75.zip','worldcities.zip')

# %%
dataframe_cities=get_full_df('worldcities.zip','worldcities.csv')

# %%
dataframe_portugal = filter_country(dataframe_cities,'Portugal')

# %%
dataframe_portugal
# Out:
#                      city          city_ascii      lat     lng   country iso2  \
# 734                Lisbon              Lisbon  38.7080 -9.1390  Portugal   PT
# 1728               Sintra              Sintra  38.7974 -9.3904  Portugal   PT
# 2050    Vila Nova de Gaia   Vila Nova de Gaia  41.1333 -8.6167  Portugal   PT
# 2437                Porto               Porto  41.1495 -8.6108  Portugal   PT
# 2756              Cascais             Cascais  38.6969 -9.4206  Portugal   PT
# ...                   ...                 ...      ...     ...       ...  ...
# 41315       Vila do Bispo       Vila do Bispo  37.0825 -8.9119  Portugal   PT
# 41531                Mêda                Meda  40.9667 -7.2667  Portugal   PT
# 41563  Vila Nova de Paiva  Vila Nova de Paiva  40.8500 -7.7333  Portugal   PT
# 41784     Alfândega da Fé     Alfandega da Fe  41.3500 -6.9667  Portugal   PT
# 41850              Sousel              Sousel  38.9532 -7.6757  Portugal   PT
#
#       iso3  admin_name  capital  population          id
# 734    PRT      Lisboa  primary    506654.0  1620619017
# 1728   PRT      Lisboa    minor    377835.0  1620848791
# 2050   PRT       Porto    minor    302295.0  1620040225
# 2437   PRT       Porto    admin    237591.0  1620356810
# 2756   PRT      Lisboa    minor    206479.0  1620824685
# ...    ...         ...      ...         ...         ...
# 41315  PRT        Faro    minor      5258.0  1620734353
# 41531  PRT      Guarda    minor      5202.0  1620700858
# 41563  PRT       Viseu    minor      5176.0  1620015183
# 41784  PRT    Bragança    minor      5104.0  1620280821
# 41850  PRT  Portalegre    minor      5074.0  1620270791
#
# [297 rows x 11 columns]

# %%
dataframe_select=select_columns(dataframe_portugal,'city','lat','lng','population')

# %%
dataframe_select
# Out:
#                      city      lat     lng  population
# 734                Lisbon  38.7080 -9.1390    506654.0
# 1728               Sintra  38.7974 -9.3904    377835.0
# 2050    Vila Nova de Gaia  41.1333 -8.6167    302295.0
# 2437                Porto  41.1495 -8.6108    237591.0
# 2756              Cascais  38.6969 -9.4206    206479.0
# ...                   ...      ...     ...         ...
# 41315       Vila do Bispo  37.0825 -8.9119      5258.0
# 41531                Mêda  40.9667 -7.2667      5202.0
# 41563  Vila Nova de Paiva  40.8500 -7.7333      5176.0
# 41784     Alfândega da Fé  41.3500 -6.9667      5104.0
# 41850              Sousel  38.9532 -7.6757      5074.0
#
# [297 rows x 4 columns]

# %%
final_df=adding_geohash_code(dataframe_select)

# %%
final_df
# Out:
#                      city      lat     lng  population       geohash
# 734                Lisbon  38.7080 -9.1390    506654.0  eycs0n94my5w
# 1728               Sintra  38.7974 -9.3904    377835.0  eyckdqf55zd3
# 2050    Vila Nova de Gaia  41.1333 -8.6167    302295.0  ez3f5bjdb6fu
# 2437                Porto  41.1495 -8.6108    237591.0  ez3fh51c1yf0
# 2756              Cascais  38.6969 -9.4206    206479.0  eyck1ss1u0gx
# ...                   ...      ...     ...         ...           ...
# 41315       Vila do Bispo  37.0825 -8.9119      5258.0  ey9dvnwt1xj8
# 41531                Mêda  40.9667 -7.2667      5202.0  ez6c49u83d7u
# 41563  Vila Nova de Paiva  40.8500 -7.7333      5176.0  ez682h8b3pct
# 41784     Alfândega da Fé  41.3500 -6.9667      5104.0  ez751rx10nev
# 41850              Sousel  38.9532 -7.6757      5074.0  eyft974wz4z2
#
# [297 rows x 5 columns]

# %%
from_df_to_json(final_df,'portuguese_cities.json')

# %%
with open('portuguese_cities.json') as json_file:
    data = json.load(json_file)
    print(data)
# Out:
# [{"city":"Lisbon","lat":38.708,"lng":-9.139,"population":506654.0,"geohash":"eycs0n94my5w"},{"city":"Sintra","lat":38.7974,"lng":-9.3904,"population":377835.0,"geohash":"eyckdqf55zd3"},{"city":"Vila Nova de Gaia","lat":41.1333,"lng":-8.6167,"population":302295.0,"geohash":"ez3f5bjdb6fu"},{"city":"Porto","lat":41.1495,"lng":-8.6108,"population":237591.0,"geohash":"ez3fh51c1yf0"},{"city":"Cascais","lat":38.6969,"lng":-9.4206,"population":206479.0,"geohash":"eyck1ss1u0gx"},{"city":"Loures","lat":38.8333,"lng":-9.1667,"population":205054.0,"geohash":"eyckzmmh27v1"},{"city":"Braga","lat":41.5503,"lng":-8.42,"population":181494.0,"geohash":"ez6h2kh8pc2c"},{"city":"Amadora","lat":38.75,"lng":-9.2333,"population":175136.0,"geohash":"eyckmyhx0e89"},{"city":"Matosinhos","lat":41.1867,"lng":-8.6844,"population":175478.0,"geohash":"ez3f63u1yv65"},{"city":"Almada","lat":38.6803,"lng":-9.1583,"population":174030.0,"geohash":"eyckp9e1h4s9"},{"city":"Oeiras","lat":38.697,"lng":-9.3017,"population":172120.0,"geohash":"eyckhkddqetu"},{"city":"Gondomar","lat":41.15,"lng":-8.5333,"population":168027.0,"geohash":"ez3fjg4hpeyr"},{"city":"Seixal","lat":38.6333,"lng":-9.0833,"population":158269.0,"geohash":"eycec2cxrc0e"},{"city":"Guimar\u00e3es","lat":41.445,"lng":-8.2908,"population":158124.0,"geohash":"ez65g2ffd7gq"},{"city":"Odivelas","lat":38.8,"lng":-9.1833,"population":144549.0,"geohash":"eyckxp2fms5p"},{"city":"Coimbra","lat":40.2111,"lng":-8.4289,"population":143396.0,"geohash":"ez4hb0nq8kkd"},{"city":"Vila Franca de Xira","lat":38.95,"lng":-8.9833,"population":136886.0,"geohash":"eyctedds1yq0"},{"city":"Maia","lat":41.2333,"lng":-8.6167,"population":135306.0,"geohash":"ez3fefm92k4z"},{"city":"Famalic\u00e3o","lat":41.4167,"lng":-8.5167,"population":133832.0,"geohash":"ez3gw5wmf82n"},{"city":"Leiria","lat":39.7431,"lng":-8.8069,"population":126897.0,"geohash":"ez1dpe5026g6"},{"city":"Set\u00fabal","lat":38.5236,"lng":-8.8935,"population":123684.0,"geohash":"eycejt5bnrtc"},{"city":"Barcelos","lat":41.5333,"lng":-8.6167,"population":120391.0,"geohash":"ez3u7bvt026b"},{"city":"Funchal","lat":32.65,"lng":-16.9167,"population":111892.0,"geohash":"etgcxpc8h34h"},{"city":"Viseu","lat":40.6575,"lng":-7.9139,"population":99274.0,"geohash":"ez4r7cmr0g26"},{"city":"Queluz","lat":38.7566,"lng":-9.2545,"population":78273.0,"geohash":"eyckmrmjd9bs"},{"city":"Viana do Castelo","lat":41.7,"lng":-8.8333,"population":88725.0,"geohash":"ez3tnzrb15qj"},{"city":"Barreiro","lat":38.6609,"lng":-9.0733,"population":78764.0,"geohash":"eycecw100f15"},{"city":"Aveiro","lat":40.6389,"lng":-8.6553,"population":78450.0,"geohash":"ez1z5n16ubh9"},{"city":"Ponta Delgada","lat":37.74,"lng":-25.67,"population":68809.0,"geohash":"eqtwxy7emtut"},{"city":"Faro","lat":37.0161,"lng":-7.935,"population":64560.0,"geohash":"eyd6e6tfmj5j"},{"city":"Santar\u00e9m","lat":39.2392,"lng":-8.6869,"population":62200.0,"geohash":"eycz4r62ut1c"},{"city":"\u00c9vora","lat":38.5725,"lng":-7.9072,"population":56596.0,"geohash":"eyf7kjfjhghm"},{"city":"Castelo Branco","lat":39.8228,"lng":-7.4931,"population":56109.0,"geohash":"ez4dt3x8w5gx"},{"city":"Rio Tinto","lat":41.1833,"lng":-8.5667,"population":50713.0,"geohash":"ez3fm11yj7t3"},{"city":"Vila Real","lat":41.2953,"lng":-7.7461,"population":51850.0,"geohash":"ez66ztx6wcc5"},{"city":"Corroios","lat":38.6147,"lng":-9.1508,"population":46475.0,"geohash":"eyc7xv8dfvuc"},{"city":"Mafamude","lat":41.1152,"lng":-8.6036,"population":38940.0,"geohash":"ez3cuhz13sfc"},{"city":"Ermezinde","lat":41.2133,"lng":-8.5472,"population":38798.0,"geohash":"ez3fmw8hggcy"},{"city":"Cac\u00e9m","lat":38.7704,"lng":-9.3081,"population":21289.0,"geohash":"eycks1yjcw3s"},{"city":"Guarda","lat":40.5364,"lng":-7.2683,"population":42541.0,"geohash":"ez4yde7mskds"},{"city":"Agualva","lat":38.77,"lng":-9.2988,"population":35824.0,"geohash":"eycks3ugd7b4"},{"city":"Massam\u00e1","lat":38.7568,"lng":-9.2748,"population":28112.0,"geohash":"eyckkzqq9rpv"},{"city":"Beja","lat":3 ...
