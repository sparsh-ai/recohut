# %%
import pandas as pd
pd.set_option('display.max_rows', 500)

# %%
df = pd.read_json('MyHistoricData/endsong.json')

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 9419 entries, 0 to 9418
# Data columns (total 21 columns):
#  #   Column                             Non-Null Count  Dtype
# ---  ------                             --------------  -----
#  0   ts                                 9419 non-null   object
#  1   username                           9419 non-null   int64
#  2   platform                           9419 non-null   object
#  3   ms_played                          9419 non-null   int64
#  4   conn_country                       9419 non-null   object
#  5   ip_addr_decrypted                  9419 non-null   object
#  6   user_agent_decrypted               9419 non-null   object
#  7   master_metadata_track_name         9399 non-null   object
#  8   master_metadata_album_artist_name  9399 non-null   object
#  9   master_metadata_album_album_name   9399 non-null   object
#  10  spotify_track_uri                  9399 non-null   object
# ...

# %%
df.isnull().sum()
# Out:
# ts                                      0
# username                                0
# platform                                0
# ms_played                               0
# conn_country                            0
# ip_addr_decrypted                       0
# user_agent_decrypted                    0
# master_metadata_track_name             20
# master_metadata_album_artist_name      20
# master_metadata_album_album_name       20
# spotify_track_uri                      20
# episode_name                         9414
# episode_show_name                    9414
# spotify_episode_uri                  9414
# reason_start                            0
# reason_end                              0
# shuffle                                 0
# skipped                              9003
# offline                                 0
# offline_timestamp                       0
# incognito_mode                          0
# dtype: int64

# %%
df = df[['ts', 
         'master_metadata_album_artist_name', 
         'master_metadata_track_name', 
         'master_metadata_album_album_name', 
         'reason_start', 
         'reason_end', 
         'shuffle', 
         'skipped']]

# %%
df.sort_values(by='ts',ignore_index=True, inplace=True)

# %%
df
# Out:
#                         ts master_metadata_album_artist_name  \
# 0     2013-11-18T10:40:26Z                           Madness
# 1     2013-11-18T10:42:29Z                        El DeBarge
# 2     2013-11-18T10:45:00Z                   Fujiya & Miyagi
# 3     2013-11-18T10:45:53Z                   Fujiya & Miyagi
# 4     2013-11-18T10:48:05Z                      Solar Fields
# ...                    ...                               ...
# 9414  2022-12-18T15:16:24Z                       Snowy White
# 9415  2022-12-18T15:20:52Z                 Bruce Springsteen
# 9416  2022-12-18T15:22:56Z                        Tim Hardin
# 9417  2022-12-18T16:40:22Z                         J.J. Cale
# 9418  2022-12-18T16:40:22Z                     Vaya Con Dios
#
#                  master_metadata_track_name master_metadata_album_album_name  \
# 0                                 Our House                    Utter Madness
# ...

# %%
df['ts'] = pd.to_datetime(df['ts'])

# %%
df
# Out:
#                             ts master_metadata_album_artist_name  \
# 0    2013-11-18 10:40:26+00:00                           Madness
# 1    2013-11-18 10:42:29+00:00                        El DeBarge
# 2    2013-11-18 10:45:00+00:00                   Fujiya & Miyagi
# 3    2013-11-18 10:45:53+00:00                   Fujiya & Miyagi
# 4    2013-11-18 10:48:05+00:00                      Solar Fields
# ...                        ...                               ...
# 9414 2022-12-18 15:16:24+00:00                       Snowy White
# 9415 2022-12-18 15:20:52+00:00                 Bruce Springsteen
# 9416 2022-12-18 15:22:56+00:00                        Tim Hardin
# 9417 2022-12-18 16:40:22+00:00                         J.J. Cale
# 9418 2022-12-18 16:40:22+00:00                     Vaya Con Dios
#
#                  master_metadata_track_name master_metadata_album_album_name  \
# 0                                 Our House                    Utter Madness
# ...

# %%
df['master_metadata_track_name'].value_counts().head(20)
# Out:
# Year of the Cat - 2001 Remaster    18
# Pink Moon                          17
# Simple Man                         17
# The Temple Of The King             14
# Diamonds And Rust                  14
# Heart Of Gold                      14
# More Than Words                    13
# The Way You Look Tonight           13
# Easy                               13
# At Last                            13
# Stairway to Heaven - Remaster      12
# A Horse with No Name               12
# Drive                              12
# Your Song                          12
# Everybody's Talkin'                12
# Unchained Melody                   12
# Knockin' On Heaven's Door          11
# If You Could Read My Mind          11
# Julia                              11
# Leaf And Stream                    11
# Name: master_metadata_track_name, dtype: int64

# %%
df['master_metadata_album_artist_name'].value_counts().head(20)
# Out:
# Frédéric Chopin       190
# Warren Zevon           84
# The Killers            78
# Percy Faith            55
# The Rolling Stones     54
# Al Stewart             47
# Norah Jones            46
# Dire Straits           46
# Elton John             45
# Ludovico Einaudi       43
# Martin Garrix          42
# Sade                   42
# The Beatles            42
# Iron Maiden            41
# Joan Baez              40
# Led Zeppelin           39
# Scorpions              38
# Fleetwood Mac          37
# Bruce Springsteen      36
# Eagles                 36
# Name: master_metadata_album_artist_name, dtype: int64
