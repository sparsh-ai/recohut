# %%
import json
import gzip
import boto3
import os
import pandas as pd
from flatten_json import flatten
from sklearn import preprocessing
import psycopg2

# %%
QUEUE_NAME = "login-queue"

# %%
def send_messages():
    sqs = boto3.client("sqs")
    queue_url = sqs.create_queue(QueueName=QUEUE_NAME)["QueueUrl"]
    print(f"queue_url: [{queue_url}]")

    with gzip.open("data/sample_data.json.gz", "r") as f:
        data = json.load(f)
        print(data)

    assert len(data) == 100

    for record in data:
        sqs.send_message(QueueUrl=queue_url, MessageBody=json.dumps(record))

    return

# %%
with open('data/sample_data.json.gz','rb') as f:
    gzip_fd = gzip.GzipFile(fileobj=f)
    d = json.loads(gzip_fd.read())

df = pd.json_normalize(d)
df
# Out:
#                                  user_id app_version device_type  \
# 0   424cdd21-063a-43a7-b91b-7ca1a833afae       2.3.0     android
# 1   c0173198-76a8-4e67-bfc2-74eaa3bbff57       0.2.6         ios
# 2   66e0635b-ce36-4ec7-aa9e-8a8fca9b83d4       2.2.1         ios
# 3   181452ad-20c3-4e93-86ad-1934c9248903        0.96     android
# 4   60b9441c-e39d-406f-bba0-c7ff0e0ee07f       0.4.6     android
# ..                                   ...         ...         ...
# 95  2ad5985b-dc70-44ca-b3ed-f4246a42f611        1.35     android
# 96  ca322b6c-97f8-4075-9663-42cebeb1d26e        0.38     android
# 97  d4f4f380-349e-48ac-bdc3-5ee4e29b57c1       3.2.0         ios
# 98  792e3e1f-bf84-409e-925c-d653fab4b6be         1.4         ios
# 99  4e216e8b-1682-4bc0-9b47-0777b4a77a9e        6.88         ios
#
#                  ip locale    device_id  foo  bar
# 0   199.172.111.135     RU  593-47-5928  NaN  NaN
# 1      241.6.88.151     PH  104-25-0070  NaN  NaN
# 2    130.111.167.54   None  127-42-0862  NaN  NaN
# 3      118.79.6.245     ID  190-44-3099  NaN  NaN
# 4      223.31.97.46     FR  149-99-5185  NaN  NaN
# ..              ...    ...          ...  ...  ...
# 95    229.70.21.221     PT  284-81-7238  NaN  NaN
# 96    235.162.61.43     BG  812-95-5877  NaN  NaN
# 97   200.100.97.178     FR  317-03-6529  NaN  NaN
# 98  164.197.201.156     TH  116-92-9733  NaN  NaN
# 99      87.114.1.14   None  437-41-2278  NaN  NaN
#
# [100 rows x 8 columns]

# %% [markdown]
# Import label encoder

# %%
# label_encoder object knows how to understand word labels.
label_encoder = preprocessing.LabelEncoder()

# %%
# Encode labels in column 'device_id' and 'ip'
df['masked_device_id']= label_encoder.fit_transform(df['device_id'])
df['masked_ip']= label_encoder.fit_transform(df['ip'])

# %%
df = df.drop(columns=['foo','bar'])
df['create_date'] = pd.Timestamp.today().strftime('%Y-%m-%d')
df = df[['user_id', 'device_type', 'masked_ip','masked_device_id','locale','app_version','create_date']]
df
# Out:
#                                  user_id device_type  masked_ip  \
# 0   424cdd21-063a-43a7-b91b-7ca1a833afae     android         39
# 1   c0173198-76a8-4e67-bfc2-74eaa3bbff57         ios         66
# 2   66e0635b-ce36-4ec7-aa9e-8a8fca9b83d4         ios         11
# 3   181452ad-20c3-4e93-86ad-1934c9248903     android          7
# 4   60b9441c-e39d-406f-bba0-c7ff0e0ee07f     android         54
# ..                                   ...         ...        ...
# 95  2ad5985b-dc70-44ca-b3ed-f4246a42f611     android         57
# 96  ca322b6c-97f8-4075-9663-42cebeb1d26e     android         61
# 97  d4f4f380-349e-48ac-bdc3-5ee4e29b57c1         ios         40
# 98  792e3e1f-bf84-409e-925c-d653fab4b6be         ios         23
# 99  4e216e8b-1682-4bc0-9b47-0777b4a77a9e         ios         94
#
#     masked_device_id locale app_version create_date
# 0                 64     RU       2.3.0  2022-12-29
# 1                  1     PH       0.2.6  2022-12-29
# 2                  6   None       2.2.1  2022-12-29
# 3                 13     ID        0.96  2022-12-29
# 4                  9     FR       0.4.6  2022-12-29
# ..               ...    ...         ...         ...
# 95                24     PT        1.35  2022-12-29
# 96                94     BG        0.38  2022-12-29
# 97                32     FR       3.2.0  2022-12-29
# 98                 4     TH         1.4  2022-12-29
# 99                45   None        6.88  2022-12-29
#
# [100 rows x 7 columns]

# %%
def get_secret(secret_name='wysde'):
    region_name = "us-east-1"
    session = boto3.session.Session()
    client = session.client(
        service_name='secretsmanager',
        region_name=region_name)
    get_secret_value_response = client.get_secret_value(SecretId=secret_name)
    get_secret_value_response = json.loads(get_secret_value_response['SecretString'])
    return get_secret_value_response

# %%
secret_vals = get_secret()

postgres_endpoint = secret_vals['RDS_POSTGRES_HOST']
postgres_user = secret_vals['RDS_POSTGRES_USERNAME']
postgres_pass = secret_vals['RDS_POSTGRES_PASSWORD']
port = 5432
dbname = "sparsh"

# %%
# establishing the connection
conn = psycopg2.connect(database=dbname, 
                        user=postgres_user, 
                        password=postgres_pass, 
                        host=postgres_endpoint, 
                        port=port)

# %%
# Creating a cursor object using the cursor() method
cursor = conn.cursor()

# %%
cursor.execute('CREATE TABLE IF NOT EXISTS user_login(user_id  varchar(128), device_type varchar(32),masked_ip varchar(256),masked_device_id varchar(256),locale varchar(32),app_version varchar(32),create_date date)')
print('Creation of table succeeded')
# Out:
# Creation of table succeeded

# %%
for i in df.index:
    cols  = ','.join(list(df.columns))
    vals  = [df.at[i,col] for col in list(df.columns)]
    query = "INSERT INTO user_login VALUES('%s','%s','%s','%s','%s','%s','%s')" % (vals[0], vals[1], vals[2],vals[3],vals[4],vals[5],vals[6])
    cursor.execute(query)

# %%
# fetching all rows
sql1='''select * from user_login'''
cursor.execute(sql1)
for i in cursor.fetchall():
    print(i)
# Out:
# ('424cdd21-063a-43a7-b91b-7ca1a833afae', 'android', '39', '64', 'RU', '2.3.0', datetime.date(2022, 12, 29))
# ('c0173198-76a8-4e67-bfc2-74eaa3bbff57', 'ios', '66', '1', 'PH', '0.2.6', datetime.date(2022, 12, 29))
# ('66e0635b-ce36-4ec7-aa9e-8a8fca9b83d4', 'ios', '11', '6', 'None', '2.2.1', datetime.date(2022, 12, 29))
# ('181452ad-20c3-4e93-86ad-1934c9248903', 'android', '7', '13', 'ID', '0.96', datetime.date(2022, 12, 29))
# ('60b9441c-e39d-406f-bba0-c7ff0e0ee07f', 'android', '54', '9', 'FR', '0.4.6', datetime.date(2022, 12, 29))
# ('5082b1ae-6523-4e3b-a1d8-9750b4407ee8', 'android', '62', '34', 'None', '3.7', datetime.date(2022, 12, 29))
# ('5bc74293-3ca1-4f34-bb89-523887d0cc2f', 'ios', '65', '87', 'PT', '2.2.8', datetime.date(2022, 12, 29))
# ('92d8ceec-2e12-49f3-81bd-518fe66971ec', 'android', '38', '90', 'BR', '0.5.5', datetime.date(2022, 12, 29))
# ('05e153b1-4fa1-474c-bd7e-9f74d1c495e7', 'android', '22', '43', 'None', '0.5.0', datetime.date(2022, 12, 29))
# ('325c0f3d-da25-45ff-aff4-81816db069bc', 'android', '30', '71', 'RU', '0.60', datetime.date(2022, 12, 29))
# ('692bef80-12db-4f19-b142-60d7cf450eda', 'ios', '52', '78', 'None', '6.4.8', datetime.date(2022, 12, 29))
# ('9135d7bf-5992-4cfd-84bb-52b52030a748', 'android', '19', '65', 'None', '0.16', datetime.date(2022, 12, 29))
# ('nan', 'nan', '99', '99', 'nan', 'nan', datetime.date(2022, 12, 29))
# ('6c72164e-1b7a-446a-906d-fedb45d8f718', 'ios', '10', '2', 'KE', '2.0.8', datetime.date(2022, 12, 29))
# ('2d839c07-94fd-4dd8-b535-a21ac271fea3', 'ios', '12', '98', 'None', '7.31', datetime.date(2022, 12, 29))
# ('271bd27b-19e9-46c9-a5a4-7c2bb5e35cb0', 'ios', '55', '70', 'PE', '7.87', datetime.date(2022, 12, 29))
# ('5e802e77-427d-4618-b437-ad4fb1461c0d', 'ios', '70', '52', 'ID', '6.80', datetime.date(2022, 12, 29))
# ('901905c7-a1ef-47bf-b28b-8f8d3f8df807', 'ios', '18', '22', 'KR', '5.56', datetime.date(2022, 12, 29))
# ('b018771c-cef7-42af-b595-83bf78cea441', 'android', '8', '44', 'KR', '1.1', datetime.date(2022, 12, 29))
# ('74847efb-c793-4336-b7be-79b46793d05b', 'android', '9', '40', 'None', '5.4.8', datetime.date(2022, 12, 29))
# ('ed5d5d23-590e-4c7c-ace0-dc8204630b14', 'ios', '87', '23', 'ID', '3.0', datetime.date(2022, 12, 29))
# ('d34e2144-9952-466e-bfbd-e8777f841cc8', 'android', '96', '26', 'None', '2.2.9', datetime.date(2022, 12, 29))
# ('2fa29cb4-c70d-4f13-977c-fb8a7fdb3641', 'ios', '20', '14', 'None', '5.60', datetime.date(2022, 12, 29))
# ('e1718797-aee8-42ec-bce7-550342cb2653', 'android', '67', '20', 'CN', '6.02', datetime.date(2022, 12, 29))
# ('fd75e212-7bc4-4bc5-a307-34c7a57b9ecc', 'android', '4', '55', 'RU', '0.32', datetime.date(2022, 12, 29))
# ('1cd051c7-3211-48ea-b3bf-321fafa741e1', 'ios', '81', '93', 'MT', '0.65', datetime.date(2022, 12, 29))
# ('780bf10e-d397-4e02-b7b4-85e5dc096c7b', 'android', '76', '8', 'GR', '1.8.0', datetime.date(2022, 12, 29))
# ('33350db1-0a80-4a75-9909-d143386405f7', 'android', '91', '62', 'None', '5.6.7', datetime.date(2022, 12, 29))
# ('806338fd-8c23-4554-a703-bcd1f1549286', 'android', '15', '88', 'None', '2.6', datetime.date(2022, 12, 29))
# ('c816a7e6-a7f4-4cf3-ae12-d3c927fbeac5', 'ios', '32', '31', 'PH', '9.10', datetime.date(2022, 12, 29))
# ('f7f0ee55-997a-4e87-946a-68d0dfb35d12', 'ios', '50', '30', 'None', '4.19', datetime.date(2022, 12, 29))
# ('3a10965b-8e05-41e4-b5b4-914e5ff21719', 'ios', '17', '10', 'MD', '0.83', datetime.date(2022, 12, 29))
# ('b9ff50c8-d8ee-4038-99f4-35de1fd03332', 'ios', '6', '84', 'RU', '9.6', datetime.date(2022, 12, 29))
# ('e84b79e6-8cd9-4d06-a005-eb9c66b29eba', 'ios', '5', '63', 'NI', '5.5', datetime.date(2022, 12, 29))
# ('e917350b-181b-4976-b3fb-cdd8529737fc', 'android', '27', '35', 'ID', '3.3.8', datetime.date(2022, 12, 29))
# ('05a10a0d-2278-4fe5-b7ae-6f24854bcdfc', 'ios', '43', '38', 'CN', '5.26', datetime.date(2022, 12, 29))
# ('82840e3f-9ac6-4462-9b77-8d5c971ec095', 'ios', '33', '73', 'US', '1.1', datetime.date(2022, 12, 29))
# ('159ad335-0fc1-44b4-90b7-4115d360187d', 'android', '47', '28', 'ID', '0.1.1', datetime.date(2022, 12, 29))
# ('9f98aad0-70e6-4fb6-be4f-f3539ca8e582', 'android', '75', '48', 'None', '0.1.5', datetime.date(2022, 12, 29))
# ('bf19b08e-fd9b-4894-a85b-0016d7b96428', 'android', '37', '92', 'None', '3.6', datetime.date(2022, 12, 29))
# ('fb644fbc-8a42-4abf-bf75-fbc5900fb187', 'android', '73', '97', 'None', '0.24', datetime.date(2022, 12, 29))
# ('c1ae09c9-5721-46bc-8830-b99be558f3b0', 'android', '2', '68', 'FR', '9.8.0', datetime.date(2022, 12, 29))
# ('4a80dec4-e47f-4d1c-a6d6-065c4218d7df', 'android', '35', '76', 'CN', '5.3.9', datetime.date(2022, 12, 29))
# ('3c2abada-e7f1-4862-bb09-477b3c61839a', 'ios', '0', '56', 'None', '0.1.6', datetime.date(2022, 12, 29))
# ('87e49911-9beb-42b0-8f4c-da554f5c706b', 'android', '68', '15', 'PA', '3.9', datetime.date(2022, 12, 29))
# ('428af9cd-b1ea-4dbf-831c-7842a4ad415b', 'ios', '28', '27', 'None', '0.7.0', datetime.date(2022, 12, 29))
# ('ec808db2-9742-460a-8c9d-6d7458d6f1f5', 'android', '53', '74', 'RU', '0.58', datetime.date(2022, 12, 29))
# ('e24da5d7-5057-4455-ac81-85ff747fdfc2', 'android', '85', '49', 'None', '6.56', datetime.date(2022, 12, 29))
# ('e9ad2ea5-de61-4582-9e01-2624580704cb', 'ios', '29', '53', 'CZ', '0.94', datetime.date(2022, 12, 29))
# ('fcab7f15-9d5f-4d7c-9f90-fbed38f3e344', 'android', '60', '85', 'UA', '1.0.3', datetime.date(2022, 12, 29))
# ('607a0bff-c282-4d3b-9b57-b0f1dba212a3', 'android', '48', '95', 'IR', '8.3', datetime.date(2022, 12, 29))
# ('c24b628c-1afd-4f59-a0f0-3db2ae71fd5c', 'ios', '88', '0', 'BR', '0.2.4', datetime.date(2022, 12, 29))
# ('a0c70e0d-6dad-4bf2-b26e-a9f39d2cc69f', 'android', '69', '60', 'None', '0.4.8', datetime.date(2022, 12, 29))
# ('27843453-3ecd-46d5-bf1c-43a137c214b5', 'ios', '45', '17', 'CA', '0.6.6', datetime.date(2022, 12, 29))
# ('868f5cea-ab60-4c83-bda0-51ac318ef89d', 'ios', '24', '12', 'VN', '0.7.9', datetime.date(2022, 12, 29))
# ('31bb8d9c-28d0-431a-a130-00b2ec325353', 'android', '80', '37', 'None', '0.61', datetime.date(2022, 12, 29))
# ('8570bbf6-c2c8-482b-b44f-7b75ff1b5fc6', 'ios', '1', '7', 'PH', '8.9.6', datetime.date(2022, 12, 29))
# ('5ba7fe55-301d-4bd2-9d36-9729edb2fd45', 'ios', '21', '36', 'MK', '2.7.2', datetime.date(2022, 12, 29))
# ('ba6489ba-84ac-4506-ac48-3da0eaca1255', 'android', '71', '11', 'None', '2.0', datetime.date(2022, 12, 29))
# ('8834753a-4860-4598-b02a-ef26b3e44859', 'ios', '31', '16', 'CN', '0.26', datetime.date(2022, 12, 29))
# ('a48f6214-bddd-47e8-84d3-7d34acdc1427', 'ios', '42', '42', 'CU', '0.84', datetime.date(2022, 12, 29))
# ('38b5aedc-9fb3-4f88-a48c-e274c347775d', 'ios', '98', '89', 'CN', '4.99', datetime.date(2022, 12, 29))
# ('1ef6f2aa-5e4c-4885-9e25-e3431efc40f5', 'android', '77', '67', 'ID', '0.56', datetime.date(2022, 12, 29))
# ('8ecdcad9-88b8-492d-80fc-a399a3d245a4', 'android', '64', '91', 'None', '5.9.5', datetime.date(2022, 12, 29))
# ('97e35131-aa1e-41a6-9fe7-711726346a68', 'ios', '83', '51', 'CN', '0.3.9', datetime.date(2022, 12, 29))
# ('bdd557b5-c71c-4d26-b31e-49cb87656dfe', 'android', '97', '72', 'SI', '2.4', datetime.date(2022, 12, 29))
# ('e705f3dc-6f05-4b8d-a25a-b3cdbea5c166', 'android', '84', '46', 'None', '3.1.4', datetime.date(2022, 12, 29))
# ('26b2aa9b-9060-4188-a297-5d40ad06fbbf', 'ios', '72', '81', 'PA', '2.00', datetime.date(2022, 12, 29))
# ('1f5e38d0-2a07-4ac6-87f1-5ca96d336260', 'ios', '41', '29', 'None', '6.0.7', datetime.date(2022, 12, 29))
# ('1cc1a510-1c81-48c3-a806-7fb300c576c8', 'android', '82', '25', 'NG', '5.5', datetime.date(2022, 12, 29))
# ('c9dc3ac8-1029-4880-a8be-9ddf4c8830e7', 'android', '34', '61', 'PT', '3.95', datetime.date(2022, 12, 29))
# ('b46cb700-0bad-4dfd-9b50-8151aacf3f3e', 'ios', '49', '39', 'MA', '0.8.4', datetime.date(2022, 12, 29))
# ('f1769f0a-4538-4029-a3a6-e788df7d4d38', 'android', '3', '5', 'CN', '2.7.9', datetime.date(2022, 12, 29))
# ('08399c7f-f48d-4f1b-9147-f441b5fedc86', 'ios', '25', '59', 'RU', '2.3', datetime.date(2022, 12, 29))
# ('7ac5c71d-90ff-4014-9317-674080b820d5', 'ios', '79', '41', 'FR', '5.3', datetime.date(2022, 12, 29))
# ('fcabe7a9-9b6a-4894-b7a7-11af7d6c4373', 'ios', '26', '57', 'MN', '4.36', datetime.date(2022, 12, 29))
# ('ff754a40-de07-4dee-a893-2e5531e8e55b', 'android', '46', '96', 'CN', '0.7.2', datetime.date(2022, 12, 29))
# ('8b9a126e-4c7b-4589-bc59-ab7571b9d994', 'ios', '78', '79', 'MX', '0.1.2', datetime.date(2022, 12, 29))
# ('1fd1e707-a7cc-4fb1-8d43-3d9d17cc4ad2', 'ios', '16', '75', 'ID', '0.5.1', datetime.date(2022, 12, 29))
# ('71f6da05-40fd-4cb7-bd0e-9d0a856e50c7', 'android', '74', '33', 'ID', '6.7.7', datetime.date(2022, 12, 29))
# ('19e19e1b-bc1a-467d-ae70-ff6e3dfe4e69', 'android', '63', '21', 'RU', '0.87', datetime.date(2022, 12, 29))
# ('813fd857-cb82-4047-aa7d-6a86c22be4c8', 'ios', '13', '54', 'FR', '3.97', datetime.date(2022, 12, 29))
# ('e9c4c6de-b2f9-4c19-a542-9983c66b40ec', 'android', '95', '82', 'None', '9.55', datetime.date(2022, 12, 29))
# ('3542a998-0a52-47f6-8358-cb6208c0a697', 'ios', '59', '69', 'FR', '0.2.8', datetime.date(2022, 12, 29))
# ('81118a3c-d266-44b6-b2b2-f9282f4bda96', 'ios', '36', '86', 'VN', '2.20', datetime.date(2022, 12, 29))
# ('3a50f8e7-2adf-4e60-88d3-7c1be36d7b31', 'android', '86', '19', 'CN', '0.9.6', datetime.date(2022, 12, 29))
# ('38a51835-f48d-471b-93a8-66f267ab1e84', 'ios', '14', '3', 'None', '0.8.3', datetime.date(2022, 12, 29))
# ('111ce02d-6cd1-407a-9a29-bb181145e321', 'ios', '89', '50', 'None', '0.8.3', datetime.date(2022, 12, 29))
# ('98ce1d36-2212-4e1b-bb58-a7ed0911fa49', 'ios', '90', '58', 'PT', '0.8.8', datetime.date(2022, 12, 29))
# ('82031930-ab99-4ad1-8276-1800cd19ed01', 'android', '93', '18', 'ID', '2.29', datetime.date(2022, 12, 29))
# ('94191e2f-4314-4cba-aa38-e662af631842', 'ios', '44', '66', 'DE', '2.8', datetime.date(2022, 12, 29))
# ('e97a928b-ed83-4957-96b3-b4ae07b1be72', 'ios', '58', '77', 'None', '3.44', datetime.date(2022, 12, 29))
# ('ae8dfd5a-31b7-4e69-8ef3-d32aac1d191f', 'android', '92', '47', 'PL', '0.3.4', datetime.date(2022, 12, 29))
# ('641b82c1-951f-49ca-8100-617a2b82b5ee', 'ios', '56', '80', 'DE', '8.6.5', datetime.date(2022, 12, 29))
# ('7c65bbae-0174-41df-ab26-44915fb616a8', 'android', '51', '83', 'FR', '8.7', datetime.date(2022, 12, 29))
# ('2ad5985b-dc70-44ca-b3ed-f4246a42f611', 'android', '57', '24', 'PT', '1.35', datetime.date(2022, 12, 29))
# ('ca322b6c-97f8-4075-9663-42cebeb1d26e', 'android', '61', '94', 'BG', '0.38', datetime.date(2022, 12, 29))
# ('d4f4f380-349e-48ac-bdc3-5ee4e29b57c1', 'ios', '40', '32', 'FR', '3.2.0', datetime.date(2022, 12, 29))
# ('792e3e1f-bf84-409e-925c-d653fab4b6be', 'ios', '23', '4', 'TH', '1.4', datetime.date(2022, 12, 29))
# ('4e216e8b-1682-4bc0-9b47-0777b4a77a9e', 'ios', '94', '45', 'None', '6.88', datetime.date(2022, 12, 29))
