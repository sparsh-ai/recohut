# %%
import pandas as pd

# %%
df = pd.read_csv("s3://wysde-datasets/acled/2022-09-01-2022-10-26.csv", sep=";")
df
# Out:
#        data_id  iso event_id_cnty  event_id_no_cnty         event_date  year  \
# 0      9579881   32      ARG11482             11482    21 October 2022  2022
# 1      9579910   76      BRA58814             58814    21 October 2022  2022
# 2      9579910   76      BRA58814             58814    21 October 2022  2022
# 3      9579922   76      BRA58863             58863    21 October 2022  2022
# 4      9579922   76      BRA58863             58863    21 October 2022  2022
# ...        ...  ...           ...               ...                ...   ...
# 58953  9582833  204        BEN752               752  01 September 2022  2022
# 58954  9586439  250      FRA18524             18524  01 September 2022  2022
# 58955  9586913  276      DEU13054             13054  01 September 2022  2022
# 58956  9587718  840      USA47383             47383  01 September 2022  2022
# 58957  9591023  380      ITA16662             16662  01 September 2022  2022
#
#        time_precision              event_type                sub_event_type  \
# 0                   1                Protests              Peaceful protest
# 1                   1                 Battles                   Armed clash
# 2                   1                 Battles                   Armed clash
# 3                   1                 Battles                   Armed clash
# 4                   1                 Battles                   Armed clash
# ...               ...                     ...                           ...
# 58953               2  Strategic developments  Looting/property destruction
# 58954               1                Protests              Peaceful protest
# 58955               2                Protests              Peaceful protest
# 58956               1                Protests              Peaceful protest
# 58957               1                Protests              Peaceful protest
#
#                                                   actor1  ...  \
# 0                                 Protesters (Argentina)  ...
# 1                Unidentified Gang and/or Police Militia  ...
# 2      Military Forces of Brazil (2019-) Military Police  ...
# 3                Unidentified Gang and/or Police Militia  ...
# 4      Military Forces of Brazil (2019-) Military Police  ...
# ...                                                  ...  ...
# 58953                                  Civilians (Benin)  ...
# 58954                                Protesters (France)  ...
# 58955                               Protesters (Germany)  ...
# 58956                         Protesters (United States)  ...
# 58957                                 Protesters (Italy)  ...
#
#                          location  latitude  longitude geo_precision  \
# 0                      Santa Rosa  -36.6205   -64.2899             1
# 1                         Niteroi  -22.8833   -43.1036             1
# 2                         Niteroi  -22.8833   -43.1036             1
# 3      Rio de Janeiro - West Zone  -22.9147   -43.4879             1
# 4      Rio de Janeiro - West Zone  -22.9147   -43.4879             1
# ...                           ...       ...        ...           ...
# 58953                       Nikki    9.9400     3.2108             1
# 58954                     Mauriac   44.7455    -0.0294             1
# 58955                 Cloppenburg   52.8461     8.0439             1
# 58956                  Fort Worth   32.7254   -97.3209             1
# 58957         Cividale del Friuli   46.0944    13.4304             1
#
#                                                   source         source_scale  \
# 0                        El Diario De La Pampa; La Arena          Subnational
# 1                           Informe Agora; O Sao Goncalo          Subnational
# 2                           Informe Agora; O Sao Goncalo          Subnational
# 3                             Globo Extra; Informe Agora          Subnational
# 4                             Globo Extra; Informe Agora          Subnational
# ...                                                  ...                  ...
# 58953                                 Undisclosed Source  Local partner-Other
# 58954                                               Actu             National
# 58955                                         NWZ Online             National
# 58956  Dallas Morning News; CBS11 (Fort Worth-Dallas)...          Subnational
# 58957                                          Il Friuli             National
#
#                                                    notes fatalities  \
# 0      On 21 October 2022, in Santa Rosa (La Pampa), ...          0
# 1      On 21 October 2022, in Niteroi - (Rio de Janei...          0
# 2      On 21 October 2022, in Niteroi - (Rio de Janei...          0
# 3      On 21 October 2022, in Rio de Janeiro - West Z...          1
# 4      On 21 October 2022, in Rio de Janeiro - West Z...          1
# ...                                                  ...        ...
# 58953  Land seizure: Around 1 September 2022 (as repo...          0
# 58954  On 1 September 2022, an unknown number of teac...          0
# 58955  Around 1 September 2022 (as reported), around ...          0
# 58956  On 1 September 2022, around 300 American Airli...          0
# 58957  On 1 September 2022, people gathered in Civida...          0
#
#         timestamp  iso3
# 0      1666629793   ARG
# 1      1666629793   BRA
# 2      1666629793   BRA
# 3      1666629793   BRA
# 4      1666629793   BRA
# ...           ...   ...
# 58953  1666650602   BEN
# 58954  1666715220   FRA
# 58955  1666715221   DEU
# 58956  1666718005   USA
# 58957  1666732465   ITA
#
# [58958 rows x 28 columns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58958 entries, 0 to 58957
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   data_id           58958 non-null  int64
#  1   iso               58958 non-null  int64
#  2   event_id_cnty     58958 non-null  object
#  3   event_id_no_cnty  58958 non-null  int64
#  4   event_date        58958 non-null  object
#  5   year              58958 non-null  int64
#  6   time_precision    58958 non-null  int64
#  7   event_type        58958 non-null  object
#  8   sub_event_type    58958 non-null  object
#  9   actor1            58958 non-null  object
#  10  assoc_actor_1     22061 non-null  object
#  11  inter1            58958 non-null  int64
#  12  interaction       58958 non-null  int64
#  13  region            58958 non-null  object
#  14  country           58958 non-null  object
#  15  admin1            58935 non-null  object
#  16  admin2            57770 non-null  object
#  17  admin3            33151 non-null  object
#  18  location          58958 non-null  object
#  19  latitude          58958 non-null  float64
#  20  longitude         58958 non-null  float64
#  21  geo_precision     58958 non-null  int64
#  22  source            58958 non-null  object
#  23  source_scale      58958 non-null  object
#  24  notes             58958 non-null  object
#  25  fatalities        58958 non-null  int64
#  26  timestamp         58958 non-null  int64
#  27  iso3              58958 non-null  object
# dtypes: float64(2), int64(10), object(16)
# memory usage: 12.6+ MB

# %%
df['event_date'] = pd.to_datetime(df['event_date'])
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 58958 entries, 0 to 58957
# Data columns (total 28 columns):
#  #   Column            Non-Null Count  Dtype
# ---  ------            --------------  -----
#  0   data_id           58958 non-null  int64
#  1   iso               58958 non-null  int64
#  2   event_id_cnty     58958 non-null  object
#  3   event_id_no_cnty  58958 non-null  int64
#  4   event_date        58958 non-null  datetime64[ns]
#  5   year              58958 non-null  int64
#  6   time_precision    58958 non-null  int64
#  7   event_type        58958 non-null  object
#  8   sub_event_type    58958 non-null  object
#  9   actor1            58958 non-null  object
#  10  assoc_actor_1     22061 non-null  object
#  11  inter1            58958 non-null  int64
#  12  interaction       58958 non-null  int64
#  13  region            58958 non-null  object
#  14  country           58958 non-null  object
#  15  admin1            58935 non-null  object
#  16  admin2            57770 non-null  object
#  17  admin3            33151 non-null  object
#  18  location          58958 non-null  object
#  19  latitude          58958 non-null  float64
#  20  longitude         58958 non-null  float64
#  21  geo_precision     58958 non-null  int64
#  22  source            58958 non-null  object
#  23  source_scale      58958 non-null  object
#  24  notes             58958 non-null  object
#  25  fatalities        58958 non-null  int64
#  26  timestamp         58958 non-null  int64
#  27  iso3              58958 non-null  object
# dtypes: datetime64[ns](1), float64(2), int64(10), object(15)
# memory usage: 12.6+ MB

# %%
df.head()
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty event_date  year  \
# 0  9579881   32      ARG11482             11482 2022-10-21  2022
# 1  9579910   76      BRA58814             58814 2022-10-21  2022
# 2  9579910   76      BRA58814             58814 2022-10-21  2022
# 3  9579922   76      BRA58863             58863 2022-10-21  2022
# 4  9579922   76      BRA58863             58863 2022-10-21  2022
#
#    time_precision event_type    sub_event_type  \
# 0               1   Protests  Peaceful protest
# 1               1    Battles       Armed clash
# 2               1    Battles       Armed clash
# 3               1    Battles       Armed clash
# 4               1    Battles       Armed clash
#
#                                               actor1  ...  \
# 0                             Protesters (Argentina)  ...
# 1            Unidentified Gang and/or Police Militia  ...
# 2  Military Forces of Brazil (2019-) Military Police  ...
# 3            Unidentified Gang and/or Police Militia  ...
# 4  Military Forces of Brazil (2019-) Military Police  ...
#
#                      location  latitude  longitude geo_precision  \
# 0                  Santa Rosa  -36.6205   -64.2899             1
# 1                     Niteroi  -22.8833   -43.1036             1
# 2                     Niteroi  -22.8833   -43.1036             1
# 3  Rio de Janeiro - West Zone  -22.9147   -43.4879             1
# 4  Rio de Janeiro - West Zone  -22.9147   -43.4879             1
#
#                             source source_scale  \
# 0  El Diario De La Pampa; La Arena  Subnational
# 1     Informe Agora; O Sao Goncalo  Subnational
# 2     Informe Agora; O Sao Goncalo  Subnational
# 3       Globo Extra; Informe Agora  Subnational
# 4       Globo Extra; Informe Agora  Subnational
#
#                                                notes fatalities   timestamp  \
# 0  On 21 October 2022, in Santa Rosa (La Pampa), ...          0  1666629793
# 1  On 21 October 2022, in Niteroi - (Rio de Janei...          0  1666629793
# 2  On 21 October 2022, in Niteroi - (Rio de Janei...          0  1666629793
# 3  On 21 October 2022, in Rio de Janeiro - West Z...          1  1666629793
# 4  On 21 October 2022, in Rio de Janeiro - West Z...          1  1666629793
#
#    iso3
# 0   ARG
# 1   BRA
# 2   BRA
# 3   BRA
# 4   BRA
#
# [5 rows x 28 columns]

# %%
import boto3
import json
import pandas as pd

from sqlalchemy import create_engine
import psycopg2


def get_secret(secret_name):
    region_name = "us-east-1"
    session = boto3.session.Session()
    client = session.client(
        service_name='secretsmanager',
        region_name=region_name)
    get_secret_value_response = client.get_secret_value(SecretId=secret_name)
    get_secret_value_response = json.loads(get_secret_value_response['SecretString'])
    return get_secret_value_response

db_credentials = get_secret(secret_name='wysde')

USERNAME = db_credentials["RDS_POSTGRES_USERNAME"]
PASSWORD = db_credentials["RDS_POSTGRES_PASSWORD"]
HOST = db_credentials["RDS_POSTGRES_HOST"]
PORT = 5432
DBNAME = "postgres"
CONN = f"postgresql://{USERNAME}:{PASSWORD}@{HOST}:{PORT}/{DBNAME}"

# %%
# load the data into our postgres database
alchemyEngine = create_engine(CONN, pool_recycle=3600);
postgreSQLConnection = alchemyEngine.connect();

# %%
df.to_sql('acled', postgreSQLConnection, if_exists='replace', index=False)
# Out:
# 958

# %%
import os
from datetime import datetime, timedelta
from time import strftime
import requests
import psycopg2

from pyspark import SparkConf
from pyspark.sql import SparkSession
from pyspark.sql import functions as F
from pyspark.sql.types import StructType

# %%
engine = create_engine(CONN)

# %%
date = "2022-10-02"

# %%
df = pd.read_sql_query(f"SELECT * FROM acled where date(event_date)='{date}' limit 10", engine)
df
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty event_date  year  \
# 0  9560194  332       HTI3528              3528 2022-10-02  2022
# 1  9561338  804      UKR75456             75456 2022-10-02  2022
# 2  9561731  804      UKR75540             75540 2022-10-02  2022
# 3  9561741  804      UKR75541             75541 2022-10-02  2022
# 4  9561747  804      UKR75630             75630 2022-10-02  2022
# 5  9562054  804      UKR75646             75646 2022-10-02  2022
# 6  9562092  804      UKR75373             75373 2022-10-02  2022
# 7  9563243  760     SYR106291            106291 2022-10-02  2022
# 8  9557035   36       AUS1294              1294 2022-10-02  2022
# 9  9556906   36       AUS1283              1283 2022-10-02  2022
#
#    time_precision                  event_type  \
# 0               1                     Battles
# 1               1  Explosions/Remote violence
# 2               1  Explosions/Remote violence
# 3               1  Explosions/Remote violence
# 4               1  Explosions/Remote violence
# 5               1  Explosions/Remote violence
# 6               1      Strategic developments
# 7               3  Violence against civilians
# 8               1                    Protests
# 9               1                    Protests
#
#                       sub_event_type                              actor1  ...  \
# 0                        Armed clash      Police Forces of Haiti (2017-)  ...
# 1      Remote explosive/landmine/IED                 Civilians (Ukraine)  ...
# 2  Shelling/artillery/missile attack   Military Forces of Russia (2000-)  ...
# 3  Shelling/artillery/missile attack   Military Forces of Russia (2000-)  ...
# 4  Shelling/artillery/missile attack   Military Forces of Russia (2000-)  ...
# 5  Shelling/artillery/missile attack   Military Forces of Russia (2000-)  ...
# 6              Disrupted weapons use  Military Forces of Ukraine (2019-)  ...
# 7                             Attack                   Civilians (Syria)  ...
# 8                   Peaceful protest              Protesters (Australia)  ...
# 9                   Peaceful protest              Protesters (Australia)  ...
#
#                    location  latitude  longitude geo_precision  \
# 0  Port-au-Prince - Tabarre   18.5833   -72.2667             1
# 1                  Okhtyrka   50.3104    34.8988             2
# 2               Klischiivka   48.5279    37.9582             1
# 3             Krasnohorivka   48.2067    37.7244             1
# 4                 Kurakhove   47.9836    37.2823             2
# 5                 Pysarivka   51.0810    34.8228             2
# 6                  Mykolaiv   46.9672    32.0183             1
# 7            Sheikh Miskine   32.8310    36.1575             2
# 8                    Darwin  -12.4427   130.8447             1
# 9       Melbourne - Western  -37.7984   144.7709             1
#
#                                               source     source_scale  \
# 0                                     Le Nouvelliste         National
# 1                                         24 Channel         National
# 2                     Ministry of Defence of Ukraine            Other
# 3                     Ministry of Defence of Ukraine            Other
# 4                     Ministry of Defence of Ukraine            Other
# 5                     Ministry of Defence of Ukraine            Other
# 6                     Ministry of Defence of Ukraine            Other
# 7                                     Facebook; SOHR  Other-New media
# 8                            Northern Territory News      Subnational
# 9  Australian Broadcasting Corporation News; Soli...   Other-National
#
#                                                notes fatalities   timestamp  \
# 0  On 2 October 2022, in Port-au-Prince - Tabarre...          1  1665502509
# 1  On 2 October 2022, a car blew up on a Russian ...          1  1665508788
# 2  On 2 October 2022, Russian forces shelled Klis...          0  1665508789
# 3  On 2 October 2022, Russian forces shelled Kras...          0  1665508789
# 4  On 2 October 2022, Russian forces shelled near...          0  1665508789
# 5  On 2 October 2022, Russian forces shelled near...          0  1665508790
# 6  Interception: On 2 October 2022, Ukrainian for...          0  1665508790
# 7  Around 2 October 2022 (as reported), the body ...          1  1665512567
# 8  On 2 October 2022, at least 30 bus drivers aff...          0  1665495151
# 9  On 2 October 2022, 35 Qenos petrochemical plan...          0  1665495151
#
#    iso3
# 0   HTI
# 1   UKR
# 2   UKR
# 3   UKR
# 4   UKR
# 5   UKR
# 6   UKR
# 7   SYR
# 8   AUS
# 9   AUS
#
# [10 rows x 28 columns]

# %%
df2 = pd.read_sql_query(f"SELECT * FROM acled where event_date > '{date}'::date - '10 days'::interval and event_date <= '{date}'::date limit 10", engine)
df2
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty event_date  year  \
# 0  9579881   32      ARG11482             11482 2022-10-21  2022
# 1  9579910   76      BRA58814             58814 2022-10-21  2022
# 2  9579910   76      BRA58814             58814 2022-10-21  2022
# 3  9579922   76      BRA58863             58863 2022-10-21  2022
# 4  9579922   76      BRA58863             58863 2022-10-21  2022
# 5  9579946  170      COL17984             17984 2022-10-21  2022
# 6  9579948  170      COL17987             17987 2022-10-21  2022
# 7  9579964  862      VEN13154             13154 2022-10-21  2022
# 8  9579965  862      VEN13155             13155 2022-10-21  2022
# 9  9580009  152       CHI9521              9521 2022-10-21  2022
#
#    time_precision event_type         sub_event_type  \
# 0               1   Protests       Peaceful protest
# 1               1    Battles            Armed clash
# 2               1    Battles            Armed clash
# 3               1    Battles            Armed clash
# 4               1    Battles            Armed clash
# 5               1   Protests       Peaceful protest
# 6               1      Riots  Violent demonstration
# 7               1   Protests       Peaceful protest
# 8               1   Protests       Peaceful protest
# 9               1   Protests       Peaceful protest
#
#                                               actor1  ...  \
# 0                             Protesters (Argentina)  ...
# 1            Unidentified Gang and/or Police Militia  ...
# 2  Military Forces of Brazil (2019-) Military Police  ...
# 3            Unidentified Gang and/or Police Militia  ...
# 4  Military Forces of Brazil (2019-) Military Police  ...
# 5                              Protesters (Colombia)  ...
# 6                                 Rioters (Colombia)  ...
# 7                             Protesters (Venezuela)  ...
# 8                             Protesters (Venezuela)  ...
# 9                                 Protesters (Chile)  ...
#
#                      location  latitude  longitude geo_precision  \
# 0                  Santa Rosa  -36.6205   -64.2899             1
# 1                     Niteroi  -22.8833   -43.1036             1
# 2                     Niteroi  -22.8833   -43.1036             1
# 3  Rio de Janeiro - West Zone  -22.9147   -43.4879             1
# 4  Rio de Janeiro - West Zone  -22.9147   -43.4879             1
# 5                  San Onofre    9.7410   -75.5202             2
# 6                      Galapa   10.9196   -74.8669             2
# 7                   El Dorado    6.7150   -61.6369             1
# 8                    Tumeremo    7.2986   -61.5050             1
# 9                    Santiago  -33.4569   -70.6483             1
#
#                                            source source_scale  \
# 0                 El Diario De La Pampa; La Arena  Subnational
# 1                    Informe Agora; O Sao Goncalo  Subnational
# 2                    Informe Agora; O Sao Goncalo  Subnational
# 3                      Globo Extra; Informe Agora  Subnational
# 4                      Globo Extra; Informe Agora  Subnational
# 5  El Universal (Colombia); El Heraldo (Colombia)     National
# 6     El Tiempo (Colombia); El Heraldo (Colombia)     National
# 7                           El Pitazo; La Patilla     National
# 8                           La Patilla; El Pitazo     National
# 9                                    Biobio Chile     National
#
#                                                notes fatalities   timestamp  \
# 0  On 21 October 2022, in Santa Rosa (La Pampa), ...          0  1666629793
# 1  On 21 October 2022, in Niteroi - (Rio de Janei...          0  1666629793
# 2  On 21 October 2022, in Niteroi - (Rio de Janei...          0  1666629793
# 3  On 21 October 2022, in Rio de Janeiro - West Z...          1  1666629793
# 4  On 21 October 2022, in Rio de Janeiro - West Z...          1  1666629793
# 5  On 21 October 2022, near San Onofre municipali...          0  1666629793
# 6  On 21 October 2022, between Galapa and Barranq...          0  1666629793
# 7  On 21 October 2022, in El Dorado (Bolivar), mi...          0  1666629793
# 8  On 21 October 2022, in Tumeremo (Bolivar), min...          0  1666629793
# 9  On 21 October 2022, in Santiago (Metropolitana...          0  1666629793
#
#    iso3
# 0   ARG
# 1   BRA
# 2   BRA
# 3   BRA
# 4   BRA
# 5   COL
# 6   COL
# 7   VEN
# 8   VEN
# 9   CHL
#
# [10 rows x 28 columns]

# %%
df2.event_date.value_counts()
# Out:
# 2022-10-21    10
# Name: event_date, dtype: int64

# %%
aws_access_key = os.getenv("AWS_ACCESS_KEY")
aws_secret_key = os.getenv("AWS_SECRET_KEY")

conf = SparkConf()
conf.set('spark.jars.packages', 'org.apache.hadoop:hadoop-aws:3.3.4')
conf.set('spark.hadoop.fs.s3a.aws.credentials.provider', 'org.apache.hadoop.fs.s3a.SimpleAWSCredentialsProvider')
conf.set('spark.hadoop.fs.s3a.access.key', aws_access_key)
conf.set('spark.hadoop.fs.s3a.secret.key', aws_secret_key)

spark = SparkSession.builder.config(conf=conf).getOrCreate()

# %%
dataframe = spark.createDataFrame(df)

# %%
dataframe.toPandas()
# Out:
#    data_id  iso event_id_cnty  event_id_no_cnty event_date  year  \
# 0  9560194  332       HTI3528              3528 2022-10-02  2022
# 1  9561338  804      UKR75456             75456 2022-10-02  2022
# 2  9561731  804      UKR75540             75540 2022-10-02  2022
# 3  9561741  804      UKR75541             75541 2022-10-02  2022
# 4  9561747  804      UKR75630             75630 2022-10-02  2022
# 5  9562054  804      UKR75646             75646 2022-10-02  2022
# 6  9562092  804      UKR75373             75373 2022-10-02  2022
# 7  9563243  760     SYR106291            106291 2022-10-02  2022
# 8  9557035   36       AUS1294              1294 2022-10-02  2022
# 9  9556906   36       AUS1283              1283 2022-10-02  2022
#
#    time_precision                  event_type  \
# 0               1                     Battles
# 1               1  Explosions/Remote violence
# 2               1  Explosions/Remote violence
# 3               1  Explosions/Remote violence
# 4               1  Explosions/Remote violence
# 5               1  Explosions/Remote violence
# 6               1      Strategic developments
# 7               3  Violence against civilians
# 8               1                    Protests
# 9               1                    Protests
#
#                       sub_event_type                              actor1  ...  \
# 0                        Armed clash      Police Forces of Haiti (2017-)  ...
# 1      Remote explosive/landmine/IED                 Civilians (Ukraine)  ...
# 2  Shelling/artillery/missile attack   Military Forces of Russia (2000-)  ...
# 3  Shelling/artillery/missile attack   Military Forces of Russia (2000-)  ...
# 4  Shelling/artillery/missile attack   Military Forces of Russia (2000-)  ...
# 5  Shelling/artillery/missile attack   Military Forces of Russia (2000-)  ...
# 6              Disrupted weapons use  Military Forces of Ukraine (2019-)  ...
# 7                             Attack                   Civilians (Syria)  ...
# 8                   Peaceful protest              Protesters (Australia)  ...
# 9                   Peaceful protest              Protesters (Australia)  ...
#
#                    location  latitude  longitude geo_precision  \
# 0  Port-au-Prince - Tabarre   18.5833   -72.2667             1
# 1                  Okhtyrka   50.3104    34.8988             2
# 2               Klischiivka   48.5279    37.9582             1
# 3             Krasnohorivka   48.2067    37.7244             1
# 4                 Kurakhove   47.9836    37.2823             2
# 5                 Pysarivka   51.0810    34.8228             2
# 6                  Mykolaiv   46.9672    32.0183             1
# 7            Sheikh Miskine   32.8310    36.1575             2
# 8                    Darwin  -12.4427   130.8447             1
# 9       Melbourne - Western  -37.7984   144.7709             1
#
#                                               source     source_scale  \
# 0                                     Le Nouvelliste         National
# 1                                         24 Channel         National
# 2                     Ministry of Defence of Ukraine            Other
# 3                     Ministry of Defence of Ukraine            Other
# 4                     Ministry of Defence of Ukraine            Other
# 5                     Ministry of Defence of Ukraine            Other
# 6                     Ministry of Defence of Ukraine            Other
# 7                                     Facebook; SOHR  Other-New media
# 8                            Northern Territory News      Subnational
# 9  Australian Broadcasting Corporation News; Soli...   Other-National
#
#                                                notes fatalities   timestamp  \
# 0  On 2 October 2022, in Port-au-Prince - Tabarre...          1  1665502509
# 1  On 2 October 2022, a car blew up on a Russian ...          1  1665508788
# 2  On 2 October 2022, Russian forces shelled Klis...          0  1665508789
# 3  On 2 October 2022, Russian forces shelled Kras...          0  1665508789
# 4  On 2 October 2022, Russian forces shelled near...          0  1665508789
# 5  On 2 October 2022, Russian forces shelled near...          0  1665508790
# 6  Interception: On 2 October 2022, Ukrainian for...          0  1665508790
# 7  Around 2 October 2022 (as reported), the body ...          1  1665512567
# 8  On 2 October 2022, at least 30 bus drivers aff...          0  1665495151
# 9  On 2 October 2022, 35 Qenos petrochemical plan...          0  1665495151
#
#    iso3
# 0   HTI
# 1   UKR
# 2   UKR
# 3   UKR
# 4   UKR
# 5   UKR
# 6   UKR
# 7   SYR
# 8   AUS
# 9   AUS
#
# [10 rows x 28 columns]
