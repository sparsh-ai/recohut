# %%
import boto3
import json

# %%
# %config SqlMagic.autopandas=True
# %config SqlMagic.displaycon=False
# %config SqlMagic.feedback=False
# %config SqlMagic.displaylimit=5
# %reload_ext sql

# %%
def get_secret(secret_name, region_name="us-east-1"):
    session = boto3.session.Session()
    client = session.client(
        service_name='secretsmanager',
        region_name=region_name)
    get_secret_value_response = client.get_secret_value(SecretId=secret_name)
    get_secret_value_response = json.loads(get_secret_value_response['SecretString'])
    return get_secret_value_response

# %%
secret_vals = get_secret("wysde")

postgres_endpoint = secret_vals['RDS_POSTGRES_HOST']
postgres_user = secret_vals['RDS_POSTGRES_USERNAME']
postgres_pass = secret_vals['RDS_POSTGRES_PASSWORD']
port = secret_vals['RDS_POSTGRES_PORT']
dbname = "sparsh"

conn = "postgresql+psycopg2://%s:%s@%s:%s/%s" \
% (postgres_user, postgres_pass, postgres_endpoint, port, dbname)

# %%
# %sql {conn}

# %% [markdown]
# ## Daily Product Revenue

# %%
# %%sql
#
# SELECT
#     o.order_date,
#     oi.order_item_product_id,
#     p.product_name,
#     round(sum(oi.order_item_subtotal::numeric),2) AS product_revenue
# FROM orders o
#     JOIN order_items oi
#         ON o.order_id = oi.order_item_order_id
#     JOIN products p
#         ON p.product_id = oi.order_item_product_id
# WHERE
# o.order_status IN ('COMPLETE', 'CLOSED')
# GROUP BY
# o.order_date,
# oi.order_item_product_id,
# p.product_name
# LIMIT 10
# Out:
#   order_date  order_item_product_id  \
# 0 2013-07-25                     24
# 1 2013-07-25                     93
# 2 2013-07-25                    134
# 3 2013-07-25                    191
# 4 2013-07-25                    226
# 5 2013-07-25                    365
# 6 2013-07-25                    403
# 7 2013-07-25                    502
# 8 2013-07-25                    572
# 9 2013-07-25                    625
#
#                                    product_name product_revenue
# 0                   Elevation Training Mask 2.0          319.96
# 1            Under Armour Men's Tech II T-Shirt           74.97
# 2            Nike Women's Legend V-Neck T-Shirt          100.00
# 3             Nike Men's Free 5.0+ Running Shoe         5099.49
# 4             Bowflex SelectTech 1090 Dumbbells          599.99
# 5              Perfect Fitness Perfect Rip Deck         3359.44
# 6       Nike Men's CJ Elite 2 TD Football Cleat         1949.85
# 7          Nike Men's Dri-FIT Victory Golf Polo         1650.00
# 8                    TYR Boys' Team Digi Jammer          119.97
# 9  Nike Men's Kobe IX Elite Low Basketball Shoe          199.99

# %% [markdown]
# ### Exercise 1 - Customer order count
#
# Get order count per customer for the month of 2014 January.
#
# Tables - orders and customers
#
# Data should be sorted in descending order by count and ascending order by customer id.
#
# Output should contain customer_id, customer_first_name, customer_last_name and customer_order_count.

# %%
# %%sql
#
# SELECT * FROM information_schema.columns
# WHERE table_catalog = '{dbname}'
# AND table_name = 'orders'
# Out:
#   table_catalog table_schema table_name        column_name  ordinal_position  \
# 0        sparsh       public     orders           order_id                 1
# 1        sparsh       public     orders         order_date                 2
# 2        sparsh       public     orders  order_customer_id                 3
# 3        sparsh       public     orders       order_status                 4
#
#   column_default is_nullable                    data_type  \
# 0           None          NO                      integer
# 1           None          NO  timestamp without time zone
# 2           None          NO                      integer
# 3           None          NO            character varying
#
#    character_maximum_length  character_octet_length  ...  is_identity  \
# 0                       NaN                     NaN  ...           NO
# 1                       NaN                     NaN  ...           NO
# 2                       NaN                     NaN  ...           NO
# 3                      45.0                   180.0  ...           NO
#
#    identity_generation  identity_start  identity_increment identity_maximum  \
# 0                 None            None                None             None
# 1                 None            None                None             None
# 2                 None            None                None             None
# 3                 None            None                None             None
#
#   identity_minimum identity_cycle is_generated generation_expression  \
# 0             None             NO        NEVER                  None
# 1             None             NO        NEVER                  None
# 2             None             NO        NEVER                  None
# 3             None             NO        NEVER                  None
#
#   is_updatable
# 0          YES
# 1          YES
# 2          YES
# 3          YES
#
# [4 rows x 44 columns]

# %%
# %%sql
# SELECT DISTINCT table_schema, table_name
# FROM information_schema.columns
# WHERE table_catalog = '{dbname}'
# AND table_schema = 'public'
# Out:
#   table_schema        table_name
# 0       public       DimCustomer
# 1       public        categories
# 2       public          DimMonth
# 3       public  taxi_zone_lookup
# 4       public       order_items
# 5       public          products
# 6       public       FactBilling
# 7       public            orders
# 8       public         customers
# 9       public       departments

# %%
# %%sql
#
# SELECT * FROM information_schema.columns
# WHERE table_catalog = '{dbname}'
# AND table_name = 'customers'
# Out:
#   table_catalog table_schema table_name        column_name  ordinal_position  \
# 0        sparsh       public  customers        customer_id                 1
# 1        sparsh       public  customers     customer_fname                 2
# 2        sparsh       public  customers     customer_lname                 3
# 3        sparsh       public  customers     customer_email                 4
# 4        sparsh       public  customers  customer_password                 5
# 5        sparsh       public  customers    customer_street                 6
# 6        sparsh       public  customers      customer_city                 7
# 7        sparsh       public  customers     customer_state                 8
# 8        sparsh       public  customers   customer_zipcode                 9
#
#   column_default is_nullable          data_type  character_maximum_length  \
# 0           None          NO            integer                       NaN
# 1           None          NO  character varying                      45.0
# 2           None          NO  character varying                      45.0
# 3           None          NO  character varying                      45.0
# 4           None          NO  character varying                      45.0
# 5           None          NO  character varying                     255.0
# 6           None          NO  character varying                      45.0
# 7           None          NO  character varying                      45.0
# 8           None          NO  character varying                      45.0
#
#    character_octet_length  ...  is_identity  identity_generation  \
# 0                     NaN  ...           NO                 None
# 1                   180.0  ...           NO                 None
# 2                   180.0  ...           NO                 None
# 3                   180.0  ...           NO                 None
# 4                   180.0  ...           NO                 None
# 5                  1020.0  ...           NO                 None
# 6                   180.0  ...           NO                 None
# 7                   180.0  ...           NO                 None
# 8                   180.0  ...           NO                 None
#
#    identity_start identity_increment identity_maximum identity_minimum  \
# 0            None               None             None             None
# 1            None               None             None             None
# 2            None               None             None             None
# 3            None               None             None             None
# 4            None               None             None             None
# 5            None               None             None             None
# 6            None               None             None             None
# 7            None               None             None             None
# 8            None               None             None             None
#
#   identity_cycle is_generated generation_expression is_updatable
# 0             NO        NEVER                  None          YES
# 1             NO        NEVER                  None          YES
# 2             NO        NEVER                  None          YES
# 3             NO        NEVER                  None          YES
# 4             NO        NEVER                  None          YES
# 5             NO        NEVER                  None          YES
# 6             NO        NEVER                  None          YES
# 7             NO        NEVER                  None          YES
# 8             NO        NEVER                  None          YES
#
# [9 rows x 44 columns]

# %%
# %%sql
#
# SELECT
#     c.customer_id,
#     c.customer_fname,
#     c.customer_lname,
#     COUNT(o.order_id) AS customer_order_count
# FROM orders o
# JOIN customers c
#     ON o.order_customer_id = c.customer_id
# WHERE
# o.order_date >= '01-01-2014' AND o.order_date < '01-02-2014'
# GROUP BY
#     c.customer_id,
#     c.customer_fname,
#     c.customer_lname
# ORDER BY
#     customer_order_count DESC,
#     customer_id ASC
# LIMIT 20;
# Out:
#     customer_id customer_fname customer_lname  customer_order_count
# 0          3099       Brittany       Copeland                     2
# 1           206           Mary           West                     1
# 2           224           Mary      Hernandez                     1
# 3           279           Anna          Smith                     1
# 4           297      Catherine          Smith                     1
# 5           363       Jennifer         Obrien                     1
# 6           387           Mary           Levy                     1
# 7           470           Mary         Cannon                     1
# 8           492           Mary       Mckinney                     1
# 9           505           Mary          Smith                     1
# 10          522        William          Smith                     1
# 11          859        Dorothy        Hawkins                     1
# 12         1044          Linda           Pope                     1
# 13         1117         Arthur         Maddox                     1
# 14         1132       Samantha          Smith                     1
# 15         1133        Tiffany           Ryan                     1
# 16         1451           Mary        Harding                     1
# 17         1512           Mary           Rowe                     1
# 18         1708       Margaret          Booth                     1
# 19         1815        Russell          Smith                     1

# %% [markdown]
# ### Exercise 2 – Dormant Customers
#
# Get the customer details who have not placed any order for the month of 2014 January.
#
# Tables – orders and customers
#
# Data should be sorted in ascending order by customer_id
#
# Output should contain all the fields from customers

# %%
# %%sql
#
# select c.*
# FROM customers c LEFT OUTER JOIN
#     (SELECT DISTINCT order_customer_id
#      FROM orders WHERE
#      to_char(order_date, 'yyyy-MM') = '2014-01'
#     ) o
#     ON c.customer_id = o.order_customer_id
# WHERE  o.order_customer_id IS NULL
# ORDER BY c.customer_id
# LIMIT 10
# Out:
#    customer_id customer_fname customer_lname customer_email customer_password  \
# 0            1        Richard      Hernandez      XXXXXXXXX         XXXXXXXXX
# 1            2           Mary        Barrett      XXXXXXXXX         XXXXXXXXX
# 2            3            Ann          Smith      XXXXXXXXX         XXXXXXXXX
# 3            4           Mary          Jones      XXXXXXXXX         XXXXXXXXX
# 4            5         Robert         Hudson      XXXXXXXXX         XXXXXXXXX
# 5            6           Mary          Smith      XXXXXXXXX         XXXXXXXXX
# 6            9           Mary          Perez      XXXXXXXXX         XXXXXXXXX
# 7           10        Melissa          Smith      XXXXXXXXX         XXXXXXXXX
# 8           11           Mary        Huffman      XXXXXXXXX         XXXXXXXXX
# 9           12    Christopher          Smith      XXXXXXXXX         XXXXXXXXX
#
#                customer_street customer_city customer_state customer_zipcode
# 0           6303 Heather Plaza   Brownsville             TX            78521
# 1      9526 Noble Embers Ridge     Littleton             CO            80126
# 2       3422 Blue Pioneer Bend        Caguas             PR            00725
# 3           8324 Little Common    San Marcos             CA            92069
# 4       10 Crystal River Mall         Caguas             PR            00725
# 5  3151 Sleepy Quail Promenade       Passaic             NJ            07055
# 6          3616 Quaking Street        Caguas             PR            00725
# 7    8598 Harvest Beacon Plaza      Stafford             VA            22554
# 8             3169 Stony Woods        Caguas             PR            00725
# 9   5594 Jagged Embers By-pass   San Antonio             TX            78227

# %% [markdown]
# ### Exercise 3 - Revenue Per Customer
#
# Get the revenue generated by each customer for the month of 2014 January
#
# Tables - orders, order_items and customers
#
# Data should be sorted in descending order by revenue and then ascending order by customer_id
#
# Output should contain customer_id, customer_first_name, customer_last_name, customer_revenue.
#
# If there are no orders placed by customer, then the corresponding revenue for a give customer should be 0.
#
# Consider only COMPLETE and CLOSED orders

# %%
# %%sql
#
# SELECT
#     c.customer_id,
#     c.customer_fname,
#     c.customer_lname,
#     sum(round(oi.order_item_subtotal::numeric,2)) AS customer_revenue
# FROM orders o
# JOIN customers c
#     ON o.order_customer_id = c.customer_id
# JOIN order_items oi
#     ON o.order_id = oi.order_item_order_id
# WHERE
#     o.order_status IN ('COMPLETE', 'CLOSED')
#     AND to_char(o.order_date,'mm/yyyy') = '01/2014'
# GROUP BY
#     c.customer_id,
#     c.customer_fname,
#     c.customer_lname
# ORDER BY
#     customer_revenue DESC,
#     c.customer_id ASC
# LIMIT 10
# Out:
#    customer_id customer_fname customer_lname customer_revenue
# 0         2555           Mary           Long          2954.63
# 1         3465           Mary        Gardner          2929.74
# 2         3710         Ashley          Smith          2739.82
# 3         1780          Larry          Sharp          2689.65
# 4          986      Catherine        Hawkins          2629.90
# 5         9676        Theresa          Smith          2599.84
# 6         1847           Mary          Smith          2589.87
# 7        11901           Mary          Smith          2469.87
# 8         4618         Andrea          Smith          2429.82
# 9        10896       Victoria          Smith          2419.78

# %% [markdown]
# ### Exercise 4 - Revenue Per Category
#
# Get the revenue generated for each category for the month of 2014 January
#
# Tables - orders, order_items, products and categories
#
# Data should be sorted in ascending order by category_id.
#
# Output should contain all the fields from category along with the revenue as category_revenue.
#
# Consider only COMPLETE and CLOSED orders

# %%
# %%sql
#
# SELECT * FROM information_schema.columns
# WHERE table_catalog = '{dbname}'
# AND table_name = 'products'
# Out:
#   table_catalog table_schema table_name          column_name  \
# 0        sparsh       public   products           product_id
# 1        sparsh       public   products  product_category_id
# 2        sparsh       public   products         product_name
# 3        sparsh       public   products  product_description
# 4        sparsh       public   products        product_price
# 5        sparsh       public   products        product_image
#
#    ordinal_position column_default is_nullable          data_type  \
# 0                 1           None          NO            integer
# 1                 2           None          NO            integer
# 2                 3           None          NO  character varying
# 3                 4           None          NO  character varying
# 4                 5           None          NO   double precision
# 5                 6           None          NO  character varying
#
#    character_maximum_length  character_octet_length  ...  is_identity  \
# 0                       NaN                     NaN  ...           NO
# 1                       NaN                     NaN  ...           NO
# 2                      45.0                   180.0  ...           NO
# 3                     255.0                  1020.0  ...           NO
# 4                       NaN                     NaN  ...           NO
# 5                     255.0                  1020.0  ...           NO
#
#    identity_generation  identity_start identity_increment identity_maximum  \
# 0                 None            None               None             None
# 1                 None            None               None             None
# 2                 None            None               None             None
# 3                 None            None               None             None
# 4                 None            None               None             None
# 5                 None            None               None             None
#
#   identity_minimum identity_cycle is_generated generation_expression  \
# 0             None             NO        NEVER                  None
# 1             None             NO        NEVER                  None
# 2             None             NO        NEVER                  None
# 3             None             NO        NEVER                  None
# 4             None             NO        NEVER                  None
# 5             None             NO        NEVER                  None
#
#   is_updatable
# 0          YES
# 1          YES
# 2          YES
# 3          YES
# 4          YES
# 5          YES
#
# [6 rows x 44 columns]

# %%
# %%sql
# SELECT * FROM information_schema.columns
# WHERE table_catalog = '{dbname}'
# AND table_name = 'order_items'
# Out:
#   table_catalog table_schema   table_name               column_name  \
# 0        sparsh       public  order_items             order_item_id
# 1        sparsh       public  order_items       order_item_order_id
# 2        sparsh       public  order_items     order_item_product_id
# 3        sparsh       public  order_items       order_item_quantity
# 4        sparsh       public  order_items       order_item_subtotal
# 5        sparsh       public  order_items  order_item_product_price
#
#    ordinal_position column_default is_nullable         data_type  \
# 0                 1           None          NO           integer
# 1                 2           None          NO           integer
# 2                 3           None          NO           integer
# 3                 4           None          NO           integer
# 4                 5           None          NO  double precision
# 5                 6           None          NO  double precision
#
#   character_maximum_length character_octet_length  ...  is_identity  \
# 0                     None                   None  ...           NO
# 1                     None                   None  ...           NO
# 2                     None                   None  ...           NO
# 3                     None                   None  ...           NO
# 4                     None                   None  ...           NO
# 5                     None                   None  ...           NO
#
#    identity_generation  identity_start identity_increment identity_maximum  \
# 0                 None            None               None             None
# 1                 None            None               None             None
# 2                 None            None               None             None
# 3                 None            None               None             None
# 4                 None            None               None             None
# 5                 None            None               None             None
#
#   identity_minimum identity_cycle is_generated generation_expression  \
# 0             None             NO        NEVER                  None
# 1             None             NO        NEVER                  None
# 2             None             NO        NEVER                  None
# 3             None             NO        NEVER                  None
# 4             None             NO        NEVER                  None
# 5             None             NO        NEVER                  None
#
#   is_updatable
# 0          YES
# 1          YES
# 2          YES
# 3          YES
# 4          YES
# 5          YES
#
# [6 rows x 44 columns]

# %%
# %%sql
# SELECT * FROM information_schema.columns
# WHERE table_catalog = '{dbname}'
# AND table_name = 'categories'
# Out:
#   table_catalog table_schema  table_name             column_name  \
# 0        sparsh       public  categories             category_id
# 1        sparsh       public  categories  category_department_id
# 2        sparsh       public  categories           category_name
#
#    ordinal_position column_default is_nullable          data_type  \
# 0                 1           None          NO            integer
# 1                 2           None          NO            integer
# 2                 3           None          NO  character varying
#
#    character_maximum_length  character_octet_length  ...  is_identity  \
# 0                       NaN                     NaN  ...           NO
# 1                       NaN                     NaN  ...           NO
# 2                      45.0                   180.0  ...           NO
#
#    identity_generation  identity_start identity_increment identity_maximum  \
# 0                 None            None               None             None
# 1                 None            None               None             None
# 2                 None            None               None             None
#
#   identity_minimum identity_cycle is_generated generation_expression  \
# 0             None             NO        NEVER                  None
# 1             None             NO        NEVER                  None
# 2             None             NO        NEVER                  None
#
#   is_updatable
# 0          YES
# 1          YES
# 2          YES
#
# [3 rows x 44 columns]

# %%
# %%sql
#
# SELECT c.*,
#     round(sum(oi.order_item_subtotal)::numeric, 2) AS category_revenue
# FROM categories c JOIN products p
#         ON c.category_id = p.product_category_id
#     JOIN order_items oi
#         ON p.product_id = oi.order_item_product_id
#     JOIN orders o
#         ON oi.order_item_order_id = o.order_id
# WHERE to_char(o.order_date, 'yyyy-MM') = '2014-01'
#     AND o.order_status IN ('COMPLETE', 'CLOSED')
# GROUP BY c.category_id
# ORDER BY c.category_id
# LIMIT 10;
# Out:
#    category_id  category_department_id        category_name category_revenue
# 0            2                       2               Soccer          1094.88
# 1            3                       2  Baseball & Softball          3214.41
# 2            4                       2           Basketball          1299.98
# 3            5                       2             Lacrosse          1299.69
# 4            6                       2     Tennis & Racquet          1124.75
# 5            7                       2               Hockey          1433.00
# 6            9                       3     Cardio Equipment        133156.77
# 7           10                       3    Strength Training          3388.96
# 8           11                       3  Fitness Accessories          1509.73
# 9           12                       3         Boxing & MMA          3998.46

# %% [markdown]
# ### Exercise 5 - Product Count Per Department
#
# Get the products for each department.
#
# Tables - departments, categories, products
#
# Data should be sorted in ascending order by department_id
#
# Output should contain all the fields from department and the product count as product_count

# %%
# %%sql
#
# SELECT * FROM information_schema.columns
# WHERE table_catalog = '{dbname}'
# AND table_name = 'departments'
# Out:
#   table_catalog table_schema   table_name      column_name  ordinal_position  \
# 0        sparsh       public  departments    department_id                 1
# 1        sparsh       public  departments  department_name                 2
#
#   column_default is_nullable          data_type  character_maximum_length  \
# 0           None          NO            integer                       NaN
# 1           None          NO  character varying                      45.0
#
#    character_octet_length  ...  is_identity  identity_generation  \
# 0                     NaN  ...           NO                 None
# 1                   180.0  ...           NO                 None
#
#    identity_start identity_increment identity_maximum identity_minimum  \
# 0            None               None             None             None
# 1            None               None             None             None
#
#   identity_cycle is_generated generation_expression is_updatable
# 0             NO        NEVER                  None          YES
# 1             NO        NEVER                  None          YES
#
# [2 rows x 44 columns]

# %%
# %%sql
#
# SELECT
#     d.*,
#     count(p.product_id) AS product_count
# FROM departments d
# JOIN categories c
#     ON d.department_id = c.category_department_id
# JOIN products p
#     ON p.product_category_id = c.category_id
# GROUP BY
# d.department_id
# ORDER BY
# d.department_id ASC
# LIMIT 20
# Out:
#    department_id department_name  product_count
# 0              2         Fitness            168
# 1              3        Footwear            168
# 2              4         Apparel            140
# 3              5            Golf            120
# 4              6        Outdoors            336
# 5              7        Fan Shop            149
