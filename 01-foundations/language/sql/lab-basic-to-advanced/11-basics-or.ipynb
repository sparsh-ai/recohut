# %%
# %run 02-connect.ipynb

# %%
# %%sql
#
# SELECT *
# FROM billboard_top_100_year_end
# LIMIT 10;
# Out:
#      year  year_rank            group           artist  \
# 0  1956.0        1.0  "Elvis Presley"  "Elvis Presley"
# 1  1956.0        2.0  "Elvis Presley"  "Elvis Presley"
# 2  1956.0        3.0  "Nelson Riddle"  "Nelson Riddle"
# 3  1956.0        4.0       "Platters"       "Platters"
# 4  1956.0        5.0     "Gogi Grant"     "Gogi Grant"
# 5  1956.0        6.0     "Les Baxter"     "Les Baxter"
# 6  1956.0        7.0      "Doris Day"      "Doris Day"
# 7  1956.0        8.0  "Elvis Presley"  "Elvis Presley"
# 8  1956.0        9.0    "Dean Martin"    "Dean Martin"
# 9  1956.0       10.0      "Kay Starr"      "Kay Starr"
#
#                                     song_name  id
# 0                          "Heartbreak Hotel"   1
# 1                            "Don't Be Cruel"   2
# 2                            "Lisbon Antigua"   3
# 3                                 "My Prayer"   4
# 4                          "The Wayward Wind"   5
# 5                  "The Poor People Of Paris"   6
# ...

# %%
# %%sql
#
# SELECT *
# FROM billboard_top_100_year_end
# WHERE year_rank = 5 OR artist = '"Gotye"'
# LIMIT 10;
# Out:
#      year  year_rank                 group                artist  \
# 0  1956.0        5.0          "Gogi Grant"          "Gogi Grant"
# 1  1957.0        5.0        "Jimmy Dorsey"        "Jimmy Dorsey"
# 2  1958.0        5.0         "Perez Prado"         "Perez Prado"
# 3  1959.0        5.0           "Paul Anka"           "Paul Anka"
# 4  1960.0        5.0        "Mark Dinning"        "Mark Dinning"
# 5  1961.0        5.0         "Del Shannon"         "Del Shannon"
# 6  1962.0        5.0          "David Rose"          "David Rose"
# 7  1963.0        5.0            "Chiffons"            "Chiffons"
# 8  1964.0        5.0          "Beach Boys"          "Beach Boys"
# 9  1965.0        5.0  "Righteous Brothers"  "Righteous Brothers"
#
#                            song_name   id
# 0                 "The Wayward Wind"    5
# 1                          "So Rare"  108
# 2                         "Patricia"  208
# 3                       "Lonely Boy"  309
# ...

# %%
# %%sql
#
# SELECT *
# FROM billboard_top_100_year_end
# WHERE year < 2013
#     AND (artist LIKE '"%Shannon%"' OR artist LIKE '"%Prado%"')
# LIMIT 10;
# Out:
#      year  year_rank               group              artist  \
# 0  1958.0        5.0       "Perez Prado"       "Perez Prado"
# 1  1961.0        5.0       "Del Shannon"       "Del Shannon"
# 2  1961.0       68.0       "Del Shannon"       "Del Shannon"
# 3  1963.0      100.0       "Del Shannon"       "Del Shannon"
# 4  1965.0       63.0  "Jackie DeShannon"  "Jackie DeShannon"
# 5  1965.0       99.0       "Del Shannon"       "Del Shannon"
# 6  1969.0       46.0  "Jackie DeShannon"  "Jackie DeShannon"
# 7  1984.0       49.0           "Shannon"           "Shannon"
#
#                             song_name    id
# 0                          "Patricia"   208
# 1                           "Runaway"   513
# 2                 "Hats Off To Larry"   576
# 3                 "Little Town Flirt"   809
# 4  "What The World Needs Now Is Love"   974
# 5                    "Keep Searchin'"  1010
# 6   "Put A Little Love In Your Heart"  1363
# 7                "Let The Music Play"  2920
