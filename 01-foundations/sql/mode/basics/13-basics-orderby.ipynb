# %%
# %run 02-connect.ipynb

# %%
# %%sql
#
# SELECT *
# FROM billboard_top_100_year_end
# LIMIT 10;
# Out:
#      year  year_rank            group           artist  \
# 0  1956.0        1.0  "Elvis Presley"  "Elvis Presley"
# 1  1956.0        2.0  "Elvis Presley"  "Elvis Presley"
# 2  1956.0        3.0  "Nelson Riddle"  "Nelson Riddle"
# 3  1956.0        4.0       "Platters"       "Platters"
# 4  1956.0        5.0     "Gogi Grant"     "Gogi Grant"
# 5  1956.0        6.0     "Les Baxter"     "Les Baxter"
# 6  1956.0        7.0      "Doris Day"      "Doris Day"
# 7  1956.0        8.0  "Elvis Presley"  "Elvis Presley"
# 8  1956.0        9.0    "Dean Martin"    "Dean Martin"
# 9  1956.0       10.0      "Kay Starr"      "Kay Starr"
#
#                                     song_name  id
# 0                          "Heartbreak Hotel"   1
# 1                            "Don't Be Cruel"   2
# 2                            "Lisbon Antigua"   3
# 3                                 "My Prayer"   4
# 4                          "The Wayward Wind"   5
# 5                  "The Poor People Of Paris"   6
# 6  "Whatever Will Be Will Be (Que Sera Sera)"   7
# 7                                 "Hound Dog"   8
# 8                 "Memories Are Made Of This"   9
# 9                       "Rock And Roll Waltz"  10

# %%
# %%sql
#
# SELECT *
# FROM billboard_top_100_year_end
# ORDER BY artist
# LIMIT 10;
# Out:
#      year  year_rank                    group                         artist  \
# 0  2005.0       42.0            "Chris Brown"
# 1  2009.0       94.0         "Zac Brown Band"
# 2  1997.0       89.0         "Michael Bolton"
# 3  1962.0       77.0            "Rick Nelson"
# 4  1960.0       20.0            "Roy Orbison"
# 5  1959.0        4.0         "Frankie Avalon"
# 6  1961.0       85.0              "Paul Anka"
# 7  1985.0       24.0            "Bryan Adams"
# 8  1991.0       42.0        "Whitney Houston"
# 9  2013.0       41.0  "A$AP Rocky feat. Drake   2 Chainz and Kendrick Lamar"
#
#                  song_name    id
# 0                "Run It!"  5280
# 1         "Whatever It Is"  5898
# 2        "Go The Distance"  4318
# 3          "Teen Age Idol"   685
# 4        "Only The Lonely"   426
# 5                  "Venus"   308
# 6         "Tonight My Love     0
# 7                 "Heaven"  3002
# 8  "I'm Your Baby Tonight"  3642
# 9                  "Drake"     0

# %%
# %%sql
#
# SELECT *
# FROM billboard_top_100_year_end
# WHERE year = 2013
# ORDER BY year_rank
# LIMIT 10;
# Out:
#      year  year_rank                                         group  \
# 0  2013.0        1.0        "Macklemore and Ryan Lewis feat. Wanz"
# 1  2013.0        1.0        "Macklemore and Ryan Lewis feat. Wanz"
# 2  2013.0        1.0        "Macklemore and Ryan Lewis feat. Wanz"
# 3  2013.0        2.0        "Robin Thicke feat. T.I. and Pharrell"
# 4  2013.0        2.0        "Robin Thicke feat. T.I. and Pharrell"
# 5  2013.0        2.0        "Robin Thicke feat. T.I. and Pharrell"
# 6  2013.0        3.0                             "Imagine Dragons"
# 7  2013.0        4.0                                      "Baauer"
# 8  2013.0        5.0  "Macklemore and Ryan Lewis feat. Ray Dalton"
# 9  2013.0        5.0  "Macklemore and Ryan Lewis feat. Ray Dalton"
#
#               artist        song_name    id
# 0       "Ryan Lewis"    "Thrift Shop"  6335
# 1       "Macklemore"    "Thrift Shop"  6334
# 2             "Wanz"    "Thrift Shop"  6336
# 3     "Robin Thicke"  "Blurred Lines"  6337
# 4         "Pharrell"  "Blurred Lines"  6339
# 5             "T.I."  "Blurred Lines"  6338
# 6  "Imagine Dragons"    "Radioactive"  6340
# 7           "Baauer"   "Harlem Shake"  6341
# 8       "Macklemore"  "Can't Hold Us"  6342
# 9       "Ray Dalton"  "Can't Hold Us"  6344

# %%
# %%sql
#
# SELECT *
# FROM billboard_top_100_year_end
# WHERE year = 2013
# ORDER BY year_rank DESC
# LIMIT 10;
# Out:
#      year  year_rank                            group                  artist  \
# 0  2013.0      100.0                       "Paramore"              "Paramore"
# 1  2013.0       99.0                       "2 Chainz"              "2 Chainz"
# 2  2013.0       98.0                   "Randy Houser"          "Randy Houser"
# 3  2013.0       97.0                      "Passenger"             "Passenger"
# 4  2013.0       96.0                 "Sara Bareilles"        "Sara Bareilles"
# 5  2013.0       95.0  "will.i.am feat. Justin Bieber"         "Justin Bieber"
# 6  2013.0       95.0  "will.i.am feat. Justin Bieber"             "will.i.am"
# 7  2013.0       94.0           "Florida Georgia Line"  "Florida Georgia Line"
# 8  2013.0       93.0                "Lady Antebellum"       "Lady Antebellum"
# 9  2013.0       92.0                   "Hunter Hayes"          "Hunter Hayes"
#
#                    song_name    id
# 0           "Still Into You"  6476
# 1            "I'm Different"  6475
# 2  "Runnin' Outta Moonlight"  6474
# 3               "Let Her Go"  6473
# 4                    "Brave"  6472
# 5               "#thatPOWER"  6471
# 6               "#thatPOWER"  6470
# 7        "Get Your Shine On"  6469
# 8                 "Downtown"  6468
# 9                   "Wanted"  6467

# %%
# %%sql
#
# SELECT *
# FROM billboard_top_100_year_end
# WHERE year_rank <= 3
# ORDER BY year DESC, year_rank
# LIMIT 10;
# Out:
#      year  year_rank                                   group  \
# 0  2013.0        1.0  "Macklemore and Ryan Lewis feat. Wanz"
# 1  2013.0        1.0  "Macklemore and Ryan Lewis feat. Wanz"
# 2  2013.0        1.0  "Macklemore and Ryan Lewis feat. Wanz"
# 3  2013.0        2.0  "Robin Thicke feat. T.I. and Pharrell"
# 4  2013.0        2.0  "Robin Thicke feat. T.I. and Pharrell"
# 5  2013.0        2.0  "Robin Thicke feat. T.I. and Pharrell"
# 6  2013.0        3.0                       "Imagine Dragons"
# 7  2012.0        1.0                    "Gotye feat. Kimbra"
# 8  2012.0        1.0                    "Gotye feat. Kimbra"
# 9  2012.0        2.0                      "Carly Rae Jepsen"
#
#                artist                       song_name    id
# 0        "Macklemore"                   "Thrift Shop"  6334
# 1              "Wanz"                   "Thrift Shop"  6336
# 2        "Ryan Lewis"                   "Thrift Shop"  6335
# 3          "Pharrell"                 "Blurred Lines"  6339
# 4              "T.I."                 "Blurred Lines"  6338
# 5      "Robin Thicke"                 "Blurred Lines"  6337
# 6   "Imagine Dragons"                   "Radioactive"  6340
# 7             "Gotye"  "Somebody That I Used To Know"  6203
# 8            "Kimbra"  "Somebody That I Used To Know"  6204
# 9  "Carly Rae Jepsen"                 "Call Me Maybe"  6205

# %%
# %%sql
#
# SELECT *
# FROM billboard_top_100_year_end
# WHERE year_rank <= 3
# ORDER BY year_rank, year DESC
# LIMIT 10;
# Out:
#      year  year_rank                                   group  \
# 0  2013.0        1.0  "Macklemore and Ryan Lewis feat. Wanz"
# 1  2013.0        1.0  "Macklemore and Ryan Lewis feat. Wanz"
# 2  2013.0        1.0  "Macklemore and Ryan Lewis feat. Wanz"
# 3  2012.0        1.0                    "Gotye feat. Kimbra"
# 4  2012.0        1.0                    "Gotye feat. Kimbra"
# 5  2011.0        1.0                                 "Adele"
# 6  2010.0        1.0                                 "Ke$ha"
# 7  2009.0        1.0                   "The Black Eyed Peas"
# 8  2008.0        1.0                 "Flo Rida feat. T-Pain"
# 9  2008.0        1.0                 "Flo Rida feat. T-Pain"
#
#                   artist                       song_name    id
# 0                 "Wanz"                   "Thrift Shop"  6336
# 1           "Ryan Lewis"                   "Thrift Shop"  6335
# 2           "Macklemore"                   "Thrift Shop"  6334
# 3                "Gotye"  "Somebody That I Used To Know"  6203
# 4               "Kimbra"  "Somebody That I Used To Know"  6204
# 5                "Adele"           "Rolling In The Deep"  6056
# 6                "Ke$ha"                       "TiK ToK"  5909
# 7  "The Black Eyed Peas"                 "Boom Boom Pow"  5779
# 8               "T-Pain"                           "Low"  5639
# 9             "Flo Rida"                           "Low"  5638

# %%
# %%sql
#
# SELECT *
# FROM billboard_top_100_year_end
# WHERE year_rank <= 3
# ORDER BY 2, 1 DESC
# LIMIT 10;
# Out:
#      year  year_rank                                   group  \
# 0  2013.0        1.0  "Macklemore and Ryan Lewis feat. Wanz"
# 1  2013.0        1.0  "Macklemore and Ryan Lewis feat. Wanz"
# 2  2013.0        1.0  "Macklemore and Ryan Lewis feat. Wanz"
# 3  2012.0        1.0                    "Gotye feat. Kimbra"
# 4  2012.0        1.0                    "Gotye feat. Kimbra"
# 5  2011.0        1.0                                 "Adele"
# 6  2010.0        1.0                                 "Ke$ha"
# 7  2009.0        1.0                   "The Black Eyed Peas"
# 8  2008.0        1.0                 "Flo Rida feat. T-Pain"
# 9  2008.0        1.0                 "Flo Rida feat. T-Pain"
#
#                   artist                       song_name    id
# 0                 "Wanz"                   "Thrift Shop"  6336
# 1           "Ryan Lewis"                   "Thrift Shop"  6335
# 2           "Macklemore"                   "Thrift Shop"  6334
# 3                "Gotye"  "Somebody That I Used To Know"  6203
# 4               "Kimbra"  "Somebody That I Used To Know"  6204
# 5                "Adele"           "Rolling In The Deep"  6056
# 6                "Ke$ha"                       "TiK ToK"  5909
# 7  "The Black Eyed Peas"                 "Boom Boom Pow"  5779
# 8               "T-Pain"                           "Low"  5639
# 9             "Flo Rida"                           "Low"  5638
