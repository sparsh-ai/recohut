# %%
# %run 02-connect.ipynb

# %%
# %%sql
#
# SELECT *
# FROM billboard_top_100_year_end
# LIMIT 10;
# Out:
#      year  year_rank            group           artist  \
# 0  1956.0        1.0  "Elvis Presley"  "Elvis Presley"
# 1  1956.0        2.0  "Elvis Presley"  "Elvis Presley"
# 2  1956.0        3.0  "Nelson Riddle"  "Nelson Riddle"
# 3  1956.0        4.0       "Platters"       "Platters"
# 4  1956.0        5.0     "Gogi Grant"     "Gogi Grant"
# 5  1956.0        6.0     "Les Baxter"     "Les Baxter"
# 6  1956.0        7.0      "Doris Day"      "Doris Day"
# 7  1956.0        8.0  "Elvis Presley"  "Elvis Presley"
# 8  1956.0        9.0    "Dean Martin"    "Dean Martin"
# 9  1956.0       10.0      "Kay Starr"      "Kay Starr"
#
#                                     song_name  id
# 0                          "Heartbreak Hotel"   1
# 1                            "Don't Be Cruel"   2
# 2                            "Lisbon Antigua"   3
# 3                                 "My Prayer"   4
# 4                          "The Wayward Wind"   5
# 5                  "The Poor People Of Paris"   6
# 6  "Whatever Will Be Will Be (Que Sera Sera)"   7
# 7                                 "Hound Dog"   8
# 8                 "Memories Are Made Of This"   9
# 9                       "Rock And Roll Waltz"  10

# %%
# %%sql
#
# SELECT *
# FROM billboard_top_100_year_end
# WHERE year_rank BETWEEN 5 AND 10
# LIMIT 10;
# Out:
#      year  year_rank            group           artist  \
# 0  1956.0        5.0     "Gogi Grant"     "Gogi Grant"
# 1  1956.0        6.0     "Les Baxter"     "Les Baxter"
# 2  1956.0        7.0      "Doris Day"      "Doris Day"
# 3  1956.0        8.0  "Elvis Presley"  "Elvis Presley"
# 4  1956.0        9.0    "Dean Martin"    "Dean Martin"
# 5  1956.0       10.0      "Kay Starr"      "Kay Starr"
# 6  1957.0        5.0   "Jimmy Dorsey"   "Jimmy Dorsey"
# 7  1957.0        6.0      "Pat Boone"      "Pat Boone"
# 8  1957.0        7.0   "Guy Mitchell"   "Guy Mitchell"
# 9  1957.0        8.0    "Sonny James"    "Sonny James"
#
#                                     song_name   id
# 0                          "The Wayward Wind"    5
# 1                  "The Poor People Of Paris"    6
# 2  "Whatever Will Be Will Be (Que Sera Sera)"    7
# 3                                 "Hound Dog"    8
# 4                 "Memories Are Made Of This"    9
# 5                       "Rock And Roll Waltz"   10
# 6                                   "So Rare"  108
# 7                           "Don't Forbid Me"  109
# 8                         "Singing The Blues"  110
# 9                                "Young Love"  111

# %%
# %%sql
#
# SELECT *
# FROM billboard_top_100_year_end
# WHERE year_rank >= 5 AND year_rank <= 10
# LIMIT 10;
# Out:
#      year  year_rank            group           artist  \
# 0  1956.0        5.0     "Gogi Grant"     "Gogi Grant"
# 1  1956.0        6.0     "Les Baxter"     "Les Baxter"
# 2  1956.0        7.0      "Doris Day"      "Doris Day"
# 3  1956.0        8.0  "Elvis Presley"  "Elvis Presley"
# 4  1956.0        9.0    "Dean Martin"    "Dean Martin"
# 5  1956.0       10.0      "Kay Starr"      "Kay Starr"
# 6  1957.0        5.0   "Jimmy Dorsey"   "Jimmy Dorsey"
# 7  1957.0        6.0      "Pat Boone"      "Pat Boone"
# 8  1957.0        7.0   "Guy Mitchell"   "Guy Mitchell"
# 9  1957.0        8.0    "Sonny James"    "Sonny James"
#
#                                     song_name   id
# 0                          "The Wayward Wind"    5
# 1                  "The Poor People Of Paris"    6
# 2  "Whatever Will Be Will Be (Que Sera Sera)"    7
# 3                                 "Hound Dog"    8
# 4                 "Memories Are Made Of This"    9
# 5                       "Rock And Roll Waltz"   10
# 6                                   "So Rare"  108
# 7                           "Don't Forbid Me"  109
# 8                         "Singing The Blues"  110
# 9                                "Young Love"  111
