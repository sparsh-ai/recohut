# %%
def make_api_call(resource):
    ENDPOINT = "https://dummyjson.com/"
    results_picked = 0
    total_results = 100 #We don't know yet, but we need to initialize
    all_data = []
    while results_picked < total_results:
        response = requests.get(f"{ENDPOINT}{resource}", params = {"skip" : results_picked})
        if response.status_code == 200:
            data = response.json()
            rows = data.get(resource)
            all_data += rows #concatening the two lists
            total_results = data.get("total")
            results_picked += len(rows) #to skip them in the next call
        else:
            raise Exception(response.text)
    return all_data

# %%
users_data = make_api_call("users")
print(len(users_data))
# Out:
# 100

# %%
carts_data = make_api_call("carts")
print(len(carts_data))
# Out:
# 20

# %% [markdown]
# We are going to use the native library json and write our JSON data inside a file.

# %%
import json    

def download_json(data, resource_name):
    file_path = f"{resource_name}.json"
    with open(file_path, "w") as file:
        file.write("\n".join([json.dumps(row) for row in data]))

download_json(carts_data, "carts")
download_json(users_data, "users")

# %%
# !head -1 carts.json
# Out:
# {"id": 1, "products": [{"id": 59, "title": "Spring and summershoes", "price": 20, "quantity": 3, "total": 60, "discountPercentage": 8.71, "discountedPrice": 55}, {"id": 88, "title": "TC Reusable Silicone Magic Washing Gloves", "price": 29, "quantity": 2, "total": 58, "discountPercentage": 3.19, "discountedPrice": 56}, {"id": 18, "title": "Oil Free Moisturizer 100ml", "price": 40, "quantity": 2, "total": 80, "discountPercentage": 13.1, "discountedPrice": 70}, {"id": 95, "title": "Wholesale cargo lashing Belt", "price": 930, "quantity": 1, "total": 930, "discountPercentage": 17.67, "discountedPrice": 766}, {"id": 39, "title": "Women Sweaters Wool", "price": 600, "quantity": 2, "total": 1200, "discountPercentage": 17.2, "discountedPrice": 994}], "total": 2328, "discountedTotal": 1941, "userId": 97, "totalProducts": 5, "totalQuantity": 10}

# %%
# !head -1 users.json
# Out:
# {"id": 1, "firstName": "Terry", "lastName": "Medhurst", "maidenName": "Smitham", "age": 50, "gender": "male", "email": "atuny0@sohu.com", "phone": "+63 791 675 8914", "username": "atuny0", "password": "9uQFF1Lh", "birthDate": "2000-12-25", "image": "https://robohash.org/hicveldicta.png", "bloodGroup": "A\u2212", "height": 189, "weight": 75.4, "eyeColor": "Green", "hair": {"color": "Black", "type": "Strands"}, "domain": "slashdot.org", "ip": "117.29.86.254", "address": {"address": "1745 T Street Southeast", "city": "Washington", "coordinates": {"lat": 38.867033, "lng": -76.979235}, "postalCode": "20020", "state": "DC"}, "macAddress": "13:69:BA:56:A3:74", "university": "Capitol University", "bank": {"cardExpire": "06/22", "cardNumber": "50380955204220685", "cardType": "maestro", "currency": "Peso", "iban": "NO17 0695 2754 967"}, "company": {"address": {"address": "629 Debbie Drive", "city": "Nashville", "coordinates": {"lat": 36.208114, "lng": -86.58621199999999}, "postalCode": "37076", "state": "TN"}, "department": "Marketing", "name": "Blanda-O'Keefe", "title": "Help Desk Operator"}, "ein": "20-9487066", "ssn": "661-64-2976", "userAgent": "Mozilla/5.0 (Windows NT 6.1) AppleWebKit/534.24 (KHTML, like Gecko) Chrome/12.0.702.0 Safari/534.24"}

# %% [markdown]
# ##### Exercise Idea - Build an ELT pipeline by loading this json into data warehouse and perform joins

# %%
import boto3
import json

def get_secret(secret_name, region_name="us-east-1"):
    session = boto3.session.Session()
    client = session.client(
        service_name='secretsmanager',
        region_name=region_name)
    get_secret_value_response = client.get_secret_value(SecretId=secret_name)
    get_secret_value_response = json.loads(get_secret_value_response['SecretString'])
    return get_secret_value_response

creds = get_secret("wysde")
USERNAME = creds["RDS_POSTGRES_USERNAME"]
PASSWORD = creds["RDS_POSTGRES_PASSWORD"]
HOST = creds["RDS_POSTGRES_HOST"]
DATABASE = 'sparsh'

conn_str = 'postgresql://{0}:{1}@{2}/{3}'.format(USERNAME, PASSWORD, HOST, DATABASE)

# %config SqlMagic.autopandas=True
# %config SqlMagic.displaycon=False
# %config SqlMagic.feedback=False
# %config SqlMagic.displaylimit=5
# %reload_ext sql
# %sql {conn_str}

# %%
import pandas as pd
import json

# %%
carts_df = pd.read_json('carts.json', lines=True)
carts_df
# Out:
#     id                                           products  total  \
# 0    1  [{'id': 59, 'title': 'Spring and summershoes',...   2328
# 1    2  [{'id': 96, 'title': 'lighting ceiling kitchen...   3023
# 2    3  [{'id': 37, 'title': 'ank Tops for Womens/Girl...    460
# 3    4  [{'id': 36, 'title': 'Sleeve Shirt Womens', 'p...    553
# 4    5  [{'id': 23, 'title': 'Orange Essence Food Flav...    844
# 5    6  [{'id': 53, 'title': 'printed high quality T s...   1454
# 6    7  [{'id': 61, 'title': 'Leather Straps Wristwatc...    588
# 7    8  [{'id': 45, 'title': 'Malai Maxi Dress', 'pric...   1129
# 8    9  [{'id': 74, 'title': 'Leather Hand Bag', 'pric...   3608
# 9   10  [{'id': 75, 'title': 'Seven Pocket Women Bag',...   9064
# 10  11  [{'id': 71, 'title': 'Women Shoulder Bags', 'p...    581
# 11  12  [{'id': 32, 'title': 'Sofa for Coffe Cafe', 'p...    534
# 12  13  [{'id': 81, 'title': 'Round Silver Frame Sun G...    497
# 13  14  [{'id': 64, 'title': 'Leather Strap Skeleton W...   2121
# 14  15  [{'id': 4, 'title': 'OPPOF19', 'price': 280, '...   4339
# 15  16  [{'id': 3, 'title': 'Samsung Universe 9', 'pri...   4040
# 16  17  [{'id': 12, 'title': 'Brown Perfume', 'price':...    352
# 17  18  [{'id': 23, 'title': 'Orange Essence Food Flav...   2476
# 18  19  [{'id': 43, 'title': 'frock gold printed', 'pr...   2492
# 19  20  [{'id': 66, 'title': 'Steel Analog Couple Watc...    315
#
#     discountedTotal  userId  totalProducts  totalQuantity
# 0              1941      97              5             10
# 1              2625      30              5             10
# 2               403      63              5             10
# 3               493      83              5             10
# 4               745      58              5             10
# 5              1276      26              5             12
# 6               519      56              5             10
# 7               952       1              5              9
# 8              3371      91              5             10
# 9              8205      13              5              9
# 10              502      66              5             12
# 11              459      52              5             11
# 12              425      79              5              9
# 13             2021      76              5              9
# 14             4007      47              5             12
# 15             3414      15              5             10
# 16              300      56              5              8
# 17             2189      42              5              9
# 18             2140       5              5             14
# 19              279      75              5              8

# %%
carts_df['products'] = carts_df['products'].apply(json.dumps)
carts_df
# Out:
#     id                                           products  total  \
# 0    1  [{"id": 59, "title": "Spring and summershoes",...   2328
# 1    2  [{"id": 96, "title": "lighting ceiling kitchen...   3023
# 2    3  [{"id": 37, "title": "ank Tops for Womens/Girl...    460
# 3    4  [{"id": 36, "title": "Sleeve Shirt Womens", "p...    553
# 4    5  [{"id": 23, "title": "Orange Essence Food Flav...    844
# 5    6  [{"id": 53, "title": "printed high quality T s...   1454
# 6    7  [{"id": 61, "title": "Leather Straps Wristwatc...    588
# 7    8  [{"id": 45, "title": "Malai Maxi Dress", "pric...   1129
# 8    9  [{"id": 74, "title": "Leather Hand Bag", "pric...   3608
# 9   10  [{"id": 75, "title": "Seven Pocket Women Bag",...   9064
# 10  11  [{"id": 71, "title": "Women Shoulder Bags", "p...    581
# 11  12  [{"id": 32, "title": "Sofa for Coffe Cafe", "p...    534
# 12  13  [{"id": 81, "title": "Round Silver Frame Sun G...    497
# 13  14  [{"id": 64, "title": "Leather Strap Skeleton W...   2121
# 14  15  [{"id": 4, "title": "OPPOF19", "price": 280, "...   4339
# 15  16  [{"id": 3, "title": "Samsung Universe 9", "pri...   4040
# 16  17  [{"id": 12, "title": "Brown Perfume", "price":...    352
# 17  18  [{"id": 23, "title": "Orange Essence Food Flav...   2476
# 18  19  [{"id": 43, "title": "frock gold printed", "pr...   2492
# 19  20  [{"id": 66, "title": "Steel Analog Couple Watc...    315
#
#     discountedTotal  userId  totalProducts  totalQuantity
# 0              1941      97              5             10
# 1              2625      30              5             10
# 2               403      63              5             10
# 3               493      83              5             10
# 4               745      58              5             10
# 5              1276      26              5             12
# 6               519      56              5             10
# 7               952       1              5              9
# 8              3371      91              5             10
# 9              8205      13              5              9
# 10              502      66              5             12
# 11              459      52              5             11
# 12              425      79              5              9
# 13             2021      76              5              9
# 14             4007      47              5             12
# 15             3414      15              5             10
# 16              300      56              5              8
# 17             2189      42              5              9
# 18             2140       5              5             14
# 19              279      75              5              8

# %%
carts_df.to_sql('carts_elt', con=conn_str, index=False)

# %%
# %%sql
# SELECT * FROM carts_elt LIMIT 10
# Out:
#    id                                           products  total  \
# 0   1  [{"id": 59, "title": "Spring and summershoes",...   2328
# 1   2  [{"id": 96, "title": "lighting ceiling kitchen...   3023
# 2   3  [{"id": 37, "title": "ank Tops for Womens/Girl...    460
# 3   4  [{"id": 36, "title": "Sleeve Shirt Womens", "p...    553
# 4   5  [{"id": 23, "title": "Orange Essence Food Flav...    844
# 5   6  [{"id": 53, "title": "printed high quality T s...   1454
# 6   7  [{"id": 61, "title": "Leather Straps Wristwatc...    588
# 7   8  [{"id": 45, "title": "Malai Maxi Dress", "pric...   1129
# 8   9  [{"id": 74, "title": "Leather Hand Bag", "pric...   3608
# 9  10  [{"id": 75, "title": "Seven Pocket Women Bag",...   9064
#
#    discountedTotal  userId  totalProducts  totalQuantity
# 0             1941      97              5             10
# 1             2625      30              5             10
# 2              403      63              5             10
# 3              493      83              5             10
# 4              745      58              5             10
# 5             1276      26              5             12
# 6              519      56              5             10
# 7              952       1              5              9
# 8             3371      91              5             10
# 9             8205      13              5              9

# %%
users_df = pd.read_json('users.json', lines=True)
users_df.head(2).T
# Out:
#                                                             0  \
# id                                                          1
# firstName                                               Terry
# lastName                                             Medhurst
# maidenName                                            Smitham
# age                                                        50
# gender                                                   male
# email                                         atuny0@sohu.com
# phone                                        +63 791 675 8914
# username                                               atuny0
# password                                             9uQFF1Lh
# birthDate                                          2000-12-25
# image                    https://robohash.org/hicveldicta.png
# bloodGroup                                                 A−
# height                                                    189
# weight                                                   75.4
# eyeColor                                                Green
# hair                    {'color': 'Black', 'type': 'Strands'}
# domain                                           slashdot.org
# ip                                              117.29.86.254
# address     {'address': '1745 T Street Southeast', 'city':...
# macAddress                                  13:69:BA:56:A3:74
# university                                 Capitol University
# bank        {'cardExpire': '06/22', 'cardNumber': '5038095...
# company     {'address': {'address': '629 Debbie Drive', 'c...
# ein                                                20-9487066
# ssn                                               661-64-2976
# userAgent   Mozilla/5.0 (Windows NT 6.1) AppleWebKit/534.2...
#
#                                                             1
# id                                                          2
# firstName                                             Sheldon
# lastName                                              Quigley
# maidenName                                               Cole
# age                                                        28
# gender                                                   male
# email                                   hbingley1@plala.or.jp
# phone                                         +7 813 117 7139
# username                                            hbingley1
# password                                           CQutx25i8r
# birthDate                                          2003-08-02
# image         https://robohash.org/doloremquesintcorrupti.png
# bloodGroup                                                 O+
# height                                                    187
# weight                                                   74.0
# eyeColor                                                Brown
# hair                      {'color': 'Blond', 'type': 'Curly'}
# domain                                                  51.la
# ip                                             253.240.20.181
# address     {'address': '6007 Applegate Lane', 'city': 'Lo...
# macAddress                                  13:F1:00:DA:A4:12
# university               Stavropol State Technical University
# bank        {'cardExpire': '10/23', 'cardNumber': '5355920...
# company     {'address': {'address': '8821 West Myrtle Aven...
# ein                                                52-5262907
# ssn                                               447-08-9217
# userAgent   Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...

# %%
users_df['hair'] = users_df['hair'].apply(json.dumps)
users_df['address'] = users_df['address'].apply(json.dumps)
users_df['bank'] = users_df['bank'].apply(json.dumps)
users_df['company'] = users_df['company'].apply(json.dumps)
users_df.head(2).T
# Out:
#                                                             0  \
# id                                                          1
# firstName                                               Terry
# lastName                                             Medhurst
# maidenName                                            Smitham
# age                                                        50
# gender                                                   male
# email                                         atuny0@sohu.com
# phone                                        +63 791 675 8914
# username                                               atuny0
# password                                             9uQFF1Lh
# birthDate                                          2000-12-25
# image                    https://robohash.org/hicveldicta.png
# bloodGroup                                                 A−
# height                                                    189
# weight                                                   75.4
# eyeColor                                                Green
# hair                    {"color": "Black", "type": "Strands"}
# domain                                           slashdot.org
# ip                                              117.29.86.254
# address     {"address": "1745 T Street Southeast", "city":...
# macAddress                                  13:69:BA:56:A3:74
# university                                 Capitol University
# bank        {"cardExpire": "06/22", "cardNumber": "5038095...
# company     {"address": {"address": "629 Debbie Drive", "c...
# ein                                                20-9487066
# ssn                                               661-64-2976
# userAgent   Mozilla/5.0 (Windows NT 6.1) AppleWebKit/534.2...
#
#                                                             1
# id                                                          2
# firstName                                             Sheldon
# lastName                                              Quigley
# maidenName                                               Cole
# age                                                        28
# gender                                                   male
# email                                   hbingley1@plala.or.jp
# phone                                         +7 813 117 7139
# username                                            hbingley1
# password                                           CQutx25i8r
# birthDate                                          2003-08-02
# image         https://robohash.org/doloremquesintcorrupti.png
# bloodGroup                                                 O+
# height                                                    187
# weight                                                   74.0
# eyeColor                                                Brown
# hair                      {"color": "Blond", "type": "Curly"}
# domain                                                  51.la
# ip                                             253.240.20.181
# address     {"address": "6007 Applegate Lane", "city": "Lo...
# macAddress                                  13:F1:00:DA:A4:12
# university               Stavropol State Technical University
# bank        {"cardExpire": "10/23", "cardNumber": "5355920...
# company     {"address": {"address": "8821 West Myrtle Aven...
# ein                                                52-5262907
# ssn                                               447-08-9217
# userAgent   Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...

# %%
users_df.to_sql('users_elt', con=conn_str, index=False)

# %%
# %%sql
# SELECT * FROM users_elt LIMIT 10
# Out:
#    id  firstName   lastName maidenName  age  gender                    email  \
# 0   1      Terry   Medhurst    Smitham   50    male          atuny0@sohu.com
# 1   2    Sheldon    Quigley       Cole   28    male    hbingley1@plala.or.jp
# 2   3    Terrill      Hills     Hoeger   38    male            rshawe2@51.la
# 3   4      Miles  Cummerata     Maggio   49    male     yraigatt3@nature.com
# 4   5      Mavis    Schultz      Yundt   38    male         kmeus4@upenn.edu
# 5   6     Alison   Reichert   Franecki   21  female        jtreleven5@nhs.uk
# 6   7      Oleta     Abbott      Wyman   31  female  dpettegre6@columbia.edu
# 7  15     Jeanne  Halvorson  Cummerata   26  female        kminchelle@qq.com
# 8   8      Ewell    Mueller     Durgan   29    male         ggude7@chron.com
# 9   9  Demetrius    Corkery    Gleason   22    male      nloiterton8@aol.com
#
#                phone     username      password  ...         domain  \
# 0   +63 791 675 8914       atuny0      9uQFF1Lh  ...   slashdot.org
# 1    +7 813 117 7139    hbingley1    CQutx25i8r  ...          51.la
# 2   +63 739 292 7942      rshawe2    OWsTbMUgFc  ...  earthlink.net
# 3   +86 461 145 4186    yraigatt3     sRQxjPfdS  ...  homestead.com
# 4  +372 285 771 1911       kmeus4     aUTdmmmbH  ...   columbia.edu
# 5  +351 527 735 3642   jtreleven5     zY1nE46Zm  ...   bandcamp.com
# 6   +62 640 802 7111   dpettegre6    YVmhktgYVS  ...        ovh.net
# 7   +86 581 108 7855   kminchelle       0lelplR  ...   google.co.uk
# 8   +86 946 297 2275       ggude7  MWwlaeWcOoF6  ...  homestead.com
# 9   +86 356 590 9727  nloiterton8   HTQxxXV9Bq4  ...  goodreads.com
#
#                ip                                            address  \
# 0   117.29.86.254  {"address": "1745 T Street Southeast", "city":...
# 1  253.240.20.181  {"address": "6007 Applegate Lane", "city": "Lo...
# 2   205.226.160.3  {"address": "560 Penstock Drive", "city": "Gra...
# 3   243.20.78.113  {"address": "150 Carter Street", "city": "Manc...
# 4   103.72.86.183  {"address": "2721 Lindsay Avenue", "city": "Lo...
# 5   49.201.206.36  {"address": "18 Densmore Drive", "city": "Esse...
# 6  25.207.107.146  {"address": "637 Britannia Drive", "city": "Va...
# 7    78.43.74.226  {"address": "4 Old Colony Way", "city": "Yarmo...
# 8   91.200.56.127  {"address": "5601 West Crocus Drive", "city": ...
# 9  78.170.185.120  {"address": "5403 Illinois Avenue", "city": "N...
#
#           macAddress                             university  \
# 0  13:69:BA:56:A3:74                     Capitol University
# 1  13:F1:00:DA:A4:12   Stavropol State Technical University
# 2  F2:88:58:64:F7:76           University of Cagayan Valley
# 3  03:45:58:59:5A:7B     Shenyang Pharmaceutical University
# 4  F8:04:9E:ED:C0:68   Estonian University of Life Sciences
# 5  6C:34:D0:4B:4E:81         Universidade da Beira Interior
# 6  48:2D:A0:67:19:E0  Institut Sains dan Teknologi Al Kamal
# 7  D9:DB:D9:5A:01:09           Donghua University, Shanghai
# 8  72:DA:1B:D7:30:E9                Wenzhou Medical College
# 9  98:EE:94:A2:91:C4        Nanjing University of Economics
#
#                                                 bank  \
# 0  {"cardExpire": "06/22", "cardNumber": "5038095...
# 1  {"cardExpire": "10/23", "cardNumber": "5355920...
# 2  {"cardExpire": "10/23", "cardNumber": "3586082...
# 3  {"cardExpire": "07/24", "cardNumber": "3580047...
# 4  {"cardExpire": "01/24", "cardNumber": "4917245...
# 5  {"cardExpire": "03/22", "cardNumber": "3456758...
# 6  {"cardExpire": "10/23", "cardNumber": "3589640...
# 7  {"cardExpire": "10/23", "cardNumber": "3588859...
# 8  {"cardExpire": "09/23", "cardNumber": "3054992...
# 9  {"cardExpire": "02/24", "cardNumber": "5372664...
#
#                                              company         ein          ssn  \
# 0  {"address": {"address": "629 Debbie Drive", "c...  20-9487066  661-64-2976
# 1  {"address": {"address": "8821 West Myrtle Aven...  52-5262907  447-08-9217
# 2  {"address": {"address": "18 Densmore Drive", "...  48-3951994  633-89-1926
# 3  {"address": {"address": "210 Green Road", "cit...  71-3644334  487-28-6642
# 4  {"address": {"address": "8398 West Denton Lane...  18-7178563  667-98-5357
# 5  {"address": {"address": "6231 North 67th Avenu...  78-3192791  158-68-0184
# 6  {"address": {"address": "1407 Walden Court", "...  29-1568401  478-11-2206
# 7  {"address": {"address": "22572 Toreador Drive"...  62-0561095  855-43-8639
# 8  {"address": {"address": "81 Seaton Place North...  88-4396827  238-41-5528
# 9  {"address": {"address": "12245 West 71st Place...  14-1066382  717-26-3759
#
#                                            userAgent
# 0  Mozilla/5.0 (Windows NT 6.1) AppleWebKit/534.2...
# 1  Mozilla/5.0 (X11; Linux x86_64) AppleWebKit/53...
# 2  Mozilla/5.0 (Windows NT 6.2; Win64; x64; rv:21...
# 3  Mozilla/5.0 (Windows NT 6.2; WOW64) AppleWebKi...
# 4  Mozilla/5.0 (Windows NT 6.0) AppleWebKit/535.1...
# 5  Mozilla/5.0 (Windows; U; Windows NT 6.0; nb-NO...
# 6  Mozilla/5.0 (Windows; U; Windows NT 5.1; ru-RU...
# 7  Mozilla/5.0 (X11; Linux i686) AppleWebKit/534....
# 8  Mozilla/5.0 (X11; Linux amd64) AppleWebKit/534...
# 9  Mozilla/5.0 (Macintosh; U; PPC Mac OS X 10_4_1...
#
# [10 rows x 27 columns]

# %%
# %%sql
# SELECT *
# FROM (
#         SELECT u.id AS user_id,
#             u."firstName" AS user_first_name,
#             u."lastName" AS user_last_name,
#             SUM(total) AS total_spent
#         FROM users_elt u
#             LEFT JOIN carts_elt c ON u.id = c."userId"
#         GROUP BY u.id,
#             user_first_name,
#             user_last_name
#         ORDER BY total_spent DESC
#     ) ts
# WHERE total_spent IS NOT NULL
# Out:
#     user_id user_first_name user_last_name total_spent
# 0        13           Trace        Douglas        9064
# 1        47         Coralie          Boyle        4339
# 2        15          Jeanne      Halvorson        4040
# 3        91            Arne         Jacobs        3608
# 4        30         Maurine        Stracke        3023
# 5         5           Mavis        Schultz        2492
# 6        42           Tiara        Rolfson        2476
# 7        97          Allene         Harber        2328
# 8        76            Deon      Gutkowski        2121
# 9        26         Griffin          Braun        1454
# 10        1           Terry       Medhurst        1129
# 11       56          Megane      Armstrong         940
# 12       58          Deanna         Glover         844
# 13       66        Terrence        Koelpin         581
# 14       83            Rita        Shields         553
# 15       52          Elbert       Gottlieb         534
# 16       79        Harrison          Lemke         497
# 17       63           Nasir       Leuschke         460
# 18       75         Claudia         Dooley         315

# %% [markdown]
# Seems like Trace Douglas is our top spender! Let’s add this table as a part of our ELT.

# %%
# %%sql
# CREATE TABLE top_spenders AS
# SELECT *
# FROM (
#         SELECT u.id AS user_id,
#             u."firstName" AS user_first_name,
#             u."lastName" AS user_last_name,
#             SUM(total) AS total_spent
#         FROM users_elt u
#             LEFT JOIN carts_elt c ON u.id = c."userId"
#         GROUP BY u.id,
#             user_first_name,
#             user_last_name
#         ORDER BY total_spent DESC
#     ) ts
# WHERE total_spent IS NOT NULL
# Out:
# Empty DataFrame
# Columns: []
# Index: []

# %%
# %%sql
# SELECT *
# FROM top_spenders
# LIMIT 10
# Out:
#    user_id user_first_name user_last_name total_spent
# 0       13           Trace        Douglas        9064
# 1       47         Coralie          Boyle        4339
# 2       15          Jeanne      Halvorson        4040
# 3       91            Arne         Jacobs        3608
# 4       30         Maurine        Stracke        3023
# 5        5           Mavis        Schultz        2492
# 6       42           Tiara        Rolfson        2476
# 7       97          Allene         Harber        2328
# 8       76            Deon      Gutkowski        2121
# 9       26         Griffin          Braun        1454
