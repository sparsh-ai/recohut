# %%
# %%capture
pip install psycopg2-binary

# %%
# !mkdir -p ~/.aws && cp /content/drive/MyDrive/AWS/d01_admin/* ~/.aws
# !chmod 600 ~/.aws/credentials
# !pip install awscli

# %%
import pandas as pd
import psycopg2
from sqlalchemy import create_engine
from sqlalchemy import text

# %%
redshift_endpoint1 = "<endpoint>"
redshift_user1 = "adminuser"
redshift_pass1 = ""
port1 = 5439
dbname1 = "dev"

# %%
engine_string = "postgresql+psycopg2://%s:%s@%s:%d/%s" \
% (redshift_user1, redshift_pass1, redshift_endpoint1, port1, dbname1)
engine = create_engine(engine_string)

# %%
query = """
SELECT *
FROM pg_catalog.pg_tables
WHERE schemaname != 'pg_catalog' AND 
    schemaname != 'information_schema';
"""

df = pd.read_sql_query(text(query), engine)
df
# Out:
#     schemaname                            tablename tableowner tablespace  \
# 0  pg_internal  redshift_auto_health_check_10919271      rdsdb       None
# 1       public                                sales      rdsdb       None
# 2       public                              listing      rdsdb       None
# 3       public                                event      rdsdb       None
# 4       public                                 date      rdsdb       None
# 5       public                             category      rdsdb       None
# 6       public                                venue      rdsdb       None
# 7       public                                users      rdsdb       None
#
#    hasindexes  hasrules  hastriggers
# 0       False     False        False
# 1       False     False        False
# 2       False     False        False
# 3       False     False        False
# 4       False     False        False
# 5       False     False        False
# 6       False     False        False
# 7       False     False        False

# %%
query = """
SELECT * FROM "dev"."public"."users";
"""

df = pd.read_sql_query(text(query), engine)
df
# Out:
#        userid  username   firstname  lastname          city state  \
# 0           2  PGL08LJI    Vladimir  Humphrey  Murfreesboro    SK
# 1           4  XDZ38RDD       Barry       Roy         Omaha    AB
# 2           5  AEB55QTM      Reagan     Hodge   Forest Lake    NS
# 3           7  OWY35QYB     Tamekah    Juarez      Moultrie    WV
# 4           9  MSD36KVR     Mufutau   Watkins   Port Orford    MD
# ...       ...       ...         ...       ...           ...   ...
# 49985   49983  RCS76EGO    Colorado    Fuller    Blacksburg    SK
# 49986   49984  FFP96MVH       Caryn   Cabrera       Beckley    CO
# 49987   49986  WSZ25RSI       Basil    Sexton     Milwaukee    CO
# 49988   49989  RRS41ZTJ  Evangeline    Franco   Bakersfield    NT
# 49989   49990  ILI20QYV        Iola     Avery     Frankfort    NU
#
#                                              email           phone likesports  \
# 0          Suspendisse.tristique@nonnisiAenean.edu  (783) 492-1886       None
# 1                                sed@lacusUtnec.ca  (355) 452-8168      False
# 2                                 Cum@accumsan.com  (476) 519-9131       None
# 3                  elementum@semperpretiumneque.ca  (297) 875-7247       None
# 4      Integer.mollis.Integer@tristiquealiquet.org  (725) 719-7670       True
# ...                                            ...             ...        ...
# 49985                  dolor.sit@acmattisvelit.com  (894) 748-8662       True
# 49986        ac.turpis.egestas@scelerisquelorem.ca  (641) 730-2786       True
# 49987           sociis.natoque.penatibus@vitae.org  (858) 335-0367       True
# 49988                         nibh.enim@egestas.ca  (976) 963-7780       None
# 49989               urna.Ut@egetdictumplacerat.edu  (443) 197-1154       None
#
#       liketheatre likeconcerts likejazz likeclassical likeopera likerock  \
# 0            None         None     True          True      None     None
# 1            True         None    False          None      None     None
# 2            None         True    False          None      None     True
# 3            None         None     True          True     False     None
# 4           False         None    False          True      None     None
# ...           ...          ...      ...           ...       ...      ...
# 49985        True         True     True          None      None     True
# 49986        None         True     None          None     False     None
# 49987        None         True     None          None      None     True
# 49988        None         None    False         False      None    False
# 49989        None         None     None          None      None     None
#
#       likevegas likebroadway likemusicals
# 0          True        False         True
# 1          None         None        False
# 2          True        False         True
# 3          None        False        False
# 4          None        False         True
# ...         ...          ...          ...
# 49985      None        False         None
# 49986      None         True         None
# 49987      None         True         True
# 49988      None        False         True
# 49989      True         True         True
#
# [49990 rows x 18 columns]
